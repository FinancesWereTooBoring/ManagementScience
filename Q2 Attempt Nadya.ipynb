# %%
import gurobipy as gb
import pandas as pd
import gurobipy as gb

# %%
df = pd.read_csv("~/Desktop/uni BAM/MS/Group Assignment/flights-1.csv",  encoding='latin-1')

issues = {"ZÃ¼rich": "Zurich",
          "DÃ¼sseldorf": "Dusseldorf", "MÃ¡laga": "Malaga"}
for key, value in issues.items():
    df.loc[df["departureCity"] == key, "departureCity"] = value
    df.loc[df["arrivalCity"] == key, "arrivalCity"] = value

# %%
df2 = df.set_index('departureCity').join(df.set_index('departureCity'),
                                         lsuffix = "first", rsuffix = "second").reset_index()
df2 = df2[df2.arrivalCityfirst != df2.arrivalCitysecond]
df2["distance"] = df2.Distancefirst + df2.Distancesecond
df2 = df2[["departureCity", "arrivalCityfirst", "arrivalCitysecond", "distance"]]
df2.columns = ["Hub", "arrivalCity", "departureCity", "Distance"]

# %%
merged_df = df2.merge(df[["departureCity", "arrivalCity", "Distance", "Demand"]],
               on=["departureCity", "arrivalCity"],
               how="left")
merged_df.columns = ["Hub", "arrivalCity", "departureCity", "IndirectDistance","DirectDistance", "Demand"]
filtered_df = merged_df[merged_df["IndirectDistance"] <= 1.3* merged_df["DirectDistance"]] # set of all the indirect routes that can be taken and their distances

# %%
Indirect_Distance = {}
for index, row in filtered_df.iterrows():
    Indirect_Distance[row.departureCity, row.Hub, row.arrivalCity] = row.IndirectDistance
    
Direct_Distance = {}
for index, row in merged_df.iterrows():
    Direct_Distance[row.departureCity, row.arrivalCity] = row.DirectDistance
    
Direct_Demand = {}
for index, row in merged_df.iterrows():
    Direct_Demand[row.departureCity, row.arrivalCity] = row.Demand

Indirect_Demand = {}
for index, row in filtered_df.iterrows():
    Indirect_Demand[row.departureCity, row.Hub, row.arrivalCity] = row.Demand
    
ItineraryFlights = {}
for index, row in merged_df.iterrows():
    itflights = []
    if row.Hub == "":
        itflights.append((row.departureCity, row.arrivalCity))
        ItineraryFlights[row.departureCity, row.arrivalCity] = itflights
    else:
        itflights.append((row.departureCity, row.Hub))
        itflights.append((row.Hub, row.arrivalCity))
        ItineraryFlights[row.departureCity, row.arrivalCity] = itflights
        
HubCities = list(set(merged_df.Hub.unique()))
HubCities = HubCities[1:]

IndirectRevenuePerCustomer = {}
for index, row in filtered_df.iterrows():
        IndirectRevenuePerCustomer[row.departureCity, row.Hub, row.arrivalCity] = row.DirectDistance*0.08

DirectRevenuePerCustomer = {}
for index, row in merged_df.iterrows():
        DirectRevenuePerCustomer[row.departureCity, row.arrivalCity] = row.DirectDistance * 0.1

# %%
charge_indirect = 0.08
charge_direct = 0.1
cost_per_mile = {"small":4.5, "medium":8, "large":20}
capacity = {"small":50, "medium":100, "large":300}
sizes = ["small", "medium", "large"]
M = 1000000000000000

model = gb.Model()
model.setParam('TimeLimit', 15*60)

# Variables
small_direct = model.addVars(ItineraryFlights, name = "small", vtype = gb.GRB.INTEGER, lb = 0)
medium_direct = model.addVars(ItineraryFlights, name = "medium", vtype = gb.GRB.INTEGER, lb = 0)
large_direct = model.addVars(ItineraryFlights, name = "large", vtype = gb.GRB.INTEGER, lb = 0)

small_indirect = model.addVars(Indirect_Distance, name = "small", vtype = gb.GRB.INTEGER, lb = 0)
medium_indirect = model.addVars(Indirect_Distance, name = "medium", vtype = gb.GRB.INTEGER, lb = 0)
large_indirect = model.addVars(Indirect_Distance, name = "large", vtype = gb.GRB.INTEGER, lb = 0)

x = model.addVars(Direct_Distance ,name = "direct_passengers", vtype = gb.GRB.INTEGER, lb = 0, ub = Direct_Demand)
f = model.addVars(Indirect_Distance, name = "indirect_passengers", vtype = gb.GRB.INTEGER, lb = 0, ub = Indirect_Demand)

h = model.addVars(HubCities, name = "hub", vtype = gb.GRB.BINARY, lb = 0, ub = 1)

# Set Constraints

# There can only be 1 hub
for city in HubCities:
    model.addConstr(gb.quicksum(f[route] for route in Indirect_Distance if city in route) <= h[city] * M)
model.addConstr(gb.quicksum(h[k] for k in HubCities) == 2)

# Total number of passengers cannot exceed demand
#model.addConstrs((x[route]) <= Direct_Demand[route] for route in Direct_Distance)
#model.addConstrs((f[route]) <= Indirect_Demand[route] for route in Indirect_Distance)

model.addConstrs((x[route] + f[routes]) <= Direct_Demand[route] for route in Direct_Distance for routes in Indirect_Distance)

# Number of passengers cannot exceed capacity
#model.addConstrs((x[route]) <= capacity[s] * cost_per_mile[s] for s in sizes for route in Direct_Distance)
#model.addConstrs((f[route]) <= capacity[s] * cost_per_mile[s] for s in sizes for route in Indirect_Distance)

#model.addConstrs((x[route] + f[routes]) <= capacity["small"] * small_direct[route] +
 #                capacity["medium"] * medium_direct[route] +
  #               capacity["large"] * large_direct[route] for route in Direct_Distance for routes in Indirect_Distance)

model.addConstrs(
    gb.quicksum(x[route] + f[indirect_route] for indirect_route in Indirect_Distance[route])
    <= capacity["small"] * small_direct[route] +
       capacity["medium"] * medium_direct[route] +
       capacity["large"] * large_direct[route]
    for route in Direct_Distance
)



# Setting the Objective
model.setObjective(
    gb.quicksum(
        DirectRevenuePerCustomer[route] - Direct_Distance[route] * (
            cost_per_mile["small"] * small_direct[route] +
            cost_per_mile["medium"] * medium_direct[route] +
            cost_per_mile["large"] * large_direct[route]
        ) for route in Direct_Distance
    ) +
    gb.quicksum(
        IndirectRevenuePerCustomer[route] - Indirect_Distance[route] * (
            cost_per_mile["small"] * small_indirect[route] +
            cost_per_mile["medium"] * medium_indirect[route] +
            cost_per_mile["large"] * large_indirect[route]
        ) for route in Indirect_Distance
    ),
    gb.GRB.MAXIMIZE
)

model.optimize()

if model.status == gb.GRB.OPTIMAL:

    selected_hubs = [city for city in HubCities if h[city].x > 0.5]
    print("Selected Hubs:", selected_hubs)
else:
    print("Optimization was not successful.")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-31
# Set parameter TimeLimit to value 900

# %%
vals = model.printAttr(["X", "Obj"])
all_vars = model.getVars()

# Since there are a lot of variables, I decided to move them into a dataframe format
values = model.getAttr("X", all_vars)
names = model.getAttr("VarName", all_vars)

res = pd.DataFrame({"names": names, "values": values})
# Out:
#     Variable            X          Obj
# --------------------------------------
# small[Madrid,London]            0        -3528
# small[Paris,London]            0       -958.5
# small[Frankfurt,London]            0      -1786.5
# small[Amsterdam,London]            0         -999
# small[Istanbul,London]            0        -7002
# small[Palma de Mallorca,London]            0      -3757.5
# small[Rome,London]            0        -4014
# small[Moscow,London]            0        -7011
# small[Lisbon,London]            0      -4432.5
# small[Zurich,London]            0      -2173.5
# small[Milan,London]            0        -2682
# small[Copenhagen,London]            0      -2677.5
# small[Manchester,London]            0       -733.5
# small[Malaga,London]            0        -4689
# small[Vienna,London]            0      -3460.5
# small[Oslo,London]            0        -3231
# small[Dusseldorf,London]            0      -1345.5
# small[Dublin,London]            0        -1296
# small[Athens,London]            0        -6696
# small[Porto,London]            0      -3694.5
# small[Helsinki,London]            0        -5103
# small[Stockholm,London]            0        -4014
# small[Berlin,London]            0      -2605.5
# small[Prague,London]            0      -2902.5
# small[Hamburg,London]            0      -2020.5
# small[Warsaw,London]            0        -4059
# small[Budapest,London]            0      -4063.5
# small[Geneva,London]            0        -2088
# small[Kyiv,London]            0      -5980.5
# small[Bucharest,London]            0        -5859
# small[Birmingham,London]            0       -454.5
# small[Milan/Bergamo,London]            0      -2713.5
# small[Edinburgh,London]            0        -1494
# small[Nice,London]            0      -2875.5
# small[Cologne/Bonn,London]            0        -1431
# small[Saint Petersburg,London]            0        -5886
# small[Stuttgart,London]            0      -2038.5
# small[Lyon,London]            0      -2056.5
# small[Trondheim,London]            0        -4095
# small[London,Madrid]            0        -3528
# small[Paris,Madrid]            0        -2943
# small[Frankfurt,Madrid]            0      -4045.5
# small[Amsterdam,Madrid]            0        -4140
# small[Istanbul,Madrid]            0      -7672.5
# small[Palma de Mallorca,Madrid]            0        -1539
# small[Rome,Madrid]            0      -3820.5
# small[Moscow,Madrid]            0        -9639
# small[Lisbon,Madrid]            0      -1408.5
# small[Zurich,Madrid]            0      -3487.5
# small[Milan,Madrid]            0      -3325.5
# small[Copenhagen,Madrid]            0      -5800.5
# small[Manchester,Madrid]            0        -4068
# small[Malaga,Madrid]            0      -1156.5
# small[Vienna,Madrid]            0        -5067
# small[Oslo,Madrid]            0        -6678
# small[Dusseldorf,Madrid]            0      -4045.5
# small[Dublin,Madrid]            0      -4054.5
# small[Athens,Madrid]            0      -6637.5
# small[Porto,Madrid]            0        -1179
# small[Helsinki,Madrid]            0        -8253
# small[Stockholm,Madrid]            0      -7258.5
# small[Berlin,Madrid]            0        -5229
# small[Prague,Madrid]            0      -4963.5
# small[Hamburg,Madrid]            0        -4995
# small[Warsaw,Madrid]            0      -6412.5
# small[Budapest,Madrid]            0      -5530.5
# small[Geneva,Madrid]            0        -2862
# small[Kyiv,Madrid]            0        -8019
# small[Bucharest,Madrid]            0        -6930
# small[Birmingham,Madrid]            0      -3766.5
# small[Milan/Bergamo,Madrid]            0      -3451.5
# small[Edinburgh,Madrid]            0      -4828.5
# small[Nice,Madrid]            0      -2731.5
# small[Cologne/Bonn,Madrid]            0        -4005
# small[Saint Petersburg,Madrid]            0      -8932.5
# small[Stuttgart,Madrid]            0        -3852
# small[Lyon,Madrid]            0      -2551.5
# small[Trondheim,Madrid]            0        -7614
# small[London,Paris]            0       -958.5
# small[Madrid,Paris]            0        -2943
# small[Frankfurt,Paris]            0      -1336.5
# small[Amsterdam,Paris]            0      -1201.5
# small[Istanbul,Paris]            0        -6318
# small[Palma de Mallorca,Paris]            0      -2884.5
# small[Rome,Paris]            0      -3091.5
# small[Moscow,Paris]            0      -6970.5
# small[Lisbon,Paris]            0        -4068
# small[Zurich,Paris]            0        -1368
# small[Milan,Paris]            0        -1791
# small[Copenhagen,Paris]            0      -2875.5
# small[Manchester,Paris]            0        -1692
# small[Malaga,Paris]            0        -4068
# small[Vienna,Paris]            0        -2898
# small[Oslo,Paris]            0        -3753
# small[Dusseldorf,Paris]            0        -1152
# small[Dublin,Paris]            0        -2187
# small[Athens,Paris]            0        -5868
# small[Porto,Paris]            0        -3393
# small[Helsinki,Paris]            0        -5346
# small[Stockholm,Paris]            0        -4320
# small[Berlin,Paris]            0      -2452.5
# small[Prague,Paris]            0        -2475
# small[Hamburg,Paris]            0      -2083.5
# small[Warsaw,Paris]            0      -3829.5
# small[Budapest,Paris]            0      -3487.5
# small[Geneva,Paris]            0      -1147.5
# small[Kyiv,Paris]            0      -5674.5
# small[Bucharest,Paris]            0      -5242.5
# small[Birmingham,Paris]            0        -1404
# small[Milan/Bergamo,Paris]            0        -1836
# small[Edinburgh,Paris]            0      -2443.5
# small[Nice,Paris]            0        -1917
# small[Cologne/Bonn,Paris]            0      -1147.5
# small[Saint Petersburg,Paris]            0        -6066
# small[Stuttgart,Paris]            0      -1399.5
# small[Lyon,Paris]            0      -1093.5
# small[Trondheim,Paris]            0      -4738.5
# small[London,Frankfurt]            0      -1786.5
# small[Madrid,Frankfurt]            0      -4045.5
# small[Paris,Frankfurt]            0      -1336.5
# small[Amsterdam,Frankfurt]            0        -1017
# small[Istanbul,Frankfurt]            0      -5224.5
# small[Palma de Mallorca,Frankfurt]            0      -3532.5
# small[Rome,Frankfurt]            0        -2682
# small[Moscow,Frankfurt]            0      -5665.5
# small[Lisbon,Frankfurt]            0        -5292
# small[Zurich,Frankfurt]            0       -850.5
# small[Milan,Frankfurt]            0      -1444.5
# small[Copenhagen,Frankfurt]            0        -1881
# small[Manchester,Frankfurt]            0        -2349
# small[Malaga,Frankfurt]            0      -5089.5
# small[Vienna,Frankfurt]            0        -1674
# small[Oslo,Frankfurt]            0        -3069
# small[Dusseldorf,Frankfurt]            0       -508.5
# small[Dublin,Frankfurt]            0      -3046.5
# small[Athens,Frankfurt]            0      -5035.5
# small[Porto,Frankfurt]            0      -4666.5
# small[Helsinki,Frankfurt]            0      -4243.5
# small[Stockholm,Frankfurt]            0        -3321
# small[Berlin,Frankfurt]            0      -1183.5
# small[Prague,Frankfurt]            0        -1152
# small[Hamburg,Frankfurt]            0        -1098
# small[Warsaw,Frankfurt]            0        -2493
# small[Budapest,Frankfurt]            0      -2272.5
# small[Geneva,Frankfurt]            0        -1323
# small[Kyiv,Frankfurt]            0        -4338
# small[Bucharest,Frankfurt]            0      -4072.5
# small[Birmingham,Frankfurt]            0        -2187
# small[Milan/Bergamo,Frankfurt]            0        -1395
# small[Edinburgh,Frankfurt]            0      -2866.5
# small[Nice,Frankfurt]            0      -2011.5
# small[Cologne/Bonn,Frankfurt]            0       -382.5
# small[Saint Petersburg,Frankfurt]            0      -4891.5
# small[Stuttgart,Frankfurt]            0         -423
# small[Lyon,Frankfurt]            0      -1570.5
# small[Trondheim,Frankfurt]            0      -4153.5
# small[London,Amsterdam]            0         -999
# small[Madrid,Amsterdam]            0        -4140
# small[Paris,Amsterdam]            0      -1201.5
# small[Frankfurt,Amsterdam]            0        -1017
# small[Istanbul,Amsterdam]            0        -6192
# small[Palma de Mallorca,Amsterdam]            0        -4005
# small[Rome,Amsterdam]            0        -3627
# small[Moscow,Amsterdam]            0        -6021
# small[Lisbon,Amsterdam]            0      -5215.5
# small[Zurich,Amsterdam]            0      -1714.5
# small[Milan,Amsterdam]            0      -2317.5
# small[Copenhagen,Amsterdam]            0      -1741.5
# small[Manchester,Amsterdam]            0      -1381.5
# small[Malaga,Amsterdam]            0        -5274
# small[Vienna,Amsterdam]            0      -2623.5
# small[Oslo,Amsterdam]            0      -2551.5
# small[Dusseldorf,Amsterdam]            0       -508.5
# small[Dublin,Amsterdam]            0      -2119.5
# small[Athens,Amsterdam]            0      -6052.5
# small[Porto,Amsterdam]            0        -4509
# small[Helsinki,Amsterdam]            0      -4207.5
# small[Stockholm,Amsterdam]            0        -3150
# small[Berlin,Amsterdam]            0        -1611
# small[Prague,Amsterdam]            0        -1998
# small[Hamburg,Amsterdam]            0        -1026
# small[Warsaw,Amsterdam]            0      -3064.5
# small[Budapest,Amsterdam]            0      -3208.5
# small[Geneva,Amsterdam]            0        -1935
# small[Kyiv,Amsterdam]            0        -4995
# small[Bucharest,Amsterdam]            0      -5008.5
# small[Birmingham,Amsterdam]            0      -1291.5
# small[Milan/Bergamo,Amsterdam]            0      -2299.5
# small[Edinburgh,Amsterdam]            0        -1845
# small[Nice,Amsterdam]            0      -2740.5
# small[Cologne/Bonn,Amsterdam]            0       -634.5
# small[Saint Petersburg,Amsterdam]            0        -4959
# small[Stuttgart,Amsterdam]            0      -1399.5
# small[Lyon,Amsterdam]            0      -2056.5
# small[Trondheim,Amsterdam]            0        -3555
# small[London,Istanbul]            0        -7002
# small[Madrid,Istanbul]            0      -7672.5
# small[Paris,Istanbul]            0        -6318
# small[Frankfurt,Istanbul]            0      -5224.5
# small[Amsterdam,Istanbul]            0        -6192
# small[Palma de Mallorca,Istanbul]            0        -6246
# small[Rome,Istanbul]            0        -3852
# small[Moscow,Istanbul]            0      -4909.5
# small[Lisbon,Istanbul]            0        -9072
# small[Zurich,Istanbul]            0      -4954.5
# small[Milan,Istanbul]            0      -4684.5
# small[Copenhagen,Istanbul]            0      -5656.5
# small[Manchester,Istanbul]            0        -7569
# small[Malaga,Istanbul]            0      -8158.5
# small[Vienna,Istanbul]            0      -3568.5
# small[Oslo,Istanbul]            0        -6849
# small[Dusseldorf,Istanbul]            0        -5715
# small[Dublin,Istanbul]            0      -8275.5
# small[Athens,Istanbul]            0      -1570.5
# small[Porto,Istanbul]            0        -8757
# small[Helsinki,Istanbul]            0      -6007.5
# small[Stockholm,Istanbul]            0      -6079.5
# small[Berlin,Istanbul]            0      -4864.5
# small[Prague,Istanbul]            0        -4221
# small[Hamburg,Istanbul]            0      -5557.5
# small[Warsaw,Istanbul]            0      -3874.5
# small[Budapest,Istanbul]            0        -2988
# small[Geneva,Istanbul]            0        -5373
# small[Kyiv,Istanbul]            0        -2952
# small[Bucharest,Istanbul]            0      -1246.5
# small[Birmingham,Istanbul]            0        -7416
# small[Milan/Bergamo,Istanbul]            0        -4590
# small[Edinburgh,Istanbul]            0        -7992
# small[Nice,Istanbul]            0        -5049
# small[Cologne/Bonn,Istanbul]            0      -5602.5
# small[Saint Petersburg,Istanbul]            0      -5890.5
# small[Stuttgart,Istanbul]            0        -4968
# small[Lyon,Istanbul]            0      -5638.5
# small[Trondheim,Istanbul]            0        -7758
# small[London,Palma de Mallorca]            0      -3757.5
# small[Madrid,Palma de Mallorca]            0        -1539
# small[Paris,Palma de Mallorca]            0      -2884.5
# small[Frankfurt,Palma de Mallorca]            0      -3532.5
# small[Amsterdam,Palma de Mallorca]            0        -4005
# small[Istanbul,Palma de Mallorca]            0        -6246
# small[Rome,Palma de Mallorca]            0        -2430
# small[Moscow,Palma de Mallorca]            0      -8752.5
# small[Lisbon,Palma de Mallorca]            0      -2857.5
# small[Zurich,Palma de Mallorca]            0        -2763
# small[Milan,Palma de Mallorca]            0        -2367
# small[Copenhagen,Palma de Mallorca]            0      -5413.5
# small[Manchester,Palma de Mallorca]            0        -4446
# small[Malaga,Palma de Mallorca]            0        -1944
# small[Vienna,Palma de Mallorca]            0      -4072.5
# small[Oslo,Palma de Mallorca]            0      -6520.5
# small[Dusseldorf,Palma de Mallorca]            0      -3730.5
# small[Dublin,Palma de Mallorca]            0        -4680
# small[Athens,Palma de Mallorca]            0        -5130
# small[Porto,Palma de Mallorca]            0      -2713.5
# small[Helsinki,Palma de Mallorca]            0        -7731
# small[Stockholm,Palma de Mallorca]            0      -6853.5
# small[Berlin,Palma de Mallorca]            0        -4635
# small[Prague,Palma de Mallorca]            0      -4162.5
# small[Hamburg,Palma de Mallorca]            0      -4612.5
# small[Warsaw,Palma de Mallorca]            0      -5566.5
# small[Budapest,Palma de Mallorca]            0      -4432.5
# small[Geneva,Palma de Mallorca]            0        -2205
# small[Kyiv,Palma de Mallorca]            0      -6952.5
# small[Bucharest,Palma de Mallorca]            0        -5616
# small[Birmingham,Palma de Mallorca]            0      -4126.5
# small[Milan/Bergamo,Palma de Mallorca]            0        -2484
# small[Edinburgh,Palma de Mallorca]            0      -5233.5
# small[Nice,Palma de Mallorca]            0      -1669.5
# small[Cologne/Bonn,Palma de Mallorca]            0      -3640.5
# small[Saint Petersburg,Palma de Mallorca]            0      -8311.5
# small[Stuttgart,Palma de Mallorca]            0      -3208.5
# small[Lyon,Palma de Mallorca]            0      -1984.5
# small[Trondheim,Palma de Mallorca]            0        -7560
# small[London,Rome]            0        -4014
# small[Madrid,Rome]            0      -3820.5
# small[Paris,Rome]            0      -3091.5
# small[Frankfurt,Rome]            0        -2682
# small[Amsterdam,Rome]            0        -3627
# small[Istanbul,Rome]            0        -3852
# small[Palma de Mallorca,Rome]            0        -2430
# small[Moscow,Rome]            0      -6655.5
# small[Lisbon,Rome]            0      -5215.5
# small[Zurich,Rome]            0      -1912.5
# small[Milan,Rome]            0        -1332
# small[Copenhagen,Rome]            0      -4288.5
# small[Manchester,Rome]            0        -4725
# small[Malaga,Rome]            0      -4369.5
# small[Vienna,Rome]            0      -2137.5
# small[Oslo,Rome]            0      -5611.5
# small[Dusseldorf,Rome]            0      -3145.5
# small[Dublin,Rome]            0      -5278.5
# small[Athens,Rome]            0        -2943
# small[Porto,Rome]            0        -4914
# small[Helsinki,Rome]            0      -6160.5
# small[Stockholm,Rome]            0        -5526
# small[Berlin,Rome]            0      -3307.5
# small[Prague,Rome]            0      -2569.5
# small[Hamburg,Rome]            0      -3658.5
# small[Warsaw,Rome]            0        -3681
# small[Budapest,Rome]            0      -2263.5
# small[Geneva,Rome]            0      -1948.5
# small[Kyiv,Rome]            0      -4693.5
# small[Bucharest,Rome]            0      -3190.5
# small[Birmingham,Rome]            0      -4468.5
# small[Milan/Bergamo,Rome]            0      -1327.5
# small[Edinburgh,Rome]            0      -5395.5
# small[Nice,Rome]            0        -1314
# small[Cologne/Bonn,Rome]            0        -3015
# small[Saint Petersburg,Rome]            0        -6570
# small[Stuttgart,Rome]            0      -2254.5
# small[Lyon,Rome]            0      -2092.5
# small[Trondheim,Rome]            0      -6709.5
# small[London,Moscow]            0        -7011
# small[Madrid,Moscow]            0        -9639
# small[Paris,Moscow]            0      -6970.5
# small[Frankfurt,Moscow]            0      -5665.5
# small[Amsterdam,Moscow]            0        -6021
# small[Istanbul,Moscow]            0      -4909.5
# small[Palma de Mallorca,Moscow]            0      -8752.5
# small[Rome,Moscow]            0      -6655.5
# small[Lisbon,Moscow]            0       -10944
# small[Zurich,Moscow]            0        -6147
# small[Milan,Moscow]            0      -6403.5
# small[Copenhagen,Moscow]            0        -4374
# small[Manchester,Moscow]            0      -7132.5
# small[Malaga,Moscow]            0     -10579.5
# small[Vienna,Moscow]            0        -4680
# small[Oslo,Moscow]            0      -4612.5
# small[Dusseldorf,Moscow]            0        -5841
# small[Dublin,Moscow]            0        -7839
# small[Athens,Moscow]            0        -6237
# small[Porto,Moscow]            0     -10336.5
# small[Helsinki,Moscow]            0        -2502
# small[Stockholm,Moscow]            0      -3442.5
# small[Berlin,Moscow]            0      -4513.5
# small[Prague,Moscow]            0      -4675.5
# small[Hamburg,Moscow]            0        -4995
# small[Warsaw,Moscow]            0      -3226.5
# small[Budapest,Moscow]            0      -4396.5
# small[Geneva,Moscow]            0        -6777
# small[Kyiv,Moscow]            0        -2115
# small[Bucharest,Moscow]            0      -4189.5
# small[Birmingham,Moscow]            0      -7195.5
# small[Milan/Bergamo,Moscow]            0        -6282
# small[Edinburgh,Moscow]            0        -7038
# small[Nice,Moscow]            0      -7087.5
# small[Cologne/Bonn,Moscow]            0      -5827.5
# small[Saint Petersburg,Moscow]            0      -1777.5
# small[Stuttgart,Moscow]            0      -5791.5
# small[Lyon,Moscow]            0      -7087.5
# small[Trondheim,Moscow]            0      -4864.5
# small[London,Lisbon]            0      -4432.5
# small[Madrid,Lisbon]            0      -1408.5
# small[Paris,Lisbon]            0        -4068
# small[Frankfurt,Lisbon]            0        -5292
# small[Amsterdam,Lisbon]            0      -5215.5
# small[Istanbul,Lisbon]            0        -9072
# small[Palma de Mallorca,Lisbon]            0      -2857.5
# small[Rome,Lisbon]            0      -5215.5
# small[Moscow,Lisbon]            0       -10944
# small[Zurich,Lisbon]            0        -4824
# small[Milan,Lisbon]            0        -4716
# small[Copenhagen,Lisbon]            0        -6939
# small[Manchester,Lisbon]            0      -4819.5
# small[Malaga,Lisbon]            0        -1314
# small[Vienna,Lisbon]            0      -6439.5
# small[Oslo,Lisbon]            0      -7663.5
# small[Dusseldorf,Lisbon]            0      -5215.5
# small[Dublin,Lisbon]            0        -4590
# small[Athens,Lisbon]            0        -7992
# small[Porto,Lisbon]            0         -765
# small[Helsinki,Lisbon]            0        -9414
# small[Stockholm,Lisbon]            0        -8370
# small[Berlin,Lisbon]            0        -6471
# small[Prague,Lisbon]            0        -6282
# small[Hamburg,Lisbon]            0      -6151.5
# small[Warsaw,Lisbon]            0      -7726.5
# small[Budapest,Lisbon]            0        -6921
# small[Geneva,Lisbon]            0        -4203
# small[Kyiv,Lisbon]            0      -9391.5
# small[Bucharest,Lisbon]            0      -8338.5
# small[Birmingham,Lisbon]            0        -4554
# small[Milan/Bergamo,Lisbon]            0      -4837.5
# small[Edinburgh,Lisbon]            0        -5499
# small[Nice,Lisbon]            0      -4135.5
# small[Cologne/Bonn,Lisbon]            0        -5193
# small[Saint Petersburg,Lisbon]            0       -10134
# small[Stuttgart,Lisbon]            0      -5152.5
# small[Lyon,Lisbon]            0        -3888
# small[Trondheim,Lisbon]            0      -8509.5
# small[London,Zurich]            0      -2173.5
# small[Madrid,Zurich]            0      -3487.5
# small[Paris,Zurich]            0        -1368
# small[Frankfurt,Zurich]            0       -850.5
# small[Amsterdam,Zurich]            0      -1714.5
# small[Istanbul,Zurich]            0      -4954.5
# small[Palma de Mallorca,Zurich]            0        -2763
# small[Rome,Zurich]            0      -1912.5
# small[Moscow,Zurich]            0        -6147
# small[Lisbon,Zurich]            0        -4824
# small[Milan,Zurich]            0       -607.5
# small[Copenhagen,Zurich]            0        -2700
# small[Manchester,Zurich]            0      -2857.5
# small[Malaga,Zurich]            0      -4450.5
# small[Vienna,Zurich]            0        -1656
# small[Oslo,Zurich]            0      -3919.5
# small[Dusseldorf,Zurich]            0      -1246.5
# small[Dublin,Zurich]            0      -3469.5
# small[Athens,Zurich]            0        -4527
# small[Porto,Zurich]            0        -4275
# small[Helsinki,Zurich]            0        -4968
# small[Stockholm,Zurich]            0      -4108.5
# small[Berlin,Zurich]            0      -1867.5
# small[Prague,Zurich]            0      -1471.5
# small[Hamburg,Zurich]            0      -1939.5
# small[Warsaw,Zurich]            0      -2920.5
# small[Budapest,Zurich]            0      -2209.5
# small[Geneva,Zurich]            0       -625.5
# small[Kyiv,Zurich]            0      -4585.5
# small[Bucharest,Zurich]            0        -3906
# small[Birmingham,Zurich]            0      -2623.5
# small[Milan/Bergamo,Zurich]            0       -580.5
# small[Edinburgh,Zurich]            0        -3492
# small[Nice,Zurich]            0      -1174.5
# small[Cologne/Bonn,Zurich]            0      -1120.5
# small[Saint Petersburg,Zurich]            0        -5562
# small[Stuttgart,Zurich]            0       -454.5
# small[Lyon,Zurich]            0         -936
# small[Trondheim,Zurich]            0        -5004
# small[London,Milan]            0        -2682
# small[Madrid,Milan]            0      -3325.5
# small[Paris,Milan]            0        -1791
# small[Frankfurt,Milan]            0      -1444.5
# small[Amsterdam,Milan]            0      -2317.5
# small[Istanbul,Milan]            0      -4684.5
# small[Palma de Mallorca,Milan]            0        -2367
# small[Rome,Milan]            0        -1332
# small[Moscow,Milan]            0      -6403.5
# small[Lisbon,Milan]            0        -4716
# small[Zurich,Milan]            0       -607.5
# small[Copenhagen,Milan]            0      -3244.5
# small[Manchester,Milan]            0        -3393
# small[Malaga,Milan]            0        -4185
# small[Vienna,Milan]            0      -1750.5
# small[Oslo,Milan]            0        -4500
# small[Dusseldorf,Milan]            0      -1858.5
# small[Dublin,Milan]            0      -3964.5
# small[Athens,Milan]            0      -4090.5
# small[Porto,Milan]            0      -4243.5
# small[Helsinki,Milan]            0      -5422.5
# small[Stockholm,Milan]            0      -4621.5
# small[Berlin,Milan]            0      -2353.5
# small[Prague,Milan]            0        -1800
# small[Hamburg,Milan]            0      -2515.5
# small[Warsaw,Milan]            0      -3199.5
# small[Budapest,Milan]            0        -2205
# small[Geneva,Milan]            0       -697.5
# small[Kyiv,Milan]            0      -4693.5
# small[Bucharest,Milan]            0        -3735
# small[Birmingham,Milan]            0        -3141
# small[Milan/Bergamo,Milan]            0       -121.5
# small[Edinburgh,Milan]            0        -4059
# small[Nice,Milan]            0         -693
# small[Cologne/Bonn,Milan]            0        -1728
# small[Saint Petersburg,Milan]            0      -5962.5
# small[Stuttgart,Milan]            0        -1026
# small[Lyon,Milan]            0         -954
# small[Trondheim,Milan]            0      -5593.5
# small[London,Copenhagen]            0      -2677.5
# small[Madrid,Copenhagen]            0      -5800.5
# small[Paris,Copenhagen]            0      -2875.5
# small[Frankfurt,Copenhagen]            0        -1881
# small[Amsterdam,Copenhagen]            0      -1741.5
# small[Istanbul,Copenhagen]            0      -5656.5
# small[Palma de Mallorca,Copenhagen]            0      -5413.5
# small[Rome,Copenhagen]            0      -4288.5
# small[Moscow,Copenhagen]            0        -4374
# small[Lisbon,Copenhagen]            0        -6939
# small[Zurich,Copenhagen]            0        -2700
# small[Milan,Copenhagen]            0      -3244.5
# small[Manchester,Copenhagen]            0      -2758.5
# small[Malaga,Copenhagen]            0      -6898.5
# small[Vienna,Copenhagen]            0      -2434.5
# small[Oslo,Copenhagen]            0        -1350
# small[Dusseldorf,Copenhagen]            0        -1755
# small[Dublin,Copenhagen]            0        -3474
# small[Athens,Copenhagen]            0        -5976
# small[Porto,Copenhagen]            0        -6246
# small[Helsinki,Copenhagen]            0      -2470.5
# small[Stockholm,Copenhagen]            0        -1458
# small[Berlin,Copenhagen]            0       -994.5
# small[Prague,Copenhagen]            0        -1782
# small[Hamburg,Copenhagen]            0         -810
# small[Warsaw,Copenhagen]            0        -1881
# small[Budapest,Copenhagen]            0        -2835
# small[Geneva,Copenhagen]            0        -3204
# small[Kyiv,Copenhagen]            0      -3721.5
# small[Bucharest,Copenhagen]            0      -4405.5
# small[Birmingham,Copenhagen]            0      -2821.5
# small[Milan/Bergamo,Copenhagen]            0      -3163.5
# small[Edinburgh,Copenhagen]            0        -2754
# small[Nice,Copenhagen]            0      -3874.5
# small[Cologne/Bonn,Copenhagen]            0      -1804.5
# small[Saint Petersburg,Copenhagen]            0      -3217.5
# small[Stuttgart,Copenhagen]            0        -2241
# small[Lyon,Copenhagen]            0        -3438
# small[Trondheim,Copenhagen]            0      -2434.5
# small[London,Manchester]            0       -733.5
# small[Madrid,Manchester]            0        -4068
# small[Paris,Manchester]            0        -1692
# small[Frankfurt,Manchester]            0        -2349
# small[Amsterdam,Manchester]            0      -1381.5
# small[Istanbul,Manchester]            0        -7569
# small[Palma de Mallorca,Manchester]            0        -4446
# small[Rome,Manchester]            0        -4725
# small[Moscow,Manchester]            0      -7132.5
# small[Lisbon,Manchester]            0      -4819.5
# small[Zurich,Manchester]            0      -2857.5
# small[Milan,Manchester]            0        -3393
# small[Copenhagen,Manchester]            0      -2758.5
# small[Malaga,Manchester]            0      -5224.5
# small[Vienna,Manchester]            0      -4000.5
# small[Oslo,Manchester]            0      -2983.5
# small[Dusseldorf,Manchester]            0        -1854
# small[Dublin,Manchester]            0         -747
# small[Athens,Manchester]            0      -7348.5
# small[Porto,Manchester]            0      -4054.5
# small[Helsinki,Manchester]            0        -5040
# small[Stockholm,Manchester]            0      -3928.5
# small[Berlin,Manchester]            0        -2943
# small[Prague,Manchester]            0      -3379.5
# small[Hamburg,Manchester]            0        -2268
# small[Warsaw,Manchester]            0        -4374
# small[Budapest,Manchester]            0        -4590
# small[Geneva,Manchester]            0        -2817
# small[Kyiv,Manchester]            0        -6309
# small[Bucharest,Manchester]            0        -6390
# small[Birmingham,Manchester]            0         -315
# small[Milan/Bergamo,Manchester]            0        -3411
# small[Edinburgh,Manchester]            0       -787.5
# small[Nice,Manchester]            0        -3609
# small[Cologne/Bonn,Manchester]            0      -1966.5
# small[Saint Petersburg,Manchester]            0      -5854.5
# small[Stuttgart,Manchester]            0        -2664
# small[Lyon,Manchester]            0        -2790
# small[Trondheim,Manchester]            0        -3708
# small[London,Malaga]            0        -4689
# small[Madrid,Malaga]            0      -1156.5
# small[Paris,Malaga]            0        -4068
# small[Frankfurt,Malaga]            0      -5089.5
# small[Amsterdam,Malaga]            0        -5274
# small[Istanbul,Malaga]            0      -8158.5
# small[Palma de Mallorca,Malaga]            0        -1944
# small[Rome,Malaga]            0      -4369.5
# small[Moscow,Malaga]            0     -10579.5
# small[Lisbon,Malaga]            0        -1314
# small[Zurich,Malaga]            0      -4450.5
# small[Milan,Malaga]            0        -4185
# small[Copenhagen,Malaga]            0      -6898.5
# small[Manchester,Malaga]            0      -5224.5
# small[Vienna,Malaga]            0        -5931
# small[Oslo,Malaga]            0        -7821
# small[Dusseldorf,Malaga]            0      -5143.5
# small[Dublin,Malaga]            0      -5179.5
# small[Athens,Malaga]            0        -6957
# small[Porto,Malaga]            0      -1705.5
# small[Helsinki,Malaga]            0      -9328.5
# small[Stockholm,Malaga]            0      -8356.5
# small[Berlin,Malaga]            0        -6264
# small[Prague,Malaga]            0      -5917.5
# small[Hamburg,Malaga]            0      -6088.5
# small[Warsaw,Malaga]            0        -7362
# small[Budapest,Malaga]            0        -6336
# small[Geneva,Malaga]            0        -3834
# small[Kyiv,Malaga]            0      -8851.5
# small[Bucharest,Malaga]            0        -7560
# small[Birmingham,Malaga]            0      -4927.5
# small[Milan/Bergamo,Malaga]            0      -4306.5
# small[Edinburgh,Malaga]            0      -5980.5
# small[Nice,Malaga]            0        -3519
# small[Cologne/Bonn,Malaga]            0      -5089.5
# small[Saint Petersburg,Malaga]            0        -9981
# small[Stuttgart,Malaga]            0        -4851
# small[Lyon,Malaga]            0      -3541.5
# small[Trondheim,Malaga]            0        -8766
# small[London,Vienna]            0      -3460.5
# small[Madrid,Vienna]            0        -5067
# small[Paris,Vienna]            0        -2898
# small[Frankfurt,Vienna]            0        -1674
# small[Amsterdam,Vienna]            0      -2623.5
# small[Istanbul,Vienna]            0      -3568.5
# small[Palma de Mallorca,Vienna]            0      -4072.5
# small[Rome,Vienna]            0      -2137.5
# small[Moscow,Vienna]            0        -4680
# small[Lisbon,Vienna]            0      -6439.5
# small[Zurich,Vienna]            0        -1656
# small[Milan,Vienna]            0      -1750.5
# small[Copenhagen,Vienna]            0      -2434.5
# small[Manchester,Vienna]            0      -4000.5
# small[Malaga,Vienna]            0        -5931
# small[Oslo,Vienna]            0        -3780
# small[Dusseldorf,Vienna]            0      -2146.5
# small[Dublin,Vienna]            0        -4716
# small[Athens,Vienna]            0        -3582
# small[Porto,Vienna]            0        -5922
# small[Helsinki,Vienna]            0      -4027.5
# small[Stockholm,Vienna]            0      -3469.5
# small[Berlin,Vienna]            0      -1462.5
# small[Prague,Vienna]            0         -693
# small[Hamburg,Vienna]            0        -2079
# small[Warsaw,Vienna]            0      -1552.5
# small[Budapest,Vienna]            0       -598.5
# small[Geneva,Vienna]            0        -2250
# small[Kyiv,Vienna]            0        -2952
# small[Bucharest,Vienna]            0        -2394
# small[Birmingham,Vienna]            0      -3856.5
# small[Milan/Bergamo,Vienna]            0      -1624.5
# small[Edinburgh,Vienna]            0      -4432.5
# small[Nice,Vienna]            0      -2416.5
# small[Cologne/Bonn,Vienna]            0      -2038.5
# small[Saint Petersburg,Vienna]            0      -4432.5
# small[Stuttgart,Vienna]            0        -1494
# small[Lyon,Vienna]            0        -2565
# small[Trondheim,Vienna]            0      -4846.5
# small[London,Oslo]            0        -3231
# small[Madrid,Oslo]            0        -6678
# small[Paris,Oslo]            0        -3753
# small[Frankfurt,Oslo]            0        -3069
# small[Amsterdam,Oslo]            0      -2551.5
# small[Istanbul,Oslo]            0        -6849
# small[Palma de Mallorca,Oslo]            0      -6520.5
# small[Rome,Oslo]            0      -5611.5
# small[Moscow,Oslo]            0      -4612.5
# small[Lisbon,Oslo]            0      -7663.5
# small[Zurich,Oslo]            0      -3919.5
# small[Milan,Oslo]            0        -4500
# small[Copenhagen,Oslo]            0        -1350
# small[Manchester,Oslo]            0      -2983.5
# small[Malaga,Oslo]            0        -7821
# small[Vienna,Oslo]            0        -3780
# small[Dusseldorf,Oslo]            0        -2790
# small[Dublin,Oslo]            0      -3541.5
# small[Athens,Oslo]            0      -7285.5
# small[Porto,Oslo]            0      -6925.5
# small[Helsinki,Oslo]            0      -2209.5
# small[Stockholm,Oslo]            0        -1170
# small[Berlin,Oslo]            0      -2344.5
# small[Prague,Oslo]            0      -3136.5
# small[Hamburg,Oslo]            0      -1984.5
# small[Warsaw,Oslo]            0      -2974.5
# small[Budapest,Oslo]            0        -4149
# small[Geneva,Oslo]            0        -4347
# small[Kyiv,Oslo]            0      -4558.5
# small[Bucharest,Oslo]            0        -5607
# small[Birmingham,Oslo]            0        -3177
# small[Milan/Bergamo,Oslo]            0      -4432.5
# small[Edinburgh,Oslo]            0      -2605.5
# small[Nice,Oslo]            0        -5085
# small[Cologne/Bonn,Oslo]            0      -2884.5
# small[Saint Petersburg,Oslo]            0      -3046.5
# small[Stuttgart,Oslo]            0        -3474
# small[Lyon,Oslo]            0        -4536
# small[Trondheim,Oslo]            0      -1093.5
# small[London,Dusseldorf]            0      -1345.5
# small[Madrid,Dusseldorf]            0      -4045.5
# small[Paris,Dusseldorf]            0        -1152
# small[Frankfurt,Dusseldorf]            0       -508.5
# small[Amsterdam,Dusseldorf]            0       -508.5
# small[Istanbul,Dusseldorf]            0        -5715
# small[Palma de Mallorca,Dusseldorf]            0      -3730.5
# small[Rome,Dusseldorf]            0      -3145.5
# small[Moscow,Dusseldorf]            0        -5841
# small[Lisbon,Dusseldorf]            0      -5215.5
# small[Zurich,Dusseldorf]            0      -1246.5
# small[Milan,Dusseldorf]            0      -1858.5
# small[Copenhagen,Dusseldorf]            0        -1755
# small[Manchester,Dusseldorf]            0        -1854
# small[Malaga,Dusseldorf]            0      -5143.5
# small[Vienna,Dusseldorf]            0      -2146.5
# small[Oslo,Dusseldorf]            0        -2790
# small[Dublin,Dusseldorf]            0      -2569.5
# small[Athens,Dusseldorf]            0      -5548.5
# small[Porto,Dusseldorf]            0        -4545
# small[Helsinki,Dusseldorf]            0      -4207.5
# small[Stockholm,Dusseldorf]            0        -3213
# small[Berlin,Dusseldorf]            0        -1332
# small[Prague,Dusseldorf]            0        -1557
# small[Hamburg,Dusseldorf]            0         -945
# small[Warsaw,Dusseldorf]            0      -2758.5
# small[Budapest,Dusseldorf]            0      -2740.5
# small[Geneva,Dusseldorf]            0        -1566
# small[Kyiv,Dusseldorf]            0        -4662
# small[Bucharest,Dusseldorf]            0      -4540.5
# small[Birmingham,Dusseldorf]            0      -1714.5
# small[Milan/Bergamo,Dusseldorf]            0        -1827
# small[Edinburgh,Dusseldorf]            0      -2353.5
# small[Nice,Dusseldorf]            0        -2340
# small[Cologne/Bonn,Dusseldorf]            0       -130.5
# small[Saint Petersburg,Dusseldorf]            0        -4914
# small[Stuttgart,Dusseldorf]            0         -900
# small[Lyon,Dusseldorf]            0        -1746
# small[Trondheim,Dusseldorf]            0      -3847.5
# small[London,Dublin]            0        -1296
# small[Madrid,Dublin]            0      -4054.5
# small[Paris,Dublin]            0        -2187
# small[Frankfurt,Dublin]            0      -3046.5
# small[Amsterdam,Dublin]            0      -2119.5
# small[Istanbul,Dublin]            0      -8275.5
# small[Palma de Mallorca,Dublin]            0        -4680
# small[Rome,Dublin]            0      -5278.5
# small[Moscow,Dublin]            0        -7839
# small[Lisbon,Dublin]            0        -4590
# small[Zurich,Dublin]            0      -3469.5
# small[Milan,Dublin]            0      -3964.5
# small[Copenhagen,Dublin]            0        -3474
# small[Manchester,Dublin]            0         -747
# small[Malaga,Dublin]            0      -5179.5
# small[Vienna,Dublin]            0        -4716
# small[Oslo,Dublin]            0      -3541.5
# small[Dusseldorf,Dublin]            0      -2569.5
# small[Athens,Dublin]            0        -7992
# small[Porto,Dublin]            0      -3820.5
# small[Helsinki,Dublin]            0      -5674.5
# small[Stockholm,Dublin]            0        -4563
# small[Berlin,Dublin]            0        -3690
# small[Prague,Dublin]            0        -4113
# small[Hamburg,Dublin]            0      -3010.5
# small[Warsaw,Dublin]            0        -5121
# small[Budapest,Dublin]            0        -5310
# small[Geneva,Dublin]            0      -3334.5
# small[Kyiv,Dublin]            0        -7056
# small[Bucharest,Dublin]            0        -7110
# small[Birmingham,Dublin]            0       -859.5
# small[Milan/Bergamo,Dublin]            0      -4000.5
# small[Edinburgh,Dublin]            0         -981
# small[Nice,Dublin]            0        -4086
# small[Cologne/Bonn,Dublin]            0        -2673
# small[Saint Petersburg,Dublin]            0      -6502.5
# small[Stuttgart,Dublin]            0      -3334.5
# small[Lyon,Dublin]            0        -3249
# small[Trondheim,Dublin]            0        -4131
# small[London,Athens]            0        -6696
# small[Madrid,Athens]            0      -6637.5
# small[Paris,Athens]            0        -5868
# small[Frankfurt,Athens]            0      -5035.5
# small[Amsterdam,Athens]            0      -6052.5
# small[Istanbul,Athens]            0      -1570.5
# small[Palma de Mallorca,Athens]            0        -5130
# small[Rome,Athens]            0        -2943
# small[Moscow,Athens]            0        -6237
# small[Lisbon,Athens]            0        -7992
# small[Zurich,Athens]            0        -4527
# small[Milan,Athens]            0      -4090.5
# small[Copenhagen,Athens]            0        -5976
# small[Manchester,Athens]            0      -7348.5
# small[Malaga,Athens]            0        -6957
# small[Vienna,Athens]            0        -3582
# small[Oslo,Athens]            0      -7285.5
# small[Dusseldorf,Athens]            0      -5548.5
# small[Dublin,Athens]            0        -7992
# small[Porto,Athens]            0        -7785
# small[Helsinki,Athens]            0      -6898.5
# small[Stockholm,Athens]            0      -6727.5
# small[Berlin,Athens]            0        -5040
# small[Prague,Athens]            0      -4279.5
# small[Hamburg,Athens]            0        -5661
# small[Warsaw,Athens]            0        -4464
# small[Budapest,Athens]            0        -3141
# small[Geneva,Athens]            0      -4783.5
# small[Kyiv,Athens]            0      -4153.5
# small[Bucharest,Athens]            0        -2079
# small[Birmingham,Athens]            0      -7141.5
# small[Milan/Bergamo,Athens]            0        -4032
# small[Edinburgh,Athens]            0        -7902
# small[Nice,Athens]            0        -4257
# small[Cologne/Bonn,Athens]            0        -5418
# small[Saint Petersburg,Athens]            0        -6948
# small[Stuttgart,Athens]            0      -4684.5
# small[Lyon,Athens]            0        -4986
# small[Trondheim,Athens]            0        -8298
# small[London,Porto]            0      -3694.5
# small[Madrid,Porto]            0        -1179
# small[Paris,Porto]            0        -3393
# small[Frankfurt,Porto]            0      -4666.5
# small[Amsterdam,Porto]            0        -4509
# small[Istanbul,Porto]            0        -8757
# small[Palma de Mallorca,Porto]            0      -2713.5
# small[Rome,Porto]            0        -4914
# small[Moscow,Porto]            0     -10336.5
# small[Lisbon,Porto]            0         -765
# small[Zurich,Porto]            0        -4275
# small[Milan,Porto]            0      -4243.5
# small[Copenhagen,Porto]            0        -6246
# small[Manchester,Porto]            0      -4054.5
# small[Malaga,Porto]            0      -1705.5
# small[Vienna,Porto]            0        -5922
# small[Oslo,Porto]            0      -6925.5
# small[Dusseldorf,Porto]            0        -4545
# small[Dublin,Porto]            0      -3820.5
# small[Athens,Porto]            0        -7785
# small[Helsinki,Porto]            0      -8716.5
# small[Stockholm,Porto]            0        -7659
# small[Berlin,Porto]            0        -5832
# small[Prague,Porto]            0        -5706
# small[Hamburg,Porto]            0        -5472
# small[Warsaw,Porto]            0        -7137
# small[Budapest,Porto]            0        -6435
# small[Geneva,Porto]            0      -3667.5
# small[Kyiv,Porto]            0        -8865
# small[Bucharest,Porto]            0      -7942.5
# small[Birmingham,Porto]            0      -3793.5
# small[Milan/Bergamo,Porto]            0      -4360.5
# small[Edinburgh,Porto]            0      -4729.5
# small[Nice,Porto]            0      -3730.5
# small[Cologne/Bonn,Porto]            0        -4536
# small[Saint Petersburg,Porto]            0      -9454.5
# small[Stuttgart,Porto]            0      -4567.5
# small[Lyon,Porto]            0      -3352.5
# small[Trondheim,Porto]            0      -7753.5
# small[London,Helsinki]            0        -5103
# small[Madrid,Helsinki]            0        -8253
# small[Paris,Helsinki]            0        -5346
# small[Frankfurt,Helsinki]            0      -4243.5
# small[Amsterdam,Helsinki]            0      -4207.5
# small[Istanbul,Helsinki]            0      -6007.5
# small[Palma de Mallorca,Helsinki]            0        -7731
# small[Rome,Helsinki]            0      -6160.5
# small[Moscow,Helsinki]            0        -2502
# small[Lisbon,Helsinki]            0        -9414
# small[Zurich,Helsinki]            0        -4968
# small[Milan,Helsinki]            0      -5422.5
# small[Copenhagen,Helsinki]            0      -2470.5
# small[Manchester,Helsinki]            0        -5040
# small[Malaga,Helsinki]            0      -9328.5
# small[Vienna,Helsinki]            0      -4027.5
# small[Oslo,Helsinki]            0      -2209.5
# small[Dusseldorf,Helsinki]            0      -4207.5
# small[Dublin,Helsinki]            0      -5674.5
# small[Athens,Helsinki]            0      -6898.5
# small[Porto,Helsinki]            0      -8716.5
# small[Stockholm,Helsinki]            0        -1107
# small[Berlin,Helsinki]            0        -3096
# small[Prague,Helsinki]            0      -3649.5
# small[Hamburg,Helsinki]            0      -3262.5
# small[Warsaw,Helsinki]            0      -2560.5
# small[Budapest,Helsinki]            0      -4081.5
# small[Geneva,Helsinki]            0        -5544
# small[Kyiv,Helsinki]            0        -3177
# small[Bucharest,Helsinki]            0        -4896
# small[Birmingham,Helsinki]            0      -5170.5
# small[Milan/Bergamo,Helsinki]            0      -5314.5
# small[Edinburgh,Helsinki]            0      -4783.5
# small[Nice,Helsinki]            0        -6102
# small[Cologne/Bonn,Helsinki]            0        -4248
# small[Saint Petersburg,Helsinki]            0         -837
# small[Stuttgart,Helsinki]            0        -4527
# small[Lyon,Helsinki]            0        -5814
# small[Trondheim,Helsinki]            0        -2367
# small[London,Stockholm]            0        -4014
# small[Madrid,Stockholm]            0      -7258.5
# small[Paris,Stockholm]            0        -4320
# small[Frankfurt,Stockholm]            0        -3321
# small[Amsterdam,Stockholm]            0        -3150
# small[Istanbul,Stockholm]            0      -6079.5
# small[Palma de Mallorca,Stockholm]            0      -6853.5
# small[Rome,Stockholm]            0        -5526
# small[Moscow,Stockholm]            0      -3442.5
# small[Lisbon,Stockholm]            0        -8370
# small[Zurich,Stockholm]            0      -4108.5
# small[Milan,Stockholm]            0      -4621.5
# small[Copenhagen,Stockholm]            0        -1458
# small[Manchester,Stockholm]            0      -3928.5
# small[Malaga,Stockholm]            0      -8356.5
# small[Vienna,Stockholm]            0      -3469.5
# small[Oslo,Stockholm]            0        -1170
# small[Dusseldorf,Stockholm]            0        -3213
# small[Dublin,Stockholm]            0        -4563
# small[Athens,Stockholm]            0      -6727.5
# small[Porto,Stockholm]            0        -7659
# small[Helsinki,Stockholm]            0        -1107
# small[Berlin,Stockholm]            0        -2268
# small[Prague,Stockholm]            0        -2952
# small[Hamburg,Stockholm]            0        -2268
# small[Warsaw,Stockholm]            0      -2263.5
# small[Budapest,Stockholm]            0        -3681
# small[Geneva,Stockholm]            0        -4644
# small[Kyiv,Stockholm]            0        -3537
# small[Bucharest,Stockholm]            0      -4873.5
# small[Birmingham,Stockholm]            0        -4068
# small[Milan/Bergamo,Stockholm]            0        -4527
# small[Edinburgh,Stockholm]            0        -3681
# small[Nice,Stockholm]            0        -5274
# small[Cologne/Bonn,Stockholm]            0        -3267
# small[Saint Petersburg,Stockholm]            0        -1935
# small[Stuttgart,Stockholm]            0        -3654
# small[Lyon,Stockholm]            0      -4891.5
# small[Trondheim,Stockholm]            0      -1714.5
# small[London,Berlin]            0      -2605.5
# small[Madrid,Berlin]            0        -5229
# small[Paris,Berlin]            0      -2452.5
# small[Frankfurt,Berlin]            0      -1183.5
# small[Amsterdam,Berlin]            0        -1611
# small[Istanbul,Berlin]            0      -4864.5
# small[Palma de Mallorca,Berlin]            0        -4635
# small[Rome,Berlin]            0      -3307.5
# small[Moscow,Berlin]            0      -4513.5
# small[Lisbon,Berlin]            0        -6471
# small[Zurich,Berlin]            0      -1867.5
# small[Milan,Berlin]            0      -2353.5
# small[Copenhagen,Berlin]            0       -994.5
# small[Manchester,Berlin]            0        -2943
# small[Malaga,Berlin]            0        -6264
# small[Vienna,Berlin]            0      -1462.5
# small[Oslo,Berlin]            0      -2344.5
# small[Dusseldorf,Berlin]            0        -1332
# small[Dublin,Berlin]            0        -3690
# small[Athens,Berlin]            0        -5040
# small[Porto,Berlin]            0        -5832
# small[Helsinki,Berlin]            0        -3096
# small[Stockholm,Berlin]            0        -2268
# small[Prague,Berlin]            0       -787.5
# small[Hamburg,Berlin]            0         -711
# small[Warsaw,Berlin]            0        -1449
# small[Budapest,Berlin]            0        -1926
# small[Geneva,Berlin]            0        -2448
# small[Kyiv,Berlin]            0      -3379.5
# small[Bucharest,Berlin]            0      -3622.5
# small[Birmingham,Berlin]            0        -2898
# small[Milan/Bergamo,Berlin]            0      -2254.5
# small[Edinburgh,Berlin]            0        -3195
# small[Nice,Berlin]            0      -3019.5
# small[Cologne/Bonn,Berlin]            0      -1309.5
# small[Saint Petersburg,Berlin]            0        -3717
# small[Stuttgart,Berlin]            0      -1426.5
# small[Lyon,Berlin]            0        -2727
# small[Trondheim,Berlin]            0      -3433.5
# small[London,Prague]            0      -2902.5
# small[Madrid,Prague]            0      -4963.5
# small[Paris,Prague]            0        -2475
# small[Frankfurt,Prague]            0        -1152
# small[Amsterdam,Prague]            0        -1998
# small[Istanbul,Prague]            0        -4221
# ...
# small[Nice,Prague,Moscow]            0      -7168.5
# small[Cologne/Bonn,Prague,Moscow]            0        -6147
# small[Porto,Prague,Moscow]            0     -10381.5
# small[Edinburgh,Prague,Moscow]            0        -8442
# small[Alicante,Prague,Moscow]            0        -9594
# small[Lyon,Prague,Moscow]            0        -7083
# small[Birmingham,Prague,Moscow]            0      -7942.5
# small[Amsterdam,Prague,Rome]            0      -4567.5
# small[Copenhagen,Prague,Rome]            0      -4351.5
# small[Moscow,Prague,Rome]            0        -7245
# small[Dublin,Prague,Rome]            0      -6682.5
# small[Berlin,Prague,Rome]            0        -3357
# small[Oslo,Prague,Rome]            0        -5706
# small[Warsaw,Prague,Rome]            0      -4018.5
# small[Helsinki,Prague,Rome]            0        -6219
# small[Hamburg,Prague,Rome]            0        -3951
# small[Manchester,Prague,Rome]            0        -5949
# small[Stockholm,Prague,Rome]            0      -5521.5
# small[Saint Petersburg,Prague,Rome]            0        -6732
# small[Kyiv,Prague,Rome]            0        -5769
# small[Edinburgh,Prague,Rome]            0        -6336
# small[Trondheim,Prague,Rome]            0        -6786
# small[Istanbul,Prague,Zurich]            0      -5692.5
# small[Copenhagen,Prague,Zurich]            0      -3253.5
# small[Moscow,Prague,Zurich]            0        -6147
# small[Berlin,Prague,Zurich]            0        -2259
# small[Oslo,Prague,Zurich]            0        -4608
# small[Athens,Prague,Zurich]            0        -5751
# small[Warsaw,Prague,Zurich]            0      -2920.5
# small[Budapest,Prague,Zurich]            0      -2704.5
# small[Helsinki,Prague,Zurich]            0        -5121
# small[Stockholm,Prague,Zurich]            0      -4423.5
# small[Saint Petersburg,Prague,Zurich]            0        -5634
# small[Bucharest,Prague,Zurich]            0      -4486.5
# small[Kyiv,Prague,Zurich]            0        -4671
# small[Trondheim,Prague,Zurich]            0        -5688
# small[Frankfurt,Prague,Vienna]            0        -1845
# small[Amsterdam,Prague,Vienna]            0        -2691
# small[Paris,Prague,Vienna]            0        -3168
# small[London,Prague,Vienna]            0      -3595.5
# small[Madrid,Prague,Vienna]            0      -5656.5
# small[Copenhagen,Prague,Vienna]            0        -2475
# small[Moscow,Prague,Vienna]            0      -5368.5
# small[Dublin,Prague,Vienna]            0        -4806
# small[Lisbon,Prague,Vienna]            0        -6975
# small[Berlin,Prague,Vienna]            0      -1480.5
# small[Oslo,Prague,Vienna]            0      -3829.5
# small[Dusseldorf,Prague,Vienna]            0        -2250
# small[Helsinki,Prague,Vienna]            0      -4342.5
# small[Palma de Mallorca,Prague,Vienna]            0      -4855.5
# small[Hamburg,Prague,Vienna]            0      -2074.5
# small[Manchester,Prague,Vienna]            0      -4072.5
# small[Geneva,Prague,Vienna]            0        -2790
# small[Stockholm,Prague,Vienna]            0        -3645
# small[Stuttgart,Prague,Vienna]            0      -1831.5
# small[Malaga,Prague,Vienna]            0      -6610.5
# small[Saint Petersburg,Prague,Vienna]            0      -4855.5
# small[Cologne/Bonn,Prague,Vienna]            0      -2164.5
# small[Porto,Prague,Vienna]            0        -6399
# small[Edinburgh,Prague,Vienna]            0      -4459.5
# small[Alicante,Prague,Vienna]            0      -5611.5
# small[Lyon,Prague,Vienna]            0      -3100.5
# small[Birmingham,Prague,Vienna]            0        -3960
# small[Trondheim,Prague,Vienna]            0      -4909.5
# small[Istanbul,Prague,Milan]            0        -6021
# small[Copenhagen,Prague,Milan]            0        -3582
# small[Moscow,Prague,Milan]            0      -6475.5
# small[Berlin,Prague,Milan]            0      -2587.5
# small[Oslo,Prague,Milan]            0      -4936.5
# small[Warsaw,Prague,Milan]            0        -3249
# small[Helsinki,Prague,Milan]            0      -5449.5
# small[Hamburg,Prague,Milan]            0      -3181.5
# small[Stockholm,Prague,Milan]            0        -4752
# small[Saint Petersburg,Prague,Milan]            0      -5962.5
# small[Bucharest,Prague,Milan]            0        -4815
# small[Kyiv,Prague,Milan]            0      -4999.5
# small[Trondheim,Prague,Milan]            0      -6016.5
# small[Istanbul,Prague,Dublin]            0        -8334
# small[Moscow,Prague,Dublin]            0      -8788.5
# small[Rome,Prague,Dublin]            0      -6682.5
# small[Vienna,Prague,Dublin]            0        -4806
# small[Athens,Prague,Dublin]            0      -8392.5
# small[Warsaw,Prague,Dublin]            0        -5562
# small[Budapest,Prague,Dublin]            0        -5346
# small[Saint Petersburg,Prague,Dublin]            0      -8275.5
# small[Bucharest,Prague,Dublin]            0        -7128
# small[Kyiv,Prague,Dublin]            0      -7312.5
# small[Istanbul,Prague,Lisbon]            0       -10503
# small[Copenhagen,Prague,Lisbon]            0        -8064
# small[Moscow,Prague,Lisbon]            0     -10957.5
# small[Vienna,Prague,Lisbon]            0        -6975
# small[Berlin,Prague,Lisbon]            0      -7069.5
# small[Oslo,Prague,Lisbon]            0      -9418.5
# small[Warsaw,Prague,Lisbon]            0        -7731
# small[Budapest,Prague,Lisbon]            0        -7515
# small[Helsinki,Prague,Lisbon]            0      -9931.5
# small[Hamburg,Prague,Lisbon]            0      -7663.5
# small[Stockholm,Prague,Lisbon]            0        -9234
# small[Saint Petersburg,Prague,Lisbon]            0     -10444.5
# small[Bucharest,Prague,Lisbon]            0        -9297
# small[Kyiv,Prague,Lisbon]            0      -9481.5
# small[Trondheim,Prague,Lisbon]            0     -10498.5
# small[Madrid,Prague,Berlin]            0        -5751
# small[Istanbul,Prague,Berlin]            0      -5008.5
# small[Moscow,Prague,Berlin]            0        -5463
# small[Rome,Prague,Berlin]            0        -3357
# small[Zurich,Prague,Berlin]            0        -2259
# small[Vienna,Prague,Berlin]            0      -1480.5
# small[Milan,Prague,Berlin]            0      -2587.5
# small[Lisbon,Prague,Berlin]            0      -7069.5
# small[Athens,Prague,Berlin]            0        -5067
# small[Budapest,Prague,Berlin]            0      -2020.5
# small[Palma de Mallorca,Prague,Berlin]            0        -4950
# small[Geneva,Prague,Berlin]            0      -2884.5
# small[Malaga,Prague,Berlin]            0        -6705
# small[Milan/Bergamo,Prague,Berlin]            0        -2475
# small[Nice,Prague,Berlin]            0      -3280.5
# small[Bucharest,Prague,Berlin]            0      -3802.5
# small[Kyiv,Prague,Berlin]            0        -3987
# small[Porto,Prague,Berlin]            0      -6493.5
# small[Alicante,Prague,Berlin]            0        -5706
# small[Lyon,Prague,Berlin]            0        -3195
# small[Madrid,Prague,Oslo]            0        -8100
# small[Istanbul,Prague,Oslo]            0      -7357.5
# small[Rome,Prague,Oslo]            0        -5706
# small[Zurich,Prague,Oslo]            0        -4608
# small[Vienna,Prague,Oslo]            0      -3829.5
# small[Milan,Prague,Oslo]            0      -4936.5
# small[Lisbon,Prague,Oslo]            0      -9418.5
# small[Athens,Prague,Oslo]            0        -7416
# small[Budapest,Prague,Oslo]            0      -4369.5
# small[Palma de Mallorca,Prague,Oslo]            0        -7299
# small[Geneva,Prague,Oslo]            0      -5233.5
# small[Stuttgart,Prague,Oslo]            0        -4275
# small[Malaga,Prague,Oslo]            0        -9054
# small[Milan/Bergamo,Prague,Oslo]            0        -4824
# small[Nice,Prague,Oslo]            0      -5629.5
# small[Bucharest,Prague,Oslo]            0      -6151.5
# small[Porto,Prague,Oslo]            0      -8842.5
# small[Alicante,Prague,Oslo]            0        -8055
# small[Lyon,Prague,Oslo]            0        -5544
# small[Istanbul,Prague,Dusseldorf]            0        -5778
# small[Moscow,Prague,Dusseldorf]            0      -6232.5
# small[Vienna,Prague,Dusseldorf]            0        -2250
# small[Athens,Prague,Dusseldorf]            0      -5836.5
# small[Warsaw,Prague,Dusseldorf]            0        -3006
# small[Budapest,Prague,Dusseldorf]            0        -2790
# small[Helsinki,Prague,Dusseldorf]            0      -5206.5
# small[Saint Petersburg,Prague,Dusseldorf]            0      -5719.5
# small[Bucharest,Prague,Dusseldorf]            0        -4572
# small[Kyiv,Prague,Dusseldorf]            0      -4756.5
# small[Frankfurt,Prague,Athens]            0      -5431.5
# small[Amsterdam,Prague,Athens]            0      -6277.5
# small[Paris,Prague,Athens]            0      -6754.5
# small[London,Prague,Athens]            0        -7182
# small[Copenhagen,Prague,Athens]            0      -6061.5
# small[Zurich,Prague,Athens]            0        -5751
# small[Dublin,Prague,Athens]            0      -8392.5
# small[Berlin,Prague,Athens]            0        -5067
# small[Oslo,Prague,Athens]            0        -7416
# small[Dusseldorf,Prague,Athens]            0      -5836.5
# small[Warsaw,Prague,Athens]            0      -5728.5
# small[Helsinki,Prague,Athens]            0        -7929
# small[Hamburg,Prague,Athens]            0        -5661
# small[Manchester,Prague,Athens]            0        -7659
# small[Stockholm,Prague,Athens]            0      -7231.5
# small[Stuttgart,Prague,Athens]            0        -5418
# small[Saint Petersburg,Prague,Athens]            0        -8442
# small[Cologne/Bonn,Prague,Athens]            0        -5751
# small[Porto,Prague,Athens]            0      -9985.5
# small[Edinburgh,Prague,Athens]            0        -8046
# small[Birmingham,Prague,Athens]            0      -7546.5
# small[Trondheim,Prague,Athens]            0        -8496
# small[Frankfurt,Prague,Warsaw]            0        -2601
# small[Amsterdam,Prague,Warsaw]            0        -3447
# small[Paris,Prague,Warsaw]            0        -3924
# small[London,Prague,Warsaw]            0      -4351.5
# small[Madrid,Prague,Warsaw]            0      -6412.5
# small[Rome,Prague,Warsaw]            0      -4018.5
# small[Zurich,Prague,Warsaw]            0      -2920.5
# small[Milan,Prague,Warsaw]            0        -3249
# small[Dublin,Prague,Warsaw]            0        -5562
# small[Lisbon,Prague,Warsaw]            0        -7731
# small[Dusseldorf,Prague,Warsaw]            0        -3006
# small[Athens,Prague,Warsaw]            0      -5728.5
# small[Palma de Mallorca,Prague,Warsaw]            0      -5611.5
# small[Manchester,Prague,Warsaw]            0      -4828.5
# small[Geneva,Prague,Warsaw]            0        -3546
# small[Stuttgart,Prague,Warsaw]            0      -2587.5
# small[Malaga,Prague,Warsaw]            0      -7366.5
# small[Milan/Bergamo,Prague,Warsaw]            0      -3136.5
# small[Nice,Prague,Warsaw]            0        -3942
# small[Cologne/Bonn,Prague,Warsaw]            0      -2920.5
# small[Porto,Prague,Warsaw]            0        -7155
# small[Edinburgh,Prague,Warsaw]            0      -5215.5
# small[Alicante,Prague,Warsaw]            0      -6367.5
# small[Lyon,Prague,Warsaw]            0      -3856.5
# small[Birmingham,Prague,Warsaw]            0        -4716
# small[Frankfurt,Prague,Budapest]            0        -2385
# small[Amsterdam,Prague,Budapest]            0        -3231
# small[Paris,Prague,Budapest]            0        -3708
# small[London,Prague,Budapest]            0      -4135.5
# small[Madrid,Prague,Budapest]            0      -6196.5
# small[Copenhagen,Prague,Budapest]            0        -3015
# small[Zurich,Prague,Budapest]            0      -2704.5
# small[Dublin,Prague,Budapest]            0        -5346
# small[Lisbon,Prague,Budapest]            0        -7515
# small[Berlin,Prague,Budapest]            0      -2020.5
# small[Oslo,Prague,Budapest]            0      -4369.5
# small[Dusseldorf,Prague,Budapest]            0        -2790
# small[Helsinki,Prague,Budapest]            0      -4882.5
# small[Palma de Mallorca,Prague,Budapest]            0      -5395.5
# small[Hamburg,Prague,Budapest]            0      -2614.5
# small[Manchester,Prague,Budapest]            0      -4612.5
# small[Geneva,Prague,Budapest]            0        -3330
# small[Stockholm,Prague,Budapest]            0        -4185
# small[Stuttgart,Prague,Budapest]            0      -2371.5
# small[Malaga,Prague,Budapest]            0      -7150.5
# small[Saint Petersburg,Prague,Budapest]            0      -5395.5
# small[Cologne/Bonn,Prague,Budapest]            0      -2704.5
# small[Porto,Prague,Budapest]            0        -6939
# small[Edinburgh,Prague,Budapest]            0      -4999.5
# small[Alicante,Prague,Budapest]            0      -6151.5
# small[Lyon,Prague,Budapest]            0      -3640.5
# small[Birmingham,Prague,Budapest]            0        -4500
# small[Trondheim,Prague,Budapest]            0      -5449.5
# small[Frankfurt,Prague,Helsinki]            0      -4801.5
# small[Paris,Prague,Helsinki]            0      -6124.5
# small[London,Prague,Helsinki]            0        -6552
# small[Madrid,Prague,Helsinki]            0        -8613
# small[Rome,Prague,Helsinki]            0        -6219
# small[Zurich,Prague,Helsinki]            0        -5121
# small[Vienna,Prague,Helsinki]            0      -4342.5
# small[Milan,Prague,Helsinki]            0      -5449.5
# small[Lisbon,Prague,Helsinki]            0      -9931.5
# small[Dusseldorf,Prague,Helsinki]            0      -5206.5
# small[Athens,Prague,Helsinki]            0        -7929
# small[Budapest,Prague,Helsinki]            0      -4882.5
# small[Palma de Mallorca,Prague,Helsinki]            0        -7812
# small[Geneva,Prague,Helsinki]            0      -5746.5
# small[Stuttgart,Prague,Helsinki]            0        -4788
# small[Malaga,Prague,Helsinki]            0        -9567
# small[Milan/Bergamo,Prague,Helsinki]            0        -5337
# small[Nice,Prague,Helsinki]            0      -6142.5
# small[Cologne/Bonn,Prague,Helsinki]            0        -5121
# small[Porto,Prague,Helsinki]            0      -9355.5
# small[Alicante,Prague,Helsinki]            0        -8568
# small[Lyon,Prague,Helsinki]            0        -6057
# small[Copenhagen,Prague,Palma de Mallorca]            0      -5944.5
# small[Moscow,Prague,Palma de Mallorca]            0        -8838
# small[Vienna,Prague,Palma de Mallorca]            0      -4855.5
# small[Berlin,Prague,Palma de Mallorca]            0        -4950
# small[Oslo,Prague,Palma de Mallorca]            0        -7299
# small[Warsaw,Prague,Palma de Mallorca]            0      -5611.5
# small[Budapest,Prague,Palma de Mallorca]            0      -5395.5
# small[Helsinki,Prague,Palma de Mallorca]            0        -7812
# small[Hamburg,Prague,Palma de Mallorca]            0        -5544
# small[Stockholm,Prague,Palma de Mallorca]            0      -7114.5
# small[Saint Petersburg,Prague,Palma de Mallorca]            0        -8325
# small[Bucharest,Prague,Palma de Mallorca]            0      -7177.5
# small[Kyiv,Prague,Palma de Mallorca]            0        -7362
# small[Trondheim,Prague,Palma de Mallorca]            0        -8379
# small[Madrid,Prague,Hamburg]            0        -6345
# small[Istanbul,Prague,Hamburg]            0      -5602.5
# small[Moscow,Prague,Hamburg]            0        -6057
# small[Rome,Prague,Hamburg]            0        -3951
# small[Vienna,Prague,Hamburg]            0      -2074.5
# small[Milan,Prague,Hamburg]            0      -3181.5
# small[Lisbon,Prague,Hamburg]            0      -7663.5
# small[Athens,Prague,Hamburg]            0        -5661
# small[Budapest,Prague,Hamburg]            0      -2614.5
# small[Palma de Mallorca,Prague,Hamburg]            0        -5544
# small[Malaga,Prague,Hamburg]            0        -7299
# small[Milan/Bergamo,Prague,Hamburg]            0        -3069
# small[Nice,Prague,Hamburg]            0      -3874.5
# small[Bucharest,Prague,Hamburg]            0      -4396.5
# small[Kyiv,Prague,Hamburg]            0        -4581
# small[Porto,Prague,Hamburg]            0      -7087.5

# %%
small_res = res[res["names"].str.startswith("small")]["values"].sum()
medium_res = res[res["names"].str.startswith("medium")]["values"].sum()
large_res = res[res["names"].str.startswith("large")]["values"].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 small_res = res[res["names"].str.startswith("small")]["values"].sum()
#       2 medium_res = res[res["names"].str.startswith("medium")]["values"].sum()
#       3 large_res = res[res["names"].str.startswith("large")]["values"].sum()
#
# NameError: name 'res' is not defined
