# %%
import gurobipy as gb
import pandas as pd

# Question 1.2, Data preparation
data = pd.read_csv("flights-1.csv", encoding='latin-1')

# Fix of the issue with different decodings
issues = {"ZÃ¼rich": "Zurich", "DÃ¼sseldorf": "Dusseldorf", "MÃ¡laga": "Malaga"}
for key, value in issues.items():
    data.loc[data["departureCity"] == key, "departureCity"] = value
    data.loc[data["arrivalCity"] == key, "arrivalCity"] = value

capacity = {"small": 50, "medium": 100, "large": 300}
cost_per_mile = {"small": 4.5, "medium": 8, "large": 20}
charge = 0.1

distances = data.set_index(['departureCity', 'arrivalCity'])['Distance'].to_dict()
demands = data.set_index(['departureCity', 'arrivalCity'])['Demand'].to_dict()

# Question 1.3, I am trying to figure out
model = gb.Model()

cities = data['departureCity'].unique()

small = model.addVars(cities, cities, name="small", vtype=gb.GRB.INTEGER, lb=0)
medium = model.addVars(cities, cities, name="medium", vtype=gb.GRB.INTEGER, lb=0)
large = model.addVars(cities, cities, name="large", vtype=gb.GRB.INTEGER, lb=0)
num_of_passengers = model.addVars(cities, cities, name="Num_of_pass_", vtype=gb.GRB.INTEGER, lb=0)

# That's how I calculate the profit
model.setObjective(gb.quicksum(charge * distances[(i, j)] * num_of_passengers[(i, j)] - distances[(i, j)] * (
        cost_per_mile["small"] * small[(i, j)] + cost_per_mile["medium"] * medium[(i, j)] + cost_per_mile["large"] * large[(i, j)])
        for i in cities for j in cities if i != j), gb.GRB.MAXIMIZE)

# the number of customers should be lower or equal to the demand
model.addConstrs(num_of_passengers[(i, j)] <= demands[(i, j)] for i in cities for j in cities if i != j)

# number of customers per route should be equal to each plane's full capacity by number of those planes
model.addConstrs(num_of_passengers[(i, j)] <= capacity["small"] * small[(i, j)] + capacity["medium"] * medium[(i, j)] + capacity["large"] * large[(i, j)]
                 for i in cities for j in cities if i != j)

model.optimize()
print("Optimal Objective Value:", model.ObjVal)

vals = model.printAttr(["X", "Obj"])
all_vars = model.getVars()

# Since there are a lot of variables, I decided to move them into a dataframe format
values = model.getAttr("X", all_vars)
names = model.getAttr("VarName", all_vars)

res = pd.DataFrame({"names": names, "values": values})
# Out:
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3280 rows, 6724 columns and 8200 nonzeros
# Model fingerprint: 0xa76b378f
# Variable types: 0 continuous, 6724 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+02]
#   Objective range  [3e+00, 5e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 2e+03]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3279 rows and 6720 columns
# Presolve time: 0.35s
# Presolved: 1 rows, 4 columns, 4 nonzeros
# Found heuristic solution: objective 3448114.6000
# Variable types: 0 continuous, 4 integer (0 binary)
#
# Root relaxation: objective 3.459636e+06, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3459636.40    0    1 3448114.60 3459636.40  0.33%     -    0s
# H    0     0                    3458704.0000 3459636.40  0.03%     -    0s
# H    0     0                    3459214.6000 3459636.40  0.01%     -    0s
# H    0     0                    3459325.6000 3459636.40  0.01%     -    0s
#      0     0 3459636.40    0    1 3459325.60 3459636.40  0.01%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.36 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 3.45933e+06 3.45921e+06 3.4587e+06 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.459325600000e+06, best bound 3.459325600000e+06, gap 0.0000%
# Optimal Objective Value: 3459325.599999997
#
#     Variable            X          Obj
# --------------------------------------
# small[Amsterdam,London]            1         -999
# small[Amsterdam,Paris]            0      -1201.5
# small[Amsterdam,Frankfurt]            0        -1017
# small[Amsterdam,Madrid]            1        -4140
# small[Amsterdam,Istanbul]            0        -6192
# small[Amsterdam,Moscow]           -0        -6021
# small[Amsterdam,Rome]            1        -3627
# small[Amsterdam,Zurich]           -0      -1714.5
# small[Amsterdam,Vienna]            0      -2623.5
# small[Amsterdam,Dublin]            0      -2119.5
# small[Amsterdam,Dusseldorf]            0       -508.5
# small[Amsterdam,Copenhagen]            0      -1741.5
# small[Amsterdam,Manchester]            0      -1381.5
# small[Amsterdam,Milan]            0      -2317.5
# small[Amsterdam,Palma de Mallorca]            0        -4005
# small[Amsterdam,Lisbon]            1      -5215.5
# small[Amsterdam,Oslo]            0      -2551.5
# small[Amsterdam,Berlin]           -0        -1611
# small[Amsterdam,Prague]            0        -1998
# small[Amsterdam,Helsinki]            0      -4207.5
# small[Amsterdam,Geneva]            0        -1935
# small[Amsterdam,Hamburg]            0        -1026
# small[Amsterdam,Edinburgh]            0        -1845
# small[Amsterdam,Milan/Bergamo]            0      -2299.5
# small[Amsterdam,Stockholm]            0        -3150
# small[Amsterdam,Malaga]            0        -5274
# small[Amsterdam,Athens]            0      -6052.5
# small[Amsterdam,Nice]            1      -2740.5
# small[Amsterdam,Lyon]            1      -2056.5
# small[Amsterdam,Birmingham]            1      -1291.5
# small[Amsterdam,Saint Petersburg]            0        -4959
# small[Amsterdam,Warsaw]            0      -3064.5
# small[Amsterdam,Cologne/Bonn]           -0       -634.5
# small[Amsterdam,Alicante]            0        -4509
# small[Amsterdam,Stuttgart]            1      -1399.5
# small[Amsterdam,Budapest]            0      -3208.5
# small[Amsterdam,Kyiv]            1        -4995
# small[Amsterdam,Bucharest]            1      -5008.5
# small[Amsterdam,Porto]            0        -4509
# small[Amsterdam,Trondheim]            1        -3555
# small[London,Amsterdam]            0         -999
# small[London,Paris]            0       -958.5
# small[London,Frankfurt]            0      -1786.5
# small[London,Madrid]           -0        -3528
# small[London,Istanbul]           -0        -7002
# small[London,Moscow]            0        -7011
# small[London,Rome]            1        -4014
# small[London,Zurich]            0      -2173.5
# small[London,Vienna]            1      -3460.5
# small[London,Dublin]            0        -1296
# small[London,Dusseldorf]            0      -1345.5
# small[London,Copenhagen]           -0      -2677.5
# small[London,Manchester]            1       -733.5
# small[London,Milan]            0        -2682
# small[London,Palma de Mallorca]           -0      -3757.5
# small[London,Lisbon]            0      -4432.5
# small[London,Oslo]           -0        -3231
# small[London,Berlin]            0      -2605.5
# small[London,Prague]            0      -2902.5
# small[London,Helsinki]            0        -5103
# small[London,Geneva]            1        -2088
# small[London,Hamburg]            0      -2020.5
# small[London,Edinburgh]            0        -1494
# small[London,Milan/Bergamo]            1      -2713.5
# small[London,Stockholm]            0        -4014
# small[London,Malaga]            0        -4689
# small[London,Athens]            0        -6696
# small[London,Nice]            0      -2875.5
# small[London,Lyon]           -0      -2056.5
# small[London,Birmingham]            0       -454.5
# small[London,Saint Petersburg]            0        -5886
# small[London,Warsaw]            0        -4059
# small[London,Cologne/Bonn]            0        -1431
# small[London,Alicante]            1      -4090.5
# small[London,Stuttgart]            0      -2038.5
# small[London,Budapest]            0      -4063.5
# small[London,Kyiv]            0      -5980.5
# small[London,Bucharest]            0        -5859
# small[London,Porto]            1      -3694.5
# small[London,Trondheim]            1        -4095
# small[Paris,Amsterdam]            0      -1201.5
# small[Paris,London]            0       -958.5
# small[Paris,Frankfurt]           -0      -1336.5
# small[Paris,Madrid]           -0        -2943
# small[Paris,Istanbul]            1        -6318
# small[Paris,Moscow]            0      -6970.5
# small[Paris,Rome]            0      -3091.5
# small[Paris,Zurich]            0        -1368
# small[Paris,Vienna]           -0        -2898
# small[Paris,Dublin]           -0        -2187
# small[Paris,Dusseldorf]           -0        -1152
# small[Paris,Copenhagen]            0      -2875.5
# small[Paris,Manchester]           -0        -1692
# small[Paris,Milan]           -0        -1791
# small[Paris,Palma de Mallorca]            0      -2884.5
# small[Paris,Lisbon]            1        -4068
# small[Paris,Oslo]            0        -3753
# small[Paris,Berlin]            0      -2452.5
# small[Paris,Prague]            1        -2475
# small[Paris,Helsinki]            0        -5346
# small[Paris,Geneva]            1      -1147.5
# small[Paris,Hamburg]            0      -2083.5
# small[Paris,Edinburgh]            0      -2443.5
# small[Paris,Milan/Bergamo]            0        -1836
# small[Paris,Stockholm]            0        -4320
# small[Paris,Malaga]            0        -4068
# small[Paris,Athens]           -0        -5868
# small[Paris,Nice]           -0        -1917
# small[Paris,Lyon]           -0      -1093.5
# small[Paris,Birmingham]            0        -1404
# small[Paris,Saint Petersburg]            0        -6066
# small[Paris,Warsaw]            0      -3829.5
# small[Paris,Cologne/Bonn]            0      -1147.5
# small[Paris,Alicante]            0      -3325.5
# small[Paris,Stuttgart]           -0      -1399.5
# small[Paris,Budapest]            0      -3487.5
# small[Paris,Kyiv]           -0      -5674.5
# small[Paris,Bucharest]            0      -5242.5
# small[Paris,Porto]            0        -3393
# small[Paris,Trondheim]            1      -4738.5
# small[Frankfurt,Amsterdam]            1        -1017
# small[Frankfurt,London]            1      -1786.5
# small[Frankfurt,Paris]            1      -1336.5
# small[Frankfurt,Madrid]           -0      -4045.5
# small[Frankfurt,Istanbul]            0      -5224.5
# small[Frankfurt,Moscow]            0      -5665.5
# small[Frankfurt,Rome]           -0        -2682
# small[Frankfurt,Zurich]            1       -850.5
# small[Frankfurt,Vienna]            1        -1674
# small[Frankfurt,Dublin]            0      -3046.5
# small[Frankfurt,Dusseldorf]            0       -508.5
# small[Frankfurt,Copenhagen]            1        -1881
# small[Frankfurt,Manchester]            0        -2349
# small[Frankfurt,Milan]            1      -1444.5
# small[Frankfurt,Palma de Mallorca]            0      -3532.5
# small[Frankfurt,Lisbon]           -0        -5292
# small[Frankfurt,Oslo]            0        -3069
# small[Frankfurt,Berlin]           -0      -1183.5
# small[Frankfurt,Prague]            0        -1152
# small[Frankfurt,Helsinki]            0      -4243.5
# small[Frankfurt,Geneva]            0        -1323
# small[Frankfurt,Hamburg]            0        -1098
# small[Frankfurt,Edinburgh]            0      -2866.5
# small[Frankfurt,Milan/Bergamo]           -0        -1395
# small[Frankfurt,Stockholm]            0        -3321
# small[Frankfurt,Malaga]            0      -5089.5
# small[Frankfurt,Athens]            0      -5035.5
# small[Frankfurt,Nice]            0      -2011.5
# small[Frankfurt,Lyon]           -0      -1570.5
# small[Frankfurt,Birmingham]           -0        -2187
# small[Frankfurt,Saint Petersburg]            0      -4891.5
# small[Frankfurt,Warsaw]            1        -2493
# small[Frankfurt,Cologne/Bonn]            0       -382.5
# small[Frankfurt,Alicante]            1      -4180.5
# small[Frankfurt,Stuttgart]           -0         -423
# small[Frankfurt,Budapest]           -0      -2272.5
# small[Frankfurt,Kyiv]            1        -4338
# small[Frankfurt,Bucharest]            1      -4072.5
# small[Frankfurt,Porto]            1      -4666.5
# small[Frankfurt,Trondheim]            1      -4153.5
# small[Madrid,Amsterdam]           -0        -4140
# small[Madrid,London]            1        -3528
# small[Madrid,Paris]            1        -2943
# small[Madrid,Frankfurt]           -0      -4045.5
# small[Madrid,Istanbul]            1      -7672.5
# small[Madrid,Moscow]            0        -9639
# small[Madrid,Rome]           -0      -3820.5
# small[Madrid,Zurich]            0      -3487.5
# small[Madrid,Vienna]            0        -5067
# small[Madrid,Dublin]            0      -4054.5
# small[Madrid,Dusseldorf]            0      -4045.5
# small[Madrid,Copenhagen]           -0      -5800.5
# small[Madrid,Manchester]            0        -4068
# small[Madrid,Milan]            0      -3325.5
# small[Madrid,Palma de Mallorca]            0        -1539
# small[Madrid,Lisbon]            1      -1408.5
# small[Madrid,Oslo]            0        -6678
# small[Madrid,Berlin]            0        -5229
# small[Madrid,Prague]            1      -4963.5
# small[Madrid,Helsinki]            0        -8253
# small[Madrid,Geneva]            0        -2862
# small[Madrid,Hamburg]            1        -4995
# small[Madrid,Edinburgh]            1      -4828.5
# small[Madrid,Milan/Bergamo]            0      -3451.5
# small[Madrid,Stockholm]            0      -7258.5
# small[Madrid,Malaga]            0      -1156.5
# small[Madrid,Athens]            0      -6637.5
# small[Madrid,Nice]            0      -2731.5
# small[Madrid,Lyon]            0      -2551.5
# small[Madrid,Birmingham]            0      -3766.5
# small[Madrid,Saint Petersburg]            0      -8932.5
# small[Madrid,Warsaw]           -0      -6412.5
# small[Madrid,Cologne/Bonn]            0        -4005
# small[Madrid,Alicante]            0      -1003.5
# small[Madrid,Stuttgart]            0        -3852
# small[Madrid,Budapest]            1      -5530.5
# small[Madrid,Kyiv]            0        -8019
# small[Madrid,Bucharest]            1        -6930
# small[Madrid,Porto]           -0        -1179
# small[Madrid,Trondheim]           -0        -7614
# small[Istanbul,Amsterdam]            1        -6192
# small[Istanbul,London]           -0        -7002
# small[Istanbul,Paris]           -0        -6318
# small[Istanbul,Frankfurt]            0      -5224.5
# small[Istanbul,Madrid]            0      -7672.5
# small[Istanbul,Moscow]            0      -4909.5
# small[Istanbul,Rome]            0        -3852
# small[Istanbul,Zurich]            0      -4954.5
# small[Istanbul,Vienna]            0      -3568.5
# small[Istanbul,Dublin]            0      -8275.5
# small[Istanbul,Dusseldorf]            0        -5715
# small[Istanbul,Copenhagen]            0      -5656.5
# small[Istanbul,Manchester]            0        -7569
# small[Istanbul,Milan]            0      -4684.5
# small[Istanbul,Palma de Mallorca]            0        -6246
# small[Istanbul,Lisbon]            1        -9072
# small[Istanbul,Oslo]            0        -6849
# small[Istanbul,Berlin]           -0      -4864.5
# small[Istanbul,Prague]            1        -4221
# small[Istanbul,Helsinki]            1      -6007.5
# small[Istanbul,Geneva]            0        -5373
# small[Istanbul,Hamburg]            1      -5557.5
# small[Istanbul,Edinburgh]            0        -7992
# small[Istanbul,Milan/Bergamo]            0        -4590
# small[Istanbul,Stockholm]            0      -6079.5
# small[Istanbul,Malaga]            0      -8158.5
# small[Istanbul,Athens]            0      -1570.5
# small[Istanbul,Nice]            0        -5049
# small[Istanbul,Lyon]            0      -5638.5
# small[Istanbul,Birmingham]            0        -7416
# small[Istanbul,Saint Petersburg]            0      -5890.5
# small[Istanbul,Warsaw]            0      -3874.5
# small[Istanbul,Cologne/Bonn]            0      -5602.5
# small[Istanbul,Alicante]            0      -7078.5
# small[Istanbul,Stuttgart]            0        -4968
# small[Istanbul,Budapest]            0        -2988
# small[Istanbul,Kyiv]            0        -2952
# small[Istanbul,Bucharest]            1      -1246.5
# small[Istanbul,Porto]            0        -8757
# small[Istanbul,Trondheim]           -0        -7758
# small[Moscow,Amsterdam]           -0        -6021
# small[Moscow,London]            0        -7011
# small[Moscow,Paris]            0      -6970.5
# small[Moscow,Frankfurt]            0      -5665.5
# small[Moscow,Madrid]            1        -9639
# small[Moscow,Istanbul]           -0      -4909.5
# small[Moscow,Rome]            0      -6655.5
# small[Moscow,Zurich]            0        -6147
# small[Moscow,Vienna]            0        -4680
# small[Moscow,Dublin]            0        -7839
# small[Moscow,Dusseldorf]            1        -5841
# small[Moscow,Copenhagen]            0        -4374
# small[Moscow,Manchester]            0      -7132.5
# small[Moscow,Milan]           -0      -6403.5
# small[Moscow,Palma de Mallorca]            0      -8752.5
# small[Moscow,Lisbon]            1       -10944
# small[Moscow,Oslo]            0      -4612.5
# small[Moscow,Berlin]            1      -4513.5
# small[Moscow,Prague]            0      -4675.5
# small[Moscow,Helsinki]            1        -2502
# small[Moscow,Geneva]            0        -6777
# small[Moscow,Hamburg]            0        -4995
# small[Moscow,Edinburgh]            0        -7038
# small[Moscow,Milan/Bergamo]            0        -6282
# small[Moscow,Stockholm]            1      -3442.5
# small[Moscow,Malaga]            0     -10579.5
# small[Moscow,Athens]           -0        -6237
# small[Moscow,Nice]            0      -7087.5
# small[Moscow,Lyon]            1      -7087.5
# small[Moscow,Birmingham]            1      -7195.5
# small[Moscow,Saint Petersburg]            0      -1777.5
# small[Moscow,Warsaw]            1      -3226.5
# small[Moscow,Cologne/Bonn]            0      -5827.5
# small[Moscow,Alicante]            1      -9553.5
# small[Moscow,Stuttgart]            0      -5791.5
# small[Moscow,Budapest]            0      -4396.5
# small[Moscow,Kyiv]            1        -2115
# small[Moscow,Bucharest]            0      -4189.5
# small[Moscow,Porto]            1     -10336.5
# small[Moscow,Trondheim]           -0      -4864.5
# small[Rome,Amsterdam]            0        -3627
# small[Rome,London]           -0        -4014
# small[Rome,Paris]            0      -3091.5
# small[Rome,Frankfurt]            1        -2682
# small[Rome,Madrid]            1      -3820.5
# small[Rome,Istanbul]            1        -3852
# small[Rome,Moscow]            0      -6655.5
# small[Rome,Zurich]            0      -1912.5
# small[Rome,Vienna]            0      -2137.5
# small[Rome,Dublin]            0      -5278.5
# small[Rome,Dusseldorf]           -0      -3145.5
# small[Rome,Copenhagen]            0      -4288.5
# small[Rome,Manchester]            0        -4725
# small[Rome,Milan]            0        -1332
# small[Rome,Palma de Mallorca]            1        -2430
# small[Rome,Lisbon]            0      -5215.5
# small[Rome,Oslo]           -0      -5611.5
# small[Rome,Berlin]            1      -3307.5
# small[Rome,Prague]            0      -2569.5
# small[Rome,Helsinki]            1      -6160.5
# small[Rome,Geneva]            0      -1948.5
# small[Rome,Hamburg]            0      -3658.5
# small[Rome,Edinburgh]            1      -5395.5
# small[Rome,Milan/Bergamo]            0      -1327.5
# small[Rome,Stockholm]            1        -5526
# small[Rome,Malaga]            0      -4369.5
# small[Rome,Athens]            1        -2943
# small[Rome,Nice]            1        -1314
# small[Rome,Lyon]            0      -2092.5
# small[Rome,Birmingham]            1      -4468.5
# small[Rome,Saint Petersburg]            1        -6570
# small[Rome,Warsaw]            0        -3681
# small[Rome,Cologne/Bonn]            1        -3015
# small[Rome,Alicante]            0        -3276
# small[Rome,Stuttgart]            1      -2254.5
# small[Rome,Budapest]            0      -2263.5
# small[Rome,Kyiv]            0      -4693.5
# small[Rome,Bucharest]            0      -3190.5
# small[Rome,Porto]            0        -4914
# small[Rome,Trondheim]           -0      -6709.5
# small[Zurich,Amsterdam]            0      -1714.5
# small[Zurich,London]            0      -2173.5
# small[Zurich,Paris]            1        -1368
# small[Zurich,Frankfurt]            0       -850.5
# small[Zurich,Madrid]            0      -3487.5
# small[Zurich,Istanbul]            0      -4954.5
# small[Zurich,Moscow]            0        -6147
# small[Zurich,Rome]            0      -1912.5
# small[Zurich,Vienna]            0        -1656
# small[Zurich,Dublin]            1      -3469.5
# small[Zurich,Dusseldorf]            1      -1246.5
# small[Zurich,Copenhagen]            0        -2700
# small[Zurich,Manchester]            1      -2857.5
# small[Zurich,Milan]           -0       -607.5
# small[Zurich,Palma de Mallorca]            0        -2763
# small[Zurich,Lisbon]            1        -4824
# small[Zurich,Oslo]            0      -3919.5
# small[Zurich,Berlin]           -0      -1867.5
# small[Zurich,Prague]            0      -1471.5
# small[Zurich,Helsinki]            1        -4968
# small[Zurich,Geneva]            1       -625.5
# small[Zurich,Hamburg]            0      -1939.5
# small[Zurich,Edinburgh]            1        -3492
# small[Zurich,Milan/Bergamo]            0       -580.5
# small[Zurich,Stockholm]            0      -4108.5
# small[Zurich,Malaga]            0      -4450.5
# small[Zurich,Athens]            0        -4527
# small[Zurich,Nice]            0      -1174.5
# small[Zurich,Lyon]            1         -936
# small[Zurich,Birmingham]            1      -2623.5
# small[Zurich,Saint Petersburg]            1        -5562
# small[Zurich,Warsaw]            1      -2920.5
# small[Zurich,Cologne/Bonn]            0      -1120.5
# small[Zurich,Alicante]            1        -3474
# small[Zurich,Stuttgart]            1       -454.5
# small[Zurich,Budapest]            0      -2209.5
# small[Zurich,Kyiv]            1      -4585.5
# small[Zurich,Bucharest]            1        -3906
# small[Zurich,Porto]            1        -4275
# small[Zurich,Trondheim]           -0        -5004
# small[Vienna,Amsterdam]           -0      -2623.5
# small[Vienna,London]            1      -3460.5
# small[Vienna,Paris]            0        -2898
# small[Vienna,Frankfurt]            0        -1674
# small[Vienna,Madrid]            1        -5067
# small[Vienna,Istanbul]            0      -3568.5
# small[Vienna,Moscow]            0        -4680
# small[Vienna,Rome]            1      -2137.5
# small[Vienna,Zurich]            0        -1656
# small[Vienna,Dublin]            1        -4716
# small[Vienna,Dusseldorf]            1      -2146.5
# small[Vienna,Copenhagen]            0      -2434.5
# small[Vienna,Manchester]            0      -4000.5
# small[Vienna,Milan]            0      -1750.5
# small[Vienna,Palma de Mallorca]            1      -4072.5
# small[Vienna,Lisbon]            1      -6439.5
# small[Vienna,Oslo]            1        -3780
# small[Vienna,Berlin]            0      -1462.5
# small[Vienna,Prague]            0         -693
# small[Vienna,Helsinki]            0      -4027.5
# small[Vienna,Geneva]            0        -2250
# small[Vienna,Hamburg]            0        -2079
# small[Vienna,Edinburgh]            1      -4432.5
# small[Vienna,Milan/Bergamo]            0      -1624.5
# small[Vienna,Stockholm]            0      -3469.5
# small[Vienna,Malaga]            1        -5931
# small[Vienna,Athens]            0        -3582
# small[Vienna,Nice]            1      -2416.5
# small[Vienna,Lyon]            1        -2565
# small[Vienna,Birmingham]            1      -3856.5
# small[Vienna,Saint Petersburg]            1      -4432.5
# small[Vienna,Warsaw]            0      -1552.5
# small[Vienna,Cologne/Bonn]            0      -2038.5
# small[Vienna,Alicante]            1      -4882.5
# small[Vienna,Stuttgart]            0        -1494
# small[Vienna,Budapest]            0       -598.5
# small[Vienna,Kyiv]            1        -2952
# small[Vienna,Bucharest]            1        -2394
# small[Vienna,Porto]            1        -5922
# small[Vienna,Trondheim]           -0      -4846.5
# small[Dublin,Amsterdam]            1      -2119.5
# small[Dublin,London]            0        -1296
# small[Dublin,Paris]            1        -2187
# small[Dublin,Frankfurt]            0      -3046.5
# small[Dublin,Madrid]            0      -4054.5
# small[Dublin,Istanbul]            0      -8275.5
# small[Dublin,Moscow]            0        -7839
# small[Dublin,Rome]            0      -5278.5
# small[Dublin,Zurich]            0      -3469.5
# small[Dublin,Vienna]            1        -4716
# small[Dublin,Dusseldorf]            0      -2569.5
# small[Dublin,Copenhagen]            1        -3474
# small[Dublin,Manchester]           -0         -747
# small[Dublin,Milan]            1      -3964.5
# small[Dublin,Palma de Mallorca]            0        -4680
# small[Dublin,Lisbon]            0        -4590
# small[Dublin,Oslo]            0      -3541.5
# small[Dublin,Berlin]            0        -3690
# small[Dublin,Prague]            1        -4113
# small[Dublin,Helsinki]            0      -5674.5
# small[Dublin,Geneva]            0      -3334.5
# small[Dublin,Hamburg]            0      -3010.5
# small[Dublin,Edinburgh]            0         -981
# small[Dublin,Milan/Bergamo]            1      -4000.5
# small[Dublin,Stockholm]            0        -4563
# small[Dublin,Malaga]            0      -5179.5
# small[Dublin,Athens]            0        -7992
# small[Dublin,Nice]            1        -4086
# small[Dublin,Lyon]            1        -3249
# small[Dublin,Birmingham]            0       -859.5
# small[Dublin,Saint Petersburg]            0      -6502.5
# small[Dublin,Warsaw]            0        -5121
# small[Dublin,Cologne/Bonn]            1        -2673
# small[Dublin,Alicante]            1        -4824
# small[Dublin,Stuttgart]            1      -3334.5
# small[Dublin,Budapest]            1        -5310
# small[Dublin,Kyiv]            1        -7056
# small[Dublin,Bucharest]            1        -7110
# small[Dublin,Porto]            1      -3820.5
# small[Dublin,Trondheim]           -0        -4131
# small[Dusseldorf,Amsterdam]            1       -508.5
# small[Dusseldorf,London]            1      -1345.5
# small[Dusseldorf,Paris]            1        -1152
# small[Dusseldorf,Frankfurt]            0       -508.5
# small[Dusseldorf,Madrid]            0      -4045.5
# small[Dusseldorf,Istanbul]            0        -5715
# small[Dusseldorf,Moscow]            1        -5841
# small[Dusseldorf,Rome]            0      -3145.5
# small[Dusseldorf,Zurich]            1      -1246.5
# small[Dusseldorf,Vienna]            1      -2146.5
# small[Dusseldorf,Dublin]            0      -2569.5
# small[Dusseldorf,Copenhagen]           -0        -1755
# small[Dusseldorf,Manchester]            1        -1854
# small[Dusseldorf,Milan]           -0      -1858.5
# small[Dusseldorf,Palma de Mallorca]            0      -3730.5
# small[Dusseldorf,Lisbon]            1      -5215.5
# small[Dusseldorf,Oslo]            0        -2790
# small[Dusseldorf,Berlin]            1        -1332
# small[Dusseldorf,Prague]            0        -1557
# small[Dusseldorf,Helsinki]            1      -4207.5
# small[Dusseldorf,Geneva]            0        -1566
# small[Dusseldorf,Hamburg]            0         -945
# small[Dusseldorf,Edinburgh]            1      -2353.5
# small[Dusseldorf,Milan/Bergamo]            0        -1827
# small[Dusseldorf,Stockholm]            0        -3213
# small[Dusseldorf,Malaga]            1      -5143.5
# small[Dusseldorf,Athens]            1      -5548.5
# small[Dusseldorf,Nice]            1        -2340
# small[Dusseldorf,Lyon]            1        -1746
# small[Dusseldorf,Birmingham]            1      -1714.5
# small[Dusseldorf,Saint Petersburg]            1        -4914
# small[Dusseldorf,Warsaw]            1      -2758.5
# small[Dusseldorf,Cologne/Bonn]            1       -130.5
# small[Dusseldorf,Alicante]            1      -4306.5
# small[Dusseldorf,Stuttgart]            0         -900
# small[Dusseldorf,Budapest]            1      -2740.5
# small[Dusseldorf,Kyiv]            1        -4662
# small[Dusseldorf,Bucharest]            1      -4540.5
# small[Dusseldorf,Porto]            1        -4545
# small[Dusseldorf,Trondheim]           -0      -3847.5
# small[Copenhagen,Amsterdam]           -0      -1741.5
# small[Copenhagen,London]            0      -2677.5
# small[Copenhagen,Paris]            0      -2875.5
# small[Copenhagen,Frankfurt]            1        -1881
# small[Copenhagen,Madrid]            0      -5800.5
# small[Copenhagen,Istanbul]            0      -5656.5
# small[Copenhagen,Moscow]           -0        -4374
# small[Copenhagen,Rome]           -0      -4288.5
# small[Copenhagen,Zurich]            0        -2700
# small[Copenhagen,Vienna]            1      -2434.5
# small[Copenhagen,Dublin]            0        -3474
# small[Copenhagen,Dusseldorf]            1        -1755
# small[Copenhagen,Manchester]            0      -2758.5
# small[Copenhagen,Milan]            0      -3244.5
# small[Copenhagen,Palma de Mallorca]            0      -5413.5
# small[Copenhagen,Lisbon]            1        -6939
# small[Copenhagen,Oslo]            0        -1350
# small[Copenhagen,Berlin]            1       -994.5
# small[Copenhagen,Prague]            0        -1782
# small[Copenhagen,Helsinki]            0      -2470.5
# small[Copenhagen,Geneva]            0        -3204
# small[Copenhagen,Hamburg]            0         -810
# small[Copenhagen,Edinburgh]            1        -2754
# small[Copenhagen,Milan/Bergamo]            1      -3163.5
# small[Copenhagen,Stockholm]           -0        -1458
# small[Copenhagen,Malaga]            1      -6898.5
# small[Copenhagen,Athens]            0        -5976
# small[Copenhagen,Nice]            1      -3874.5
# small[Copenhagen,Lyon]            1        -3438
# small[Copenhagen,Birmingham]            1      -2821.5
# small[Copenhagen,Saint Petersburg]            0      -3217.5
# small[Copenhagen,Warsaw]            0        -1881
# small[Copenhagen,Cologne/Bonn]            1      -1804.5
# small[Copenhagen,Alicante]            1        -6039
# small[Copenhagen,Stuttgart]            1        -2241
# small[Copenhagen,Budapest]            1        -2835
# small[Copenhagen,Kyiv]            1      -3721.5
# small[Copenhagen,Bucharest]            1      -4405.5
# small[Copenhagen,Porto]            1        -6246
# small[Copenhagen,Trondheim]           -0      -2434.5
# small[Manchester,Amsterdam]           -0      -1381.5
# small[Manchester,London]            1       -733.5
# small[Manchester,Paris]           -0        -1692
# small[Manchester,Frankfurt]            1        -2349
# small[Manchester,Madrid]            0        -4068
# small[Manchester,Istanbul]            0        -7569
# small[Manchester,Moscow]           -0      -7132.5
# small[Manchester,Rome]            1        -4725
# small[Manchester,Zurich]            1      -2857.5
# small[Manchester,Vienna]            1      -4000.5
# small[Manchester,Dublin]            0         -747
# small[Manchester,Dusseldorf]            1        -1854
# small[Manchester,Copenhagen]            0      -2758.5
# small[Manchester,Milan]            0        -3393
# small[Manchester,Palma de Mallorca]            0        -4446
# small[Manchester,Lisbon]            0      -4819.5
# small[Manchester,Oslo]            0      -2983.5
# small[Manchester,Berlin]            0        -2943
# small[Manchester,Prague]            1      -3379.5
# small[Manchester,Helsinki]            0        -5040
# small[Manchester,Geneva]            1        -2817
# small[Manchester,Hamburg]            1        -2268
# small[Manchester,Edinburgh]            0       -787.5
# small[Manchester,Milan/Bergamo]            1        -3411
# small[Manchester,Stockholm]            0      -3928.5
# small[Manchester,Malaga]            0      -5224.5
# small[Manchester,Athens]            0      -7348.5
# small[Manchester,Nice]            1        -3609
# small[Manchester,Lyon]            1        -2790
# small[Manchester,Birmingham]            0         -315
# small[Manchester,Saint Petersburg]            1      -5854.5
# small[Manchester,Warsaw]            1        -4374
# small[Manchester,Cologne/Bonn]            0      -1966.5
# small[Manchester,Alicante]            1        -4716
# small[Manchester,Stuttgart]            1        -2664
# small[Manchester,Budapest]            1        -4590
# small[Manchester,Kyiv]            1        -6309
# small[Manchester,Bucharest]            1        -6390
# small[Manchester,Porto]            1      -4054.5
# small[Manchester,Trondheim]           -0        -3708
# small[Milan,Amsterdam]            0      -2317.5
# small[Milan,London]            0        -2682
# small[Milan,Paris]            1        -1791
# small[Milan,Frankfurt]            1      -1444.5
# small[Milan,Madrid]            0      -3325.5
# small[Milan,Istanbul]            0      -4684.5
# small[Milan,Moscow]            0      -6403.5
# small[Milan,Rome]            0        -1332
# small[Milan,Zurich]            0       -607.5
# small[Milan,Vienna]            1      -1750.5
# small[Milan,Dublin]            0      -3964.5
# small[Milan,Dusseldorf]            1      -1858.5
# small[Milan,Copenhagen]            0      -3244.5
# small[Milan,Manchester]            0        -3393
# small[Milan,Palma de Mallorca]            0        -2367
# small[Milan,Lisbon]            1        -4716
# small[Milan,Oslo]            0        -4500
# small[Milan,Berlin]            0      -2353.5
# small[Milan,Prague]            0        -1800
# small[Milan,Helsinki]            0      -5422.5
# small[Milan,Geneva]            0       -697.5
# small[Milan,Hamburg]            1      -2515.5
# small[Milan,Edinburgh]            1        -4059
# small[Milan,Milan/Bergamo]            1       -121.5
# small[Milan,Stockholm]            0      -4621.5
# small[Milan,Malaga]            1        -4185
# small[Milan,Athens]            0      -4090.5
# small[Milan,Nice]            0         -693
# small[Milan,Lyon]            1         -954
# small[Milan,Birmingham]            1        -3141
# small[Milan,Saint Petersburg]            1      -5962.5
# small[Milan,Warsaw]            0      -3199.5
# small[Milan,Cologne/Bonn]            1        -1728
# small[Milan,Alicante]            1      -3145.5
# small[Milan,Stuttgart]            0        -1026
# small[Milan,Budapest]            0        -2205
# small[Milan,Kyiv]            1      -4693.5
# small[Milan,Bucharest]            1        -3735
# small[Milan,Porto]            1      -4243.5
# small[Milan,Trondheim]           -0      -5593.5
# small[Palma de Mallorca,Amsterdam]            0        -4005
# small[Palma de Mallorca,London]            1      -3757.5
# small[Palma de Mallorca,Paris]            1      -2884.5
# small[Palma de Mallorca,Frankfurt]            0      -3532.5
# small[Palma de Mallorca,Madrid]            1        -1539
# small[Palma de Mallorca,Istanbul]            0        -6246
# small[Palma de Mallorca,Moscow]            0      -8752.5
# small[Palma de Mallorca,Rome]            0        -2430
# small[Palma de Mallorca,Zurich]            1        -2763
# small[Palma de Mallorca,Vienna]            0      -4072.5
# small[Palma de Mallorca,Dublin]            1        -4680
# small[Palma de Mallorca,Dusseldorf]            0      -3730.5
# small[Palma de Mallorca,Copenhagen]            1      -5413.5
# small[Palma de Mallorca,Manchester]            1        -4446
# small[Palma de Mallorca,Milan]            1        -2367
# small[Palma de Mallorca,Lisbon]            1      -2857.5
# small[Palma de Mallorca,Oslo]            0      -6520.5
# small[Palma de Mallorca,Berlin]            0        -4635
# small[Palma de Mallorca,Prague]            1      -4162.5
# small[Palma de Mallorca,Helsinki]            1        -7731
# small[Palma de Mallorca,Geneva]            0        -2205
# small[Palma de Mallorca,Hamburg]            1      -4612.5
# small[Palma de Mallorca,Edinburgh]            1      -5233.5
# small[Palma de Mallorca,Milan/Bergamo]            1        -2484
# small[Palma de Mallorca,Stockholm]            0      -6853.5
# small[Palma de Mallorca,Malaga]            1        -1944
# small[Palma de Mallorca,Athens]            0        -5130
# small[Palma de Mallorca,Nice]            0      -1669.5
# small[Palma de Mallorca,Lyon]            0      -1984.5
# small[Palma de Mallorca,Birmingham]            1      -4126.5
# small[Palma de Mallorca,Saint Petersburg]            1      -8311.5
# small[Palma de Mallorca,Warsaw]            0      -5566.5
# small[Palma de Mallorca,Cologne/Bonn]           -0      -3640.5
# small[Palma de Mallorca,Alicante]            0         -846
# small[Palma de Mallorca,Stuttgart]            1      -3208.5
# small[Palma de Mallorca,Budapest]            1      -4432.5
# small[Palma de Mallorca,Kyiv]            1      -6952.5
# small[Palma de Mallorca,Bucharest]            1        -5616
# small[Palma de Mallorca,Porto]            1      -2713.5
# small[Palma de Mallorca,Trondheim]           -0        -7560
# small[Lisbon,Amsterdam]            0      -5215.5
# small[Lisbon,London]           -0      -4432.5
# small[Lisbon,Paris]            0        -4068
# small[Lisbon,Frankfurt]            0        -5292
# small[Lisbon,Madrid]           -0      -1408.5
# small[Lisbon,Istanbul]            1        -9072
# small[Lisbon,Moscow]            1       -10944
# small[Lisbon,Rome]            0      -5215.5
# small[Lisbon,Zurich]            0        -4824
# small[Lisbon,Vienna]            1      -6439.5
# small[Lisbon,Dublin]            0        -4590
# small[Lisbon,Dusseldorf]            0      -5215.5
# small[Lisbon,Copenhagen]            1        -6939
# small[Lisbon,Manchester]            0      -4819.5
# small[Lisbon,Milan]            0        -4716
# small[Lisbon,Palma de Mallorca]            0      -2857.5
# small[Lisbon,Oslo]            0      -7663.5
# small[Lisbon,Berlin]            0        -6471
# small[Lisbon,Prague]            1        -6282
# small[Lisbon,Helsinki]            1        -9414
# small[Lisbon,Geneva]            1        -4203
# small[Lisbon,Hamburg]            1      -6151.5
# small[Lisbon,Edinburgh]            1        -5499
# small[Lisbon,Milan/Bergamo]            1      -4837.5
# small[Lisbon,Stockholm]            0        -8370
# small[Lisbon,Malaga]            1        -1314
# small[Lisbon,Athens]            0        -7992
# small[Lisbon,Nice]            1      -4135.5
# small[Lisbon,Lyon]            1        -3888
# small[Lisbon,Birmingham]            1        -4554
# small[Lisbon,Saint Petersburg]            1       -10134
# small[Lisbon,Warsaw]            0      -7726.5
# small[Lisbon,Cologne/Bonn]            1        -5193
# small[Lisbon,Alicante]            0      -2110.5
# small[Lisbon,Stuttgart]            1      -5152.5
# small[Lisbon,Budapest]            1        -6921
# small[Lisbon,Kyiv]           -0      -9391.5
# small[Lisbon,Bucharest]            1      -8338.5
# small[Lisbon,Porto]            0         -765
# small[Lisbon,Trondheim]           -0      -8509.5
# small[Oslo,Amsterdam]            0      -2551.5
# small[Oslo,London]           -0        -3231
# small[Oslo,Paris]            1        -3753
# small[Oslo,Frankfurt]            0        -3069
# small[Oslo,Madrid]            0        -6678
# small[Oslo,Istanbul]           -0        -6849
# small[Oslo,Moscow]           -0      -4612.5
# small[Oslo,Rome]            0      -5611.5
# small[Oslo,Zurich]            0      -3919.5
# small[Oslo,Vienna]            1        -3780
# small[Oslo,Dublin]            0      -3541.5
# small[Oslo,Dusseldorf]            0        -2790
# small[Oslo,Copenhagen]            1        -1350
# small[Oslo,Manchester]            0      -2983.5
# small[Oslo,Milan]            0        -4500
# small[Oslo,Palma de Mallorca]            0      -6520.5
# small[Oslo,Lisbon]            0      -7663.5
# small[Oslo,Berlin]            0      -2344.5
# small[Oslo,Prague]            1      -3136.5
# small[Oslo,Helsinki]            1      -2209.5
# small[Oslo,Geneva]            0        -4347
# small[Oslo,Hamburg]            0      -1984.5
# small[Oslo,Edinburgh]            1      -2605.5
# small[Oslo,Milan/Bergamo]            1      -4432.5
# small[Oslo,Stockholm]           -0        -1170
# small[Oslo,Malaga]            1        -7821
# small[Oslo,Athens]            0      -7285.5
# small[Oslo,Nice]            1        -5085
# small[Oslo,Lyon]            1        -4536
# small[Oslo,Birmingham]            1        -3177
# small[Oslo,Saint Petersburg]            1      -3046.5
# small[Oslo,Warsaw]            0      -2974.5
# small[Oslo,Cologne/Bonn]            1      -2884.5
# small[Oslo,Alicante]            1        -7065
# small[Oslo,Stuttgart]            1        -3474
# small[Oslo,Budapest]            1        -4149
# small[Oslo,Kyiv]            1      -4558.5
# small[Oslo,Bucharest]            1        -5607
# small[Oslo,Porto]            1      -6925.5
# small[Oslo,Trondheim]           -0      -1093.5
# small[Berlin,Amsterdam]            0        -1611
# small[Berlin,London]            0      -2605.5
# small[Berlin,Paris]            0      -2452.5
# small[Berlin,Frankfurt]            0      -1183.5
# small[Berlin,Madrid]            0        -5229
# small[Berlin,Istanbul]            1      -4864.5
# small[Berlin,Moscow]            0      -4513.5
# small[Berlin,Rome]            1      -3307.5
# small[Berlin,Zurich]           -0      -1867.5
# small[Berlin,Vienna]            1      -1462.5
# small[Berlin,Dublin]            0        -3690
# small[Berlin,Dusseldorf]            1        -1332
# small[Berlin,Copenhagen]           -0       -994.5
# small[Berlin,Manchester]            0        -2943
# small[Berlin,Milan]            0      -2353.5
# small[Berlin,Palma de Mallorca]            0        -4635
# small[Berlin,Lisbon]            0        -6471
# small[Berlin,Oslo]            0      -2344.5
# small[Berlin,Prague]            0       -787.5
# small[Berlin,Helsinki]            1        -3096
# small[Berlin,Geneva]            1        -2448
# small[Berlin,Hamburg]            0         -711
# small[Berlin,Edinburgh]            1        -3195
# small[Berlin,Milan/Bergamo]           -0      -2254.5
# small[Berlin,Stockholm]            0        -2268
# small[Berlin,Malaga]            1        -6264
# small[Berlin,Athens]            0        -5040
# small[Berlin,Nice]            1      -3019.5
# small[Berlin,Lyon]           -0        -2727
# small[Berlin,Birmingham]            1        -2898
# small[Berlin,Saint Petersburg]            1        -3717
# small[Berlin,Warsaw]            0        -1449
# small[Berlin,Cologne/Bonn]            1      -1309.5
# small[Berlin,Alicante]            1        -5328
# small[Berlin,Stuttgart]            1      -1426.5
# small[Berlin,Budapest]            0        -1926
# small[Berlin,Kyiv]            1      -3379.5
# small[Berlin,Bucharest]            1      -3622.5
# small[Berlin,Porto]           -0        -5832
# small[Berlin,Trondheim]           -0      -3433.5
# small[Prague,Amsterdam]            0        -1998
# small[Prague,London]           -0      -2902.5
# small[Prague,Paris]            0        -2475
# small[Prague,Frankfurt]            0        -1152
# small[Prague,Madrid]           -0      -4963.5
# small[Prague,Istanbul]            1        -4221
# small[Prague,Moscow]            0      -4675.5
# small[Prague,Rome]            0      -2569.5
# small[Prague,Zurich]            0      -1471.5
# small[Prague,Vienna]            0         -693
# small[Prague,Dublin]            0        -4113
# small[Prague,Dusseldorf]            0        -1557
# small[Prague,Copenhagen]            1        -1782
# small[Prague,Manchester]            1      -3379.5
# small[Prague,Milan]            0        -1800
# small[Prague,Palma de Mallorca]            1      -4162.5
# small[Prague,Lisbon]            0        -6282
# small[Prague,Oslo]            0      -3136.5
# small[Prague,Berlin]            0       -787.5
# small[Prague,Helsinki]            1      -3649.5
# small[Prague,Geneva]            1        -2097
# small[Prague,Hamburg]            1      -1381.5
# small[Prague,Edinburgh]           -0      -3766.5
# small[Prague,Milan/Bergamo]            1      -1687.5
# small[Prague,Stockholm]            1        -2952
# small[Prague,Malaga]            1      -5917.5
# small[Prague,Athens]            1      -4279.5
# small[Prague,Nice]            1        -2493
# small[Prague,Lyon]           -0      -2407.5
# small[Prague,Birmingham]           -0        -3267
# small[Prague,Saint Petersburg]            1      -4162.5
# small[Prague,Warsaw]            1        -1449
# small[Prague,Cologne/Bonn]           -0      -1471.5
# small[Prague,Alicante]           -0      -4918.5
# small[Prague,Stuttgart]            1      -1138.5
# small[Prague,Budapest]            1        -1233
# small[Prague,Kyiv]           -0      -3199.5
# small[Prague,Bucharest]           -0        -3015
# small[Prague,Porto]           -0        -5706
# small[Prague,Trondheim]           -0      -4216.5
# small[Helsinki,Amsterdam]            0      -4207.5
# small[Helsinki,London]            0        -5103
# small[Helsinki,Paris]            0        -5346
# small[Helsinki,Frankfurt]            0      -4243.5
# small[Helsinki,Madrid]            1        -8253
# small[Helsinki,Istanbul]            1      -6007.5
# small[Helsinki,Moscow]            1        -2502
# small[Helsinki,Rome]            0      -6160.5
# small[Helsinki,Zurich]            0        -4968
# small[Helsinki,Vienna]            0      -4027.5
# small[Helsinki,Dublin]            0      -5674.5
# small[Helsinki,Dusseldorf]            1      -4207.5
# small[Helsinki,Copenhagen]            0      -2470.5
# small[Helsinki,Manchester]            0        -5040
# small[Helsinki,Milan]            1      -5422.5
# small[Helsinki,Palma de Mallorca]            0        -7731
# small[Helsinki,Lisbon]            1        -9414
# small[Helsinki,Oslo]            0      -2209.5
# small[Helsinki,Berlin]            1        -3096
# small[Helsinki,Prague]            1      -3649.5
# small[Helsinki,Geneva]            1        -5544
# small[Helsinki,Hamburg]            1      -3262.5
# small[Helsinki,Edinburgh]            1      -4783.5
# small[Helsinki,Milan/Bergamo]            1      -5314.5
# small[Helsinki,Stockholm]            0        -1107
# small[Helsinki,Malaga]           -0      -9328.5
# small[Helsinki,Athens]            0      -6898.5
# small[Helsinki,Nice]            1        -6102
# small[Helsinki,Lyon]           -0        -5814
# small[Helsinki,Birmingham]           -0      -5170.5
# small[Helsinki,Saint Petersburg]            0         -837
# small[Helsinki,Warsaw]            1      -2560.5
# small[Helsinki,Cologne/Bonn]           -0        -4248
# small[Helsinki,Alicante]            1      -8419.5
# small[Helsinki,Stuttgart]           -0        -4527
# small[Helsinki,Budapest]           -0      -4081.5
# small[Helsinki,Kyiv]            1        -3177
# small[Helsinki,Bucharest]            1        -4896
# small[Helsinki,Porto]           -0      -8716.5
# small[Helsinki,Trondheim]           -0        -2367
# small[Geneva,Amsterdam]            0        -1935
# small[Geneva,London]            0        -2088
# small[Geneva,Paris]            0      -1147.5
# small[Geneva,Frankfurt]            0        -1323
# small[Geneva,Madrid]           -0        -2862
# small[Geneva,Istanbul]            0        -5373
# small[Geneva,Moscow]            1        -6777
# small[Geneva,Rome]            0      -1948.5
# small[Geneva,Zurich]            0       -625.5
# small[Geneva,Vienna]            1        -2250
# small[Geneva,Dublin]            0      -3334.5
# small[Geneva,Dusseldorf]            0        -1566
# small[Geneva,Copenhagen]            0        -3204
# small[Geneva,Manchester]            1        -2817
# small[Geneva,Milan]            0       -697.5
# small[Geneva,Palma de Mallorca]            0        -2205
# small[Geneva,Lisbon]            0        -4203
# small[Geneva,Oslo]            1        -4347
# small[Geneva,Berlin]            1        -2448
# small[Geneva,Prague]            1        -2097
# small[Geneva,Helsinki]            1        -5544
# small[Geneva,Hamburg]            1        -2412
# small[Geneva,Edinburgh]           -0      -3532.5
# small[Geneva,Milan/Bergamo]            1         -783
# small[Geneva,Stockholm]            1        -4644
# small[Geneva,Malaga]            1        -3834
# small[Geneva,Athens]            1      -4783.5
# small[Geneva,Nice]            1       -814.5
# small[Geneva,Lyon]            1         -315
# small[Geneva,Birmingham]           -0      -2542.5
# small[Geneva,Saint Petersburg]           -0      -6160.5
# small[Geneva,Warsaw]            1      -3550.5
# small[Geneva,Cologne/Bonn]            1      -1462.5
# small[Geneva,Alicante]           -0      -2875.5
# small[Geneva,Stuttgart]           -0      -1021.5
# small[Geneva,Budapest]           -0        -2772
# small[Geneva,Kyiv]           -0      -5197.5
# small[Geneva,Bucharest]           -0      -4396.5
# small[Geneva,Porto]           -0      -3667.5
# small[Geneva,Trondheim]           -0      -5413.5
# small[Hamburg,Amsterdam]            0        -1026
# small[Hamburg,London]            0      -2020.5
# small[Hamburg,Paris]            0      -2083.5
# small[Hamburg,Frankfurt]            0        -1098
# small[Hamburg,Madrid]            1        -4995
# small[Hamburg,Istanbul]            0      -5557.5
# small[Hamburg,Moscow]            1        -4995
# small[Hamburg,Rome]            0      -3658.5
# small[Hamburg,Zurich]            0      -1939.5
# small[Hamburg,Vienna]            1        -2079
# small[Hamburg,Dublin]            0      -3010.5
# small[Hamburg,Dusseldorf]            0         -945
# small[Hamburg,Copenhagen]            0         -810
# small[Hamburg,Manchester]            1        -2268
# small[Hamburg,Milan]            1      -2515.5
# small[Hamburg,Palma de Mallorca]            0      -4612.5
# small[Hamburg,Lisbon]            1      -6151.5
# small[Hamburg,Oslo]            0      -1984.5
# small[Hamburg,Berlin]            0         -711
# small[Hamburg,Prague]            1      -1381.5
# small[Hamburg,Helsinki]            1      -3262.5
# small[Hamburg,Geneva]           -0        -2412
# small[Hamburg,Edinburgh]           -0        -2484
# small[Hamburg,Milan/Bergamo]           -0        -2448
# small[Hamburg,Stockholm]            1        -2268
# small[Hamburg,Malaga]            1      -6088.5
# small[Hamburg,Athens]            1        -5661
# small[Hamburg,Nice]           -0      -3109.5
# small[Hamburg,Lyon]           -0      -2632.5
# ...
# Num_of_pass_[Alicante,Istanbul]          100        157.3
# Num_of_pass_[Alicante,Moscow]           87        212.3
# Num_of_pass_[Alicante,Rome]          100         72.8
# Num_of_pass_[Alicante,Zurich]           50         77.2
# Num_of_pass_[Alicante,Vienna]           50        108.5
# Num_of_pass_[Alicante,Dublin]           50        107.2
# Num_of_pass_[Alicante,Dusseldorf]           50         95.7
# Num_of_pass_[Alicante,Copenhagen]           50        134.2
# Num_of_pass_[Alicante,Manchester]           50        104.8
# Num_of_pass_[Alicante,Milan]           50         69.9
# Num_of_pass_[Alicante,Palma de Mallorca]          100         18.8
# Num_of_pass_[Alicante,Lisbon]           85         46.9
# Num_of_pass_[Alicante,Oslo]           50          157
# Num_of_pass_[Alicante,Berlin]           -0        118.4
# Num_of_pass_[Alicante,Prague]           -0        109.3
# Num_of_pass_[Alicante,Helsinki]           49        187.1
# Num_of_pass_[Alicante,Geneva]           -0         63.9
# Num_of_pass_[Alicante,Hamburg]           -0        116.2
# Num_of_pass_[Alicante,Edinburgh]           -0        122.2
# Num_of_pass_[Alicante,Milan/Bergamo]           -0         72.6
# Num_of_pass_[Alicante,Stockholm]           48        166.5
# Num_of_pass_[Alicante,Malaga]           50         24.3
# Num_of_pass_[Alicante,Athens]           50        131.5
# Num_of_pass_[Alicante,Nice]           -0         54.8
# Num_of_pass_[Alicante,Lyon]           -0         57.9
# Num_of_pass_[Alicante,Birmingham]           -0         97.8
# Num_of_pass_[Alicante,Saint Petersburg]           -0        200.8
# Num_of_pass_[Alicante,Warsaw]           -0          141
# Num_of_pass_[Alicante,Cologne/Bonn]           -0         94.1
# Num_of_pass_[Alicante,Stuttgart]           -0         86.7
# Num_of_pass_[Alicante,Budapest]           -0          117
# Num_of_pass_[Alicante,Kyiv]           -0          173
# Num_of_pass_[Alicante,Bucharest]           -0        143.7
# Num_of_pass_[Alicante,Porto]           50         47.3
# Num_of_pass_[Alicante,Trondheim]           -0        179.2
# Num_of_pass_[Stuttgart,Amsterdam]          188         31.1
# Num_of_pass_[Stuttgart,London]          195         45.3
# Num_of_pass_[Stuttgart,Paris]          150         31.1
# Num_of_pass_[Stuttgart,Frankfurt]          200          9.4
# Num_of_pass_[Stuttgart,Madrid]          100         85.6
# Num_of_pass_[Stuttgart,Istanbul]          100        110.4
# Num_of_pass_[Stuttgart,Moscow]          100        128.7
# Num_of_pass_[Stuttgart,Rome]           50         50.1
# Num_of_pass_[Stuttgart,Zurich]           50         10.1
# Num_of_pass_[Stuttgart,Vienna]           90         33.2
# Num_of_pass_[Stuttgart,Dublin]           50         74.1
# Num_of_pass_[Stuttgart,Dusseldorf]           50           20
# Num_of_pass_[Stuttgart,Copenhagen]           50         49.8
# Num_of_pass_[Stuttgart,Manchester]           50         59.2
# Num_of_pass_[Stuttgart,Milan]           50         22.8
# Num_of_pass_[Stuttgart,Palma de Mallorca]           50         71.3
# Num_of_pass_[Stuttgart,Lisbon]           48        114.5
# Num_of_pass_[Stuttgart,Oslo]           50         77.2
# Num_of_pass_[Stuttgart,Berlin]           50         31.7
# Num_of_pass_[Stuttgart,Prague]           50         25.3
# Num_of_pass_[Stuttgart,Helsinki]           50        100.6
# Num_of_pass_[Stuttgart,Geneva]           50         22.7
# Num_of_pass_[Stuttgart,Hamburg]           50         33.1
# Num_of_pass_[Stuttgart,Edinburgh]           -0         71.9
# Num_of_pass_[Stuttgart,Milan/Bergamo]           -0         21.6
# Num_of_pass_[Stuttgart,Stockholm]           -0         81.2
# Num_of_pass_[Stuttgart,Malaga]           -0        107.8
# Num_of_pass_[Stuttgart,Athens]           -0        104.1
# Num_of_pass_[Stuttgart,Nice]           -0         36.2
# Num_of_pass_[Stuttgart,Lyon]           -0         29.2
# Num_of_pass_[Stuttgart,Birmingham]           -0         54.9
# Num_of_pass_[Stuttgart,Saint Petersburg]           -0        114.1
# Num_of_pass_[Stuttgart,Warsaw]           -0         57.2
# Num_of_pass_[Stuttgart,Cologne/Bonn]           -0           17
# Num_of_pass_[Stuttgart,Alicante]           -0         86.7
# Num_of_pass_[Stuttgart,Budapest]           -0         46.4
# Num_of_pass_[Stuttgart,Kyiv]           -0         96.2
# Num_of_pass_[Stuttgart,Bucharest]           -0         85.7
# Num_of_pass_[Stuttgart,Porto]           -0        101.5
# Num_of_pass_[Stuttgart,Trondheim]           -0        101.4
# Num_of_pass_[Budapest,Amsterdam]          100         71.3
# Num_of_pass_[Budapest,London]          197         90.3
# Num_of_pass_[Budapest,Paris]          189         77.5
# Num_of_pass_[Budapest,Frankfurt]          189         50.5
# Num_of_pass_[Budapest,Madrid]          150        122.9
# Num_of_pass_[Budapest,Istanbul]          100         66.4
# Num_of_pass_[Budapest,Moscow]          100         97.7
# Num_of_pass_[Budapest,Rome]           98         50.3
# Num_of_pass_[Budapest,Zurich]          100         49.1
# Num_of_pass_[Budapest,Vienna]          100         13.3
# Num_of_pass_[Budapest,Dublin]           50          118
# Num_of_pass_[Budapest,Dusseldorf]           50         60.9
# Num_of_pass_[Budapest,Copenhagen]           50           63
# Num_of_pass_[Budapest,Manchester]           50          102
# Num_of_pass_[Budapest,Milan]           95           49
# Num_of_pass_[Budapest,Palma de Mallorca]           50         98.5
# Num_of_pass_[Budapest,Lisbon]           87        153.8
# Num_of_pass_[Budapest,Oslo]           50         92.2
# Num_of_pass_[Budapest,Berlin]           89         42.8
# Num_of_pass_[Budapest,Prague]           50         27.4
# Num_of_pass_[Budapest,Helsinki]           50         90.7
# Num_of_pass_[Budapest,Geneva]           -0         61.6
# Num_of_pass_[Budapest,Hamburg]           49         57.6
# Num_of_pass_[Budapest,Edinburgh]           -0        111.1
# Num_of_pass_[Budapest,Milan/Bergamo]           50         46.2
# Num_of_pass_[Budapest,Stockholm]           50         81.8
# Num_of_pass_[Budapest,Malaga]           50        140.8
# Num_of_pass_[Budapest,Athens]           50         69.8
# Num_of_pass_[Budapest,Nice]           -0         62.7
# Num_of_pass_[Budapest,Lyon]           -0         68.5
# Num_of_pass_[Budapest,Birmingham]           -0           99
# Num_of_pass_[Budapest,Saint Petersburg]           50         97.3
# Num_of_pass_[Budapest,Warsaw]           50         33.8
# Num_of_pass_[Budapest,Cologne/Bonn]           -0         58.6
# Num_of_pass_[Budapest,Alicante]           -0          117
# Num_of_pass_[Budapest,Stuttgart]           -0         46.4
# Num_of_pass_[Budapest,Kyiv]           -0           56
# Num_of_pass_[Budapest,Bucharest]           50           40
# Num_of_pass_[Budapest,Porto]           -0          143
# Num_of_pass_[Budapest,Trondheim]           -0          115
# Num_of_pass_[Kyiv,Amsterdam]          190          111
# Num_of_pass_[Kyiv,London]          150        132.9
# Num_of_pass_[Kyiv,Paris]          195        126.1
# Num_of_pass_[Kyiv,Frankfurt]          150         96.4
# Num_of_pass_[Kyiv,Madrid]          100        178.2
# Num_of_pass_[Kyiv,Istanbul]          100         65.6
# Num_of_pass_[Kyiv,Moscow]          150           47
# Num_of_pass_[Kyiv,Rome]          100        104.3
# Num_of_pass_[Kyiv,Zurich]           50        101.9
# Num_of_pass_[Kyiv,Vienna]           50         65.6
# Num_of_pass_[Kyiv,Dublin]           50        156.8
# Num_of_pass_[Kyiv,Dusseldorf]           50        103.6
# Num_of_pass_[Kyiv,Copenhagen]           50         82.7
# Num_of_pass_[Kyiv,Manchester]           50        140.2
# Num_of_pass_[Kyiv,Milan]           50        104.3
# Num_of_pass_[Kyiv,Palma de Mallorca]           50        154.5
# Num_of_pass_[Kyiv,Lisbon]           -0        208.7
# Num_of_pass_[Kyiv,Oslo]           50        101.3
# Num_of_pass_[Kyiv,Berlin]           48         75.1
# Num_of_pass_[Kyiv,Prague]           -0         71.1
# Num_of_pass_[Kyiv,Helsinki]           50         70.6
# Num_of_pass_[Kyiv,Geneva]           -0        115.5
# Num_of_pass_[Kyiv,Hamburg]           -0         89.8
# Num_of_pass_[Kyiv,Edinburgh]           -0        143.4
# Num_of_pass_[Kyiv,Milan/Bergamo]           -0        101.6
# Num_of_pass_[Kyiv,Stockholm]           50         78.6
# Num_of_pass_[Kyiv,Malaga]           -0        196.7
# Num_of_pass_[Kyiv,Athens]           50         92.3
# Num_of_pass_[Kyiv,Nice]           -0        118.6
# Num_of_pass_[Kyiv,Lyon]           -0        122.5
# Num_of_pass_[Kyiv,Birmingham]           -0        139.5
# Num_of_pass_[Kyiv,Saint Petersburg]           -0         65.6
# Num_of_pass_[Kyiv,Warsaw]           50         42.9
# Num_of_pass_[Kyiv,Cologne/Bonn]           -0        102.3
# Num_of_pass_[Kyiv,Alicante]           -0          173
# Num_of_pass_[Kyiv,Stuttgart]           -0         96.2
# Num_of_pass_[Kyiv,Budapest]           -0           56
# Num_of_pass_[Kyiv,Bucharest]           50         46.4
# Num_of_pass_[Kyiv,Porto]           -0          197
# Num_of_pass_[Kyiv,Trondheim]           -0        116.7
# Num_of_pass_[Bucharest,Amsterdam]          150        111.3
# Num_of_pass_[Bucharest,London]          150        130.2
# Num_of_pass_[Bucharest,Paris]          193        116.5
# Num_of_pass_[Bucharest,Frankfurt]          100         90.5
# Num_of_pass_[Bucharest,Madrid]          150          154
# Num_of_pass_[Bucharest,Istanbul]          150         27.7
# Num_of_pass_[Bucharest,Moscow]          100         93.1
# Num_of_pass_[Bucharest,Rome]           99         70.9
# Num_of_pass_[Bucharest,Zurich]           50         86.8
# Num_of_pass_[Bucharest,Vienna]           50         53.2
# Num_of_pass_[Bucharest,Dublin]           50          158
# Num_of_pass_[Bucharest,Dusseldorf]           50        100.9
# Num_of_pass_[Bucharest,Copenhagen]           50         97.9
# Num_of_pass_[Bucharest,Manchester]           50          142
# Num_of_pass_[Bucharest,Milan]           50           83
# Num_of_pass_[Bucharest,Palma de Mallorca]           50        124.8
# Num_of_pass_[Bucharest,Lisbon]           50        185.3
# Num_of_pass_[Bucharest,Oslo]           50        124.6
# Num_of_pass_[Bucharest,Berlin]           50         80.5
# Num_of_pass_[Bucharest,Prague]           -0           67
# Num_of_pass_[Bucharest,Helsinki]           48        108.8
# Num_of_pass_[Bucharest,Geneva]           47         97.7
# Num_of_pass_[Bucharest,Hamburg]           -0         96.1
# Num_of_pass_[Bucharest,Edinburgh]           -0        150.6
# Num_of_pass_[Bucharest,Milan/Bergamo]           -0         80.6
# Num_of_pass_[Bucharest,Stockholm]           50        108.3
# Num_of_pass_[Bucharest,Malaga]           48          168
# Num_of_pass_[Bucharest,Athens]           50         46.2
# Num_of_pass_[Bucharest,Nice]           -0         93.6
# Num_of_pass_[Bucharest,Lyon]           -0        104.1
# Num_of_pass_[Bucharest,Birmingham]           -0          139
# Num_of_pass_[Bucharest,Saint Petersburg]           50        108.6
# Num_of_pass_[Bucharest,Warsaw]           -0         58.7
# Num_of_pass_[Bucharest,Cologne/Bonn]           -0         98.6
# Num_of_pass_[Bucharest,Alicante]           -0        143.7
# Num_of_pass_[Bucharest,Stuttgart]           -0         85.7
# Num_of_pass_[Bucharest,Budapest]           50           40
# Num_of_pass_[Bucharest,Kyiv]           50         46.4
# Num_of_pass_[Bucharest,Porto]           -0        176.5
# Num_of_pass_[Bucharest,Trondheim]           -0        145.2
# Num_of_pass_[Porto,Amsterdam]          100        100.2
# Num_of_pass_[Porto,London]          189         82.1
# Num_of_pass_[Porto,Paris]          100         75.4
# Num_of_pass_[Porto,Frankfurt]          100        103.7
# Num_of_pass_[Porto,Madrid]          185         26.2
# Num_of_pass_[Porto,Istanbul]          100        194.6
# Num_of_pass_[Porto,Moscow]           50        229.7
# Num_of_pass_[Porto,Rome]           94        109.2
# Num_of_pass_[Porto,Zurich]           50           95
# Num_of_pass_[Porto,Vienna]           50        131.6
# Num_of_pass_[Porto,Dublin]           50         84.9
# Num_of_pass_[Porto,Dusseldorf]           50          101
# Num_of_pass_[Porto,Copenhagen]           50        138.8
# Num_of_pass_[Porto,Manchester]           50         90.1
# Num_of_pass_[Porto,Milan]           50         94.3
# Num_of_pass_[Porto,Palma de Mallorca]           50         60.3
# Num_of_pass_[Porto,Lisbon]           91           17
# Num_of_pass_[Porto,Oslo]           50        153.9
# Num_of_pass_[Porto,Berlin]           50        129.6
# Num_of_pass_[Porto,Prague]           -0        126.8
# Num_of_pass_[Porto,Helsinki]           48        193.7
# Num_of_pass_[Porto,Geneva]           -0         81.5
# Num_of_pass_[Porto,Hamburg]           -0        121.6
# Num_of_pass_[Porto,Edinburgh]           -0        105.1
# Num_of_pass_[Porto,Milan/Bergamo]           -0         96.9
# Num_of_pass_[Porto,Stockholm]           -0        170.2
# Num_of_pass_[Porto,Malaga]           50         37.9
# Num_of_pass_[Porto,Athens]           -0          173
# Num_of_pass_[Porto,Nice]           -0         82.9
# Num_of_pass_[Porto,Lyon]           -0         74.5
# Num_of_pass_[Porto,Birmingham]           -0         84.3
# Num_of_pass_[Porto,Saint Petersburg]           -0        210.1
# Num_of_pass_[Porto,Warsaw]           -0        158.6
# Num_of_pass_[Porto,Cologne/Bonn]           -0        100.8
# Num_of_pass_[Porto,Alicante]           50         47.3
# Num_of_pass_[Porto,Stuttgart]           -0        101.5
# Num_of_pass_[Porto,Budapest]           -0          143
# Num_of_pass_[Porto,Kyiv]           -0          197
# Num_of_pass_[Porto,Bucharest]           -0        176.5
# Num_of_pass_[Porto,Trondheim]           -0        172.3
# Num_of_pass_[Trondheim,Amsterdam]           -0           79
# Num_of_pass_[Trondheim,London]           50           91
# Num_of_pass_[Trondheim,Paris]           -0        105.3
# Num_of_pass_[Trondheim,Frankfurt]           -0         92.3
# Num_of_pass_[Trondheim,Madrid]           -0        169.2
# Num_of_pass_[Trondheim,Istanbul]           -0        172.4
# Num_of_pass_[Trondheim,Moscow]           -0        108.1
# Num_of_pass_[Trondheim,Rome]           -0        149.1
# Num_of_pass_[Trondheim,Zurich]           -0        111.2
# Num_of_pass_[Trondheim,Vienna]           -0        107.7
# Num_of_pass_[Trondheim,Dublin]           -0         91.8
# Num_of_pass_[Trondheim,Dusseldorf]           -0         85.5
# Num_of_pass_[Trondheim,Copenhagen]           -0         54.1
# Num_of_pass_[Trondheim,Manchester]           -0         82.4
# Num_of_pass_[Trondheim,Milan]           -0        124.3
# Num_of_pass_[Trondheim,Palma de Mallorca]           -0          168
# Num_of_pass_[Trondheim,Lisbon]           -0        189.1
# Num_of_pass_[Trondheim,Oslo]           -0         24.3
# Num_of_pass_[Trondheim,Berlin]           -0         76.3
# Num_of_pass_[Trondheim,Prague]           -0         93.7
# Num_of_pass_[Trondheim,Helsinki]           -0         52.6
# Num_of_pass_[Trondheim,Geneva]           -0        120.3
# Num_of_pass_[Trondheim,Hamburg]           -0         68.3
# Num_of_pass_[Trondheim,Edinburgh]           -0         69.9
# Num_of_pass_[Trondheim,Milan/Bergamo]           -0        122.8
# Num_of_pass_[Trondheim,Stockholm]           -0         38.1
# Num_of_pass_[Trondheim,Malaga]           -0        194.8
# Num_of_pass_[Trondheim,Athens]           -0        184.4
# Num_of_pass_[Trondheim,Nice]           -0          137
# Num_of_pass_[Trondheim,Lyon]           -0        124.1
# Num_of_pass_[Trondheim,Birmingham]           -0         87.9
# Num_of_pass_[Trondheim,Saint Petersburg]           -0         69.5
# Num_of_pass_[Trondheim,Warsaw]           -0         86.5
# Num_of_pass_[Trondheim,Cologne/Bonn]           -0         87.7
# Num_of_pass_[Trondheim,Alicante]           -0        179.2
# Num_of_pass_[Trondheim,Stuttgart]           -0        101.4
# Num_of_pass_[Trondheim,Budapest]           -0          115
# Num_of_pass_[Trondheim,Kyiv]           -0        116.7
# Num_of_pass_[Trondheim,Bucharest]           -0        145.2
# Num_of_pass_[Trondheim,Porto]           -0        172.3

# %%
import gurobipy as gb
import pandas as pd

indirect_revenue_per_customer = dict()
cities = data['arrivalCity'].unique()

for first in cities:
    for second in cities:
        for third in cities:
            if first != second and first != third and second != third:
                if (first, second) in distances and (second, third) in distances:
                    if distances[(first, third)] * 1.3 >= distances[(first, second)] + distances[(second, third)]:
                        indirect_revenue_per_customer[(first, second, third)] = 0.08 * distances[(first, third)]

charge_indirect = 0.08

model2 = gb.Model()

cities = data['departureCity'].unique()

# Variables for direct and indirect flights
small_direct = model2.addVars(cities, cities, name="small_direct", vtype=gb.GRB.INTEGER, lb=0)
medium_direct = model2.addVars(cities, cities, name="medium_direct", vtype=gb.GRB.INTEGER, lb=0)
large_direct = model2.addVars(cities, cities, name="large_direct", vtype=gb.GRB.INTEGER, lb=0)

small_indirect = model2.addVars(indirect_revenue_per_customer.keys(), name="small_indirect", vtype=gb.GRB.INTEGER, lb=0)
medium_indirect = model2.addVars(indirect_revenue_per_customer.keys(), name="medium_indirect", vtype=gb.GRB.INTEGER, lb=0)
large_indirect = model2.addVars(indirect_revenue_per_customer.keys(), name="large_indirect", vtype=gb.GRB.INTEGER, lb=0)

num_of_passengers_direct = model2.addVars(cities, cities, name="Num_direct", vtype=gb.GRB.INTEGER, lb=0)
num_of_passengers_indirect = model2.addVars(indirect_revenue_per_customer.keys(), name="Num_indirect", vtype=gb.GRB.INTEGER, lb=0)

hub = model2.addVars(cities, name="hub", vtype=gb.GRB.BINARY, lb=0)

M = 1000000000

# Constraints for direct flights
model2.addConstrs(num_of_passengers_direct[(i, j)] <= demands[(i, j)] 
                 for i in cities for j in cities if i != j)

model2.addConstrs(num_of_passengers_direct[(i, j)] <= 
                 capacity["small"] * small_direct[(i, j)] + capacity["medium"] * medium_direct[(i, j)] + capacity["large"] * large_direct[(i, j)]
                 for i in cities for j in cities if i != j)

# Constraints for indirect flights
model2.addConstrs(num_of_passengers_indirect[(i, k, j)] <= demands[(i, j)] 
                 for (i, k, j) in indirect_revenue_per_customer)

model2.addConstrs(num_of_passengers_indirect[(i, k, j)] <= 
                 capacity["small"] * small_indirect[(i, k, j)] + capacity["medium"] * medium_indirect[(i, k, j)] + capacity["large"] * large_indirect[(i, k, j)]
                 for (i, k, j) in indirect_revenue_per_customer)

# Binary variables for direct routes
y_direct = model2.addVars(cities, cities, name="direct_used", vtype=gb.GRB.BINARY, lb=0)

# Binary variables for indirect routes
y_indirect = model2.addVars(indirect_revenue_per_customer.keys(), name="indirect_used", vtype=gb.GRB.BINARY, lb=0)

model2.addConstrs(y_direct.sum(i, j) + y_indirect.sum(i, '*', j) <= 1
                  for i in cities
                  for j in cities
                  for k in cities
                  if i != j and i != k and j != k)

#Only 1 hub

model2.addConstr(gb.quicksum(hub[k] for k in cities) == 1)

# Hub constraints

model2.addConstrs(y_indirect.sum('*', k, '*') <= hub[k] * M for k in cities for (i, k, j) in indirect_revenue_per_customer)

# Modified objective function with both direct and indirect flights
model2.setObjective(gb.quicksum(y_direct[i, j] * (charge * distances[(i, j)] * num_of_passengers_direct[(i, j)] - 
                                                  cost_per_mile["small"] * small_direct[(i, j)] - 
                                                  cost_per_mile["medium"] * medium_direct[(i, j)] - 
                                                  cost_per_mile["large"] * large_direct[(i, j)])
                               for i in cities for j in cities if i != j) +
                   gb.quicksum(y_indirect[i, k, j] * (charge_indirect * distances[(i, j)] * num_of_passengers_indirect[(i, k, j)] - 
                                                       cost_per_mile["small"] * small_indirect[(i, k, j)] - 
                                                       cost_per_mile["medium"] * medium_indirect[(i, k, j)] - 
                                                       cost_per_mile["large"] * large_indirect[(i, k, j)])
                               for (i, k, j) in indirect_revenue_per_customer),
                   gb.GRB.MAXIMIZE)

model2.optimize()
# Out:
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 800047 rows, 93656 columns and 398264159 nonzeros
# Model fingerprint: 0x3e390874
# Model has 74728 quadratic objective terms
# Variable types: 0 continuous, 93656 integer (18764 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [5e+00, 5e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 0 columns (presolve time = 180s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 194s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 200s) ...
#
# Interrupt request received

# %%
print("Optimal Objective Value 1:", model.ObjVal)
print("Optimal Objective Value 2:", model2.ObjVal)

# %%
# Assuming the optimization is successful
if model2.status == gb.GRB.OPTIMAL:
    selected_hub = None
    for (i, k, j) in indirect_revenue_per_customer:
        if round(y_indirect[i, k, j].x) == 1:
            selected_hub = k
            break

    if selected_hub is not None:
        print(f"The selected hub is: {selected_hub}")
    else:
        print("No hub is selected.")
else:
    print("Optimization was not successful.")
# Out:
# The selected hub is: Alicante

# %%
# Assuming the optimization is successful for Code 1
if model2.status == gb.GRB.OPTIMAL:
    # Extract variable values for direct flight passengers
    direct_passenger_values = model2.getAttr("X", num_of_passengers_direct.values())

    # Extract variable values for indirect flight passengers
    indirect_passenger_values = model2.getAttr("X", num_of_passengers_indirect.values())

    # Compute total number of passengers for each route
    total_passengers_direct = sum(direct_passenger_values)
    total_passengers_indirect = sum(indirect_passenger_values)

    # Compute overall total number of passengers
    total_passengers = total_passengers_direct + total_passengers_indirect

    print(f"Total number of passengers (direct): {total_passengers_direct}")
    print(f"Total number of passengers (indirect): {total_passengers_indirect}")
    print(f"Overall total number of passengers: {total_passengers}")
else:
    print("Optimization was not successful.")

# Assuming the optimization is successful for Code 2
if model.status == gb.GRB.OPTIMAL:
    # Extract variable values for direct flight passengers in Code 2
    direct_passenger_values_code2 = model.getAttr("X", num_of_passengers.values())

    # Compute total number of passengers for Code 2
    total_passengers_direct_code2 = sum(direct_passenger_values_code2)

    print(f"\nTotal number of passengers (direct) for Code 2: {total_passengers_direct_code2}")
else:
    print("Optimization was not successful.")

print(sum(demands.values()))
# Out:
# Total number of passengers (direct): 230116.0
# Total number of passengers (indirect): 41.0
# Overall total number of passengers: 230157.0
#
# Total number of passengers (direct) for Code 2: 203305.0
# 230850

# %%
# Assuming the optimization is successful for Code 1
if model2.status == gb.GRB.OPTIMAL:
    # Extract variable values for direct flights
    direct_flight_values = model2.getAttr("X", [small_direct, medium_direct, large_direct])

    # Extract variable values for indirect flights
    indirect_flight_values = model2.getAttr("X", [small_indirect, medium_indirect, large_indirect])

    # Compute total number of flights for each plane type
    total_flights_small = sum(direct_flight_values[0]) + sum(indirect_flight_values[0])
    total_flights_medium = sum(direct_flight_values[1]) + sum(indirect_flight_values[1])
    total_flights_large = sum(direct_flight_values[2]) + sum(indirect_flight_values[2])

    # Compute overall total number of flights
    total_flights = total_flights_small + total_flights_medium + total_flights_large

    print(f"Total number of flights (small): {total_flights_small}")
    print(f"Total number of flights (medium): {total_flights_medium}")
    print(f"Total number of flights (large): {total_flights_large}")
    print(f"Overall total number of flights: {total_flights}")
else:
    print("Optimization was not successful.")
