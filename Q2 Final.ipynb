# %%
import gurobipy as gb
import pandas as pd
import gurobipy as gb

# %%
df = pd.read_csv("~/Desktop/uni BAM/MS/Group Assignment/flights-1.csv",  encoding='latin-1')

issues = {"ZÃ¼rich": "Zurich",
          "DÃ¼sseldorf": "Dusseldorf", "MÃ¡laga": "Malaga"}
for key, value in issues.items():
    df.loc[df["departureCity"] == key, "departureCity"] = value
    df.loc[df["arrivalCity"] == key, "arrivalCity"] = value

# Joining the DataFrame with itself on the departure city
df2 = df.set_index('departureCity').join(df.set_index('departureCity'), lsuffix="first", rsuffix="second").reset_index()

# Filtering out rows where the arrival cities match
df2 = df2[df2.arrivalCityfirst != df2.arrivalCitysecond]

# Calculating the total distance as the sum of the distances from departure to hub and hub to arrival
df2["distance"] = df2.Distancefirst + df2.Distancesecond

# Selecting relevant columns
df2 = df2[["departureCity", "arrivalCityfirst", "arrivalCitysecond", "distance"]]

# Renaming columns
df2.columns = ["Hub", "arrivalCity", "departureCity", "Distance"]


merged_df = df2.merge(df[["departureCity", "arrivalCity", "Distance", "Demand"]],
               on=["departureCity", "arrivalCity"],
               how="left")

merged_df.columns = ["Hub", "arrivalCity", "departureCity", "IndirectDistance","DirectDistance", "Demand"]

merged_df["1.3times_Direct"] = 1.3 * merged_df["DirectDistance"]
merged_df = merged_df[["Hub", "arrivalCity", "departureCity", "IndirectDistance", "DirectDistance", "1.3times_Direct", "Demand"]]

merged_df.loc[merged_df["IndirectDistance"] >= merged_df["DirectDistance"] * 1.3, "Hub"] = ""
merged_df["RouteDistance"] = merged_df["DirectDistance"]

mask = merged_df["Hub"] != ""
merged_df.loc[mask, "RouteDistance"] = merged_df.loc[mask, "IndirectDistance"]
merged_df["IndirectUsed"] = (merged_df["Hub"] != "").astype(int) # Presence of a hub
merged_df = merged_df.drop_duplicates(subset = ["arrivalCity", "departureCity", "RouteDistance"])


flights=[]
for index,row in merged_df.iterrows():
    if row.Hub=="":
        flights.append((row.departureCity,row.arrivalCity))
    else:
        flights.append((row.departureCity,row.Hub))
        flights.append((row.Hub,row.departureCity))
flights=list(set(flights))#removing duplicates

ItineraryFlights = {}
for index, row in merged_df.iterrows():
    itflights = []
    if row.Hub == "":
        itflights.append((row.departureCity, row.arrivalCity))
        ItineraryFlights[row.departureCity, row.arrivalCity] = itflights
    else:
        itflights.append((row.departureCity, row.Hub))
        itflights.append((row.Hub, row.arrivalCity))
        ItineraryFlights[row.departureCity, row.arrivalCity] = itflights
        
Demand = {}
Distances = {}
for index,row in merged_df.iterrows():
    Demand[row.departureCity, row.arrivalCity] = row.Demand
    Distances[row.departureCity, row.arrivalCity, "Direct"] = row.DirectDistance
    if row.Hub != "":
        Distances[row.departureCity, row.Hub, row.arrivalCity, "Indirect"] = row.IndirectDistance
        
IndirectUsed = {}
for index,row in merged_df.iterrows():
    IndirectUsed[row.departureCity, row.arrivalCity] = row.IndirectUsed
    
HubCities = list(set(merged_df.Hub.unique()))
HubCities = HubCities[1:]

# Make a dictionary of all the demands for the destinations
demand = merged_df.set_index(['departureCity', 'arrivalCity'])['Demand'].to_dict()
indirect_demand = merged_df.set_index(['departureCity', 'Hub', 'arrivalCity'])['Demand'].to_dict()


# Make a dictionary of all the distances for the destinations
indirect_df=merged_df[merged_df['Hub']!='']
indirect_distance = indirect_df.set_index(['departureCity', 'arrivalCity'])[['IndirectDistance']].to_dict()
indirect_distances = indirect_distance['IndirectDistance']
direct_distances = merged_df.set_index(['departureCity', 'arrivalCity'])['DirectDistance'].to_dict()
indirect_routes = list(indirect_distances.keys())
direct_routes = list(direct_distances.keys())

route_distance = merged_df.set_index(['departureCity', 'Hub', 'arrivalCity'])['RouteDistance'].to_dict()
route_list = list(route_distance.keys())

# %%
charge_indirect = 0.08
charge_direct = 0.1
cost_per_mile = {"small":4.5, "medium":8, "large":20}
capacity = {"small":50, "medium":100, "large":300}

model_test = gb.Model("RevenueOptimization")

# Variables the number of each size of plane that is going to fly
small = model_test.addVars(ItineraryFlights.keys(), name = "small", vtype = gb.GRB.INTEGER, lb = 0)
medium = model_test.addVars(ItineraryFlights.keys(), name = "medium", vtype = gb.GRB.INTEGER, lb = 0)
large = model_test.addVars(ItineraryFlights.keys(), name = "large", vtype = gb.GRB.INTEGER, lb = 0)

direct_passengers = model_test.addVars(ItineraryFlights.keys(), name = "direct_pass", vtype = gb.GRB.INTEGER, lb = 0)
indirect_passengers = model_test.addVars(ItineraryFlights, name = "indirect_pass", vtype = gb.GRB.INTEGER, lb = 0)

hub = model_test.addVars(HubCities, name = "hub", vtype = gb.GRB.BINARY, lb = 0)

M = 1000000000000

model_test.setObjective(gb.quicksum(charge_direct * direct_distances[route] * direct_passengers[route] -
                                    direct_distances[route] * (cost_per_mile["small"] * small[route] +
                                                               cost_per_mile["medium"] * medium[route] +
                                                               cost_per_mile["large"] * large[route])
                                    for route in ItineraryFlights.keys()) +
                        gb.quicksum(charge_indirect * direct_distances[route] * indirect_passengers[route] -
                                    indirect_distances.get(route, 0) * (cost_per_mile["small"] * small[route] +
                                                                        cost_per_mile["medium"] * medium[route] +
                                                                        cost_per_mile["large"] * large[route])
                                    for route in ItineraryFlights) ,gb.GRB.MAXIMIZE)

# Objective Function
# Constraints

model_test.addConstrs((direct_passengers[route]) <= Demand[route]
                     for route in  ItineraryFlights.keys())
model_test.addConstrs((indirect_passengers[route]) <= Demand[route]
                     for route in ItineraryFlights.keys())
    
model_test.addConstrs((direct_passengers[route] + indirect_passengers[route]) <= Demand[route] 
                      for route in ItineraryFlights.keys())

model_test.addConstrs((direct_passengers[route] + indirect_passengers[route]) <= capacity["small"] * small[route] + capacity["medium"] * medium[route] + capacity["large"] * large[route]
                      for route in ItineraryFlights.keys())

for city in HubCities:
    model_test.addConstr(gb.quicksum(indirect_passengers[route] for route in ItineraryFlights.keys() if city in route) <= hub[city] * M)
model_test.addConstr(gb.quicksum(hub[k] for k in HubCities) == 2)

model_test.optimize()

if model_test.status == gb.GRB.OPTIMAL:

    selected_hubs = [city for city in HubCities if hub[city].x > 0.5]
    print("Selected Hubs:", selected_hubs)
else:
    print("Optimization was not successful.")
# Out:
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[rosetta2])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 6602 rows, 8241 columns and 18122 nonzeros
# Model fingerprint: 0x3d80cc66
# Variable types: 0 continuous, 8241 integer (41 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+12]
#   Objective range  [2e+00, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective -0.0000000
# Presolve removed 6601 rows and 8237 columns
# Presolve time: 0.48s
# Presolved: 1 rows, 4 columns, 4 nonzeros
# Found heuristic solution: objective 165652.40000
# Variable types: 0 continuous, 4 integer (1 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.51 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 165652 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.656524000000e+05, best bound 1.656524000000e+05, gap 0.0000%
# Selected Hubs: ['Dublin', 'London']

# %%
vals = model_test.printAttr(["X", "Obj"])
all_vars = model_test.getVars()

values = model_test.getAttr("X", all_vars)
names = model_test.getAttr("VarName", all_vars)

res = pd.DataFrame({"names": names, "values": values})

daily_profit = model_test.ObjVal

small_res = res[res["names"].str.startswith("small")]["values"].sum()
medium_res = res[res["names"].str.startswith("medium")]["values"].sum()
large_res = res[res["names"].str.startswith("large")]["values"].sum()
# Out:
#     Variable            X          Obj
# --------------------------------------
# small[Madrid,London]            0      -7429.5
# small[Paris,London]           -0       -958.5
# small[Frankfurt,London]            0      -4081.5
# small[Amsterdam,London]            1         -999
# small[Istanbul,London]            0       -14130
# small[Palma de Mallorca,London]            0      -7600.5
# small[Rome,London]            0        -8100
# small[Moscow,London]            0     -15331.5
# small[Lisbon,London]            0        -8892
# small[Zurich,London]            0      -4666.5
# small[Milan,London]            0        -5463
# small[Copenhagen,London]            0        -5508
# small[Manchester,London]            0        -1503
# small[Malaga,London]            0       -10089
# small[Vienna,London]            0        -7290
# small[Oslo,London]            0        -6948
# small[Dusseldorf,London]            0        -2907
# small[Dublin,London]            0      -2776.5
# small[Athens,London]            0     -13396.5
# small[Porto,London]            0        -8046
# small[Helsinki,London]            0     -11722.5
# small[Stockholm,London]            0        -8415
# small[Berlin,London]            0        -5337
# small[Prague,London]            0      -6547.5
# small[Hamburg,London]            0        -4311
# small[Warsaw,London]            0        -9153
# small[Budapest,London]            0      -8446.5
# small[Geneva,London]            0        -4194
# small[Kyiv,London]            0     -12739.5
# small[Bucharest,London]            0     -11938.5
# small[Birmingham,London]            0       -454.5
# small[Milan/Bergamo,London]            0      -5467.5
# small[Edinburgh,London]            0        -3015
# small[Nice,London]            0      -6223.5
# small[Cologne/Bonn,London]            0        -2907
# small[Saint Petersburg,London]            0       -12834
# small[Stuttgart,London]            0      -4666.5
# small[Lyon,London]            0      -4108.5
# small[Trondheim,London]            0      -8419.5
# small[London,Madrid]            0      -7429.5
# small[Paris,Madrid]            0        -6588
# small[Frankfurt,Madrid]            0      -8383.5
# small[Amsterdam,Madrid]            0        -9342
# small[Istanbul,Madrid]            0     -16114.5
# small[Palma de Mallorca,Madrid]            0      -3388.5
# small[Rome,Madrid]            0      -7789.5
# small[Moscow,Madrid]            0     -19273.5
# small[Lisbon,Madrid]            0      -1408.5
# small[Zurich,Madrid]            0        -7794
# small[Milan,Madrid]            0      -7420.5
# small[Copenhagen,Madrid]            0       -11988
# small[Manchester,Madrid]            0      -9301.5
# small[Malaga,Madrid]           -0      -1156.5
# small[Vienna,Madrid]            0     -10210.5
# small[Oslo,Madrid]            0       -14085
# small[Dusseldorf,Madrid]            0      -8779.5
# small[Dublin,Madrid]            0        -9054
# small[Athens,Madrid]            0       -14652
# small[Porto,Madrid]            0        -1179
# small[Helsinki,Madrid]            0     -16708.5
# small[Stockholm,Madrid]            0     -14854.5
# small[Berlin,Madrid]            0       -10584
# small[Prague,Madrid]            0     -10723.5
# small[Hamburg,Madrid]            0       -10422
# small[Warsaw,Madrid]            0     -12820.5
# small[Budapest,Madrid]            0     -11227.5
# small[Geneva,Madrid]            0        -6408
# small[Kyiv,Madrid]            0       -16092
# small[Bucharest,Madrid]            0     -14323.5
# small[Birmingham,Madrid]            0      -8113.5
# small[Milan/Bergamo,Madrid]            0      -7519.5
# small[Edinburgh,Madrid]            0       -10737
# small[Nice,Madrid]            0        -5940
# small[Cologne/Bonn,Madrid]            0        -8613
# small[Saint Petersburg,Madrid]            0       -17982
# small[Stuttgart,Madrid]            0        -7794
# small[Lyon,Madrid]            0      -5728.5
# small[Trondheim,Madrid]            0     -16105.5
# small[London,Paris]           -0       -958.5
# small[Madrid,Paris]            0        -6588
# small[Frankfurt,Paris]            0        -2997
# small[Amsterdam,Paris]           -0      -1201.5
# small[Istanbul,Paris]            0     -12640.5
# small[Palma de Mallorca,Paris]            0        -6471
# small[Rome,Paris]            0        -6372
# small[Moscow,Paris]            0     -14485.5
# small[Lisbon,Paris]            0        -8226
# small[Zurich,Paris]            0        -3141
# small[Milan,Paris]            0      -3766.5
# small[Copenhagen,Paris]            0        -6516
# small[Manchester,Paris]            0        -3411
# small[Malaga,Paris]            0      -9166.5
# small[Vienna,Paris]            0        -5922
# small[Oslo,Paris]            0      -8626.5
# small[Dusseldorf,Paris]            0        -2430
# small[Dublin,Paris]            0        -4626
# small[Athens,Paris]            0       -11763
# small[Porto,Paris]            0        -7515
# small[Helsinki,Paris]            0       -11682
# small[Stockholm,Paris]            0      -9796.5
# small[Berlin,Paris]            0      -5278.5
# small[Prague,Paris]            0      -5314.5
# small[Hamburg,Paris]            0        -4518
# small[Warsaw,Paris]            0        -8118
# small[Budapest,Paris]            0        -7065
# small[Geneva,Paris]            0        -2556
# small[Kyiv,Paris]            0       -11628
# small[Bucharest,Paris]            0     -10516.5
# small[Birmingham,Paris]            0        -2817
# small[Milan/Bergamo,Paris]            0      -3784.5
# small[Edinburgh,Paris]            0        -4923
# small[Nice,Paris]            0        -4401
# small[Cologne/Bonn,Paris]            0        -2430
# small[Saint Petersburg,Paris]            0       -12996
# small[Stuttgart,Paris]            0        -3159
# small[Lyon,Paris]           -0      -1093.5
# small[Trondheim,Paris]            0       -10701
# small[London,Frankfurt]            0      -4081.5
# small[Madrid,Frankfurt]            0      -8383.5
# small[Paris,Frankfurt]            0        -2997
# small[Amsterdam,Frankfurt]           -0        -1017
# small[Istanbul,Frankfurt]            0     -11029.5
# small[Palma de Mallorca,Frankfurt]            0        -7146
# small[Rome,Frankfurt]            0        -5445
# small[Moscow,Frankfurt]            0       -12663
# small[Lisbon,Frankfurt]            0     -10966.5
# small[Zurich,Frankfurt]            0        -1728
# small[Milan,Frankfurt]            0      -2902.5
# small[Copenhagen,Frankfurt]            0        -3789
# small[Manchester,Frankfurt]            0      -5377.5
# small[Malaga,Frankfurt]            0     -10390.5
# small[Vienna,Frankfurt]            0        -3591
# small[Oslo,Frankfurt]            0        -6966
# small[Dusseldorf,Frankfurt]            0      -1021.5
# small[Dublin,Frankfurt]            0        -6804
# small[Athens,Frankfurt]            0       -10413
# small[Porto,Frankfurt]            0        -9792
# small[Helsinki,Frankfurt]            0        -9297
# small[Stockholm,Frankfurt]            0        -7398
# small[Berlin,Frankfurt]           -0      -1183.5
# small[Prague,Frankfurt]           -0        -1152
# small[Hamburg,Frankfurt]            0        -2475
# small[Warsaw,Frankfurt]            0      -5719.5
# small[Budapest,Frankfurt]            0      -4783.5
# small[Geneva,Frankfurt]            0        -2799
# small[Kyiv,Frankfurt]            0        -9774
# small[Bucharest,Frankfurt]            0        -8829
# small[Birmingham,Frankfurt]            0      -4927.5
# small[Milan/Bergamo,Frankfurt]            0        -2826
# small[Edinburgh,Frankfurt]            0        -6525
# small[Nice,Frankfurt]            0      -4036.5
# small[Cologne/Bonn,Frankfurt]            0       -382.5
# small[Saint Petersburg,Frankfurt]            0     -10273.5
# small[Stuttgart,Frankfurt]           -0         -423
# small[Lyon,Frankfurt]            0        -3357
# small[Trondheim,Frankfurt]            0      -9139.5
# small[London,Amsterdam]           -0         -999
# small[Madrid,Amsterdam]            0        -9342
# small[Paris,Amsterdam]           -0      -1201.5
# small[Frankfurt,Amsterdam]            1        -1017
# small[Istanbul,Amsterdam]            0       -12861
# small[Palma de Mallorca,Amsterdam]            0      -8482.5
# small[Rome,Amsterdam]            0      -8194.5
# small[Moscow,Amsterdam]            0       -12312
# small[Lisbon,Amsterdam]            0       -11754
# small[Zurich,Amsterdam]            0      -3568.5
# small[Milan,Amsterdam]            0      -4639.5
# small[Copenhagen,Amsterdam]            0      -3577.5
# small[Manchester,Amsterdam]            0        -3114
# small[Malaga,Amsterdam]            0       -11439
# small[Vienna,Amsterdam]            0        -5994
# small[Oslo,Amsterdam]            0        -5562
# small[Dusseldorf,Amsterdam]            1       -508.5
# small[Dublin,Amsterdam]            0        -4248
# small[Athens,Amsterdam]            0       -12294
# small[Porto,Amsterdam]            0      -9103.5
# small[Helsinki,Amsterdam]            0      -8464.5
# small[Stockholm,Amsterdam]            0        -6444
# small[Berlin,Amsterdam]            0        -3348
# small[Prague,Amsterdam]            0        -4536
# small[Hamburg,Amsterdam]           -0        -1026
# small[Warsaw,Amsterdam]            0        -7038
# small[Budapest,Amsterdam]            0      -7132.5
# small[Geneva,Amsterdam]            0        -4356
# small[Kyiv,Amsterdam]            0       -11295
# small[Bucharest,Amsterdam]            0       -10629
# small[Birmingham,Amsterdam]            0        -2745
# small[Milan/Bergamo,Amsterdam]            0      -4594.5
# small[Edinburgh,Amsterdam]            0        -4014
# small[Nice,Amsterdam]            0        -5859
# small[Cologne/Bonn,Amsterdam]            0      -1273.5
# small[Saint Petersburg,Amsterdam]            0     -10912.5
# small[Stuttgart,Amsterdam]            0      -2839.5
# small[Lyon,Amsterdam]            0        -4707
# small[Trondheim,Amsterdam]            0        -7200
# small[London,Istanbul]            0       -14130
# small[Madrid,Istanbul]            0     -16114.5
# small[Paris,Istanbul]            0     -12640.5
# small[Frankfurt,Istanbul]            0     -11029.5
# small[Amsterdam,Istanbul]            0       -12861
# small[Palma de Mallorca,Istanbul]            0     -13963.5
# small[Rome,Istanbul]            0        -8289
# small[Moscow,Istanbul]            0      -9976.5
# small[Lisbon,Istanbul]            0     -18850.5
# small[Zurich,Istanbul]            0       -10179
# small[Milan,Istanbul]            0     -10246.5
# small[Copenhagen,Istanbul]            0       -11412
# small[Manchester,Istanbul]            0       -15381
# small[Malaga,Istanbul]            0     -17563.5
# small[Vienna,Istanbul]            0        -7155
# small[Oslo,Istanbul]            0       -15723
# small[Dusseldorf,Istanbul]            0       -11916
# small[Dublin,Istanbul]            0     -16699.5
# small[Athens,Istanbul]           -0      -1570.5
# small[Porto,Istanbul]            0     -17986.5
# small[Helsinki,Istanbul]            0     -12442.5
# small[Stockholm,Istanbul]            0     -12217.5
# small[Berlin,Istanbul]            0       -10188
# small[Prague,Istanbul]            0      -9544.5
# small[Hamburg,Istanbul]            0     -12451.5
# small[Warsaw,Istanbul]            0        -8757
# small[Budapest,Istanbul]            0      -6034.5
# small[Geneva,Istanbul]            0       -10953
# small[Kyiv,Istanbul]            0      -6286.5
# small[Bucharest,Istanbul]            1      -1246.5
# small[Birmingham,Istanbul]            0       -14994
# small[Milan/Bergamo,Istanbul]            0       -10125
# small[Edinburgh,Istanbul]            0     -16438.5
# small[Nice,Istanbul]            0       -11178
# small[Cologne/Bonn,Istanbul]            0     -11677.5
# small[Saint Petersburg,Istanbul]            0       -12654
# small[Stuttgart,Istanbul]            0       -10377
# small[Lyon,Istanbul]            0       -11529
# small[Trondheim,Istanbul]            0     -17716.5
# small[London,Palma de Mallorca]            0      -7600.5
# small[Madrid,Palma de Mallorca]            0      -3388.5
# small[Paris,Palma de Mallorca]            0        -6471
# small[Frankfurt,Palma de Mallorca]            0        -7146
# small[Amsterdam,Palma de Mallorca]            0      -8482.5
# small[Istanbul,Palma de Mallorca]            0     -13963.5
# small[Rome,Palma de Mallorca]            0      -5413.5
# small[Moscow,Palma de Mallorca]            0     -17662.5
# small[Lisbon,Palma de Mallorca]            0        -6336
# small[Zurich,Palma de Mallorca]            0        -5607
# small[Milan,Palma de Mallorca]            0      -4729.5
# small[Copenhagen,Palma de Mallorca]            0     -10876.5
# small[Manchester,Palma de Mallorca]            0     -10066.5
# small[Malaga,Palma de Mallorca]            0      -3883.5
# small[Vienna,Palma de Mallorca]            0      -8491.5
# small[Oslo,Palma de Mallorca]            0       -14373
# small[Dusseldorf,Palma de Mallorca]            0        -7839
# small[Dublin,Palma de Mallorca]            0      -9751.5
# small[Athens,Palma de Mallorca]            0       -10503
# small[Porto,Palma de Mallorca]            0      -5431.5
# small[Helsinki,Palma de Mallorca]            0       -15858
# small[Stockholm,Palma de Mallorca]            0     -14683.5
# small[Berlin,Palma de Mallorca]            0      -9265.5
# small[Prague,Palma de Mallorca]            0        -8397
# small[Hamburg,Palma de Mallorca]            0        -9315
# small[Warsaw,Palma de Mallorca]            0       -11250
# small[Budapest,Palma de Mallorca]            0        -9405
# small[Geneva,Palma de Mallorca]            0        -4689
# small[Kyiv,Palma de Mallorca]            0       -14301
# small[Bucharest,Palma de Mallorca]            0     -12082.5
# small[Birmingham,Palma de Mallorca]            0        -8415
# small[Milan/Bergamo,Palma de Mallorca]            0      -4963.5
# small[Edinburgh,Palma de Mallorca]            0     -11488.5
# small[Nice,Palma de Mallorca]            0      -1669.5
# small[Cologne/Bonn,Palma de Mallorca]            0        -7524
# small[Saint Petersburg,Palma de Mallorca]            0       -16767
# small[Stuttgart,Palma de Mallorca]            0        -6426
# small[Lyon,Palma de Mallorca]            0      -4486.5
# small[Trondheim,Palma de Mallorca]            0       -15327
# small[London,Rome]            0        -8100
# small[Madrid,Rome]            0      -7789.5
# small[Paris,Rome]            0        -6372
# small[Frankfurt,Rome]            0        -5445
# small[Amsterdam,Rome]            0      -8194.5
# small[Istanbul,Rome]            0        -8289
# small[Palma de Mallorca,Rome]            0      -5413.5
# small[Moscow,Rome]            0       -14715
# small[Lisbon,Rome]            0       -11952
# small[Zurich,Rome]            0      -3820.5
# small[Milan,Rome]            0        -2781
# small[Copenhagen,Rome]            0        -8901
# small[Manchester,Rome]            0        -9495
# small[Malaga,Rome]            0      -8743.5
# small[Vienna,Rome]            1      -2137.5
# small[Oslo,Rome]            0       -12267
# small[Dusseldorf,Rome]            0      -6304.5
# small[Dublin,Rome]            0     -10660.5
# small[Athens,Rome]            1        -2943
# small[Porto,Rome]            0     -11101.5
# small[Helsinki,Rome]            0       -13041
# small[Stockholm,Rome]            0       -11547
# small[Berlin,Rome]            0      -7087.5
# small[Prague,Rome]            0        -5400
# small[Hamburg,Rome]            0      -7510.5
# small[Warsaw,Rome]            0        -7371
# small[Budapest,Rome]            0      -4999.5
# small[Geneva,Rome]            0        -4077
# small[Kyiv,Rome]            0       -10305
# small[Bucharest,Rome]            0        -7254
# small[Birmingham,Rome]            0      -9004.5
# small[Milan/Bergamo,Rome]            0        -2781
# small[Edinburgh,Rome]            0       -10800
# small[Nice,Rome]           -0        -1314
# small[Cologne/Bonn,Rome]            0        -6048
# small[Saint Petersburg,Rome]            0     -14044.5
# small[Stuttgart,Rome]            0      -4621.5
# small[Lyon,Rome]            0        -4239
# small[Trondheim,Rome]            0       -13626
# small[London,Moscow]            0     -15331.5
# small[Madrid,Moscow]            0     -19273.5
# small[Paris,Moscow]            0     -14485.5
# small[Frankfurt,Moscow]            0       -12663
# small[Amsterdam,Moscow]            0       -12312
# small[Istanbul,Moscow]            0      -9976.5
# small[Palma de Mallorca,Moscow]            0     -17662.5
# small[Rome,Moscow]            0       -14715
# small[Lisbon,Moscow]            0       -21915
# small[Zurich,Moscow]            0       -12483
# small[Milan,Moscow]            0       -13158
# small[Copenhagen,Moscow]            0      -9481.5
# small[Manchester,Moscow]            0       -16137
# small[Malaga,Moscow]            0       -21177
# small[Vienna,Moscow]            0        -9459
# small[Oslo,Moscow]            0     -10570.5
# small[Dusseldorf,Moscow]            0     -13234.5
# small[Dublin,Moscow]            0     -17455.5
# small[Athens,Moscow]            0     -13927.5
# small[Porto,Moscow]            0     -20758.5
# small[Helsinki,Moscow]            0      -5116.5
# small[Stockholm,Moscow]            0        -7155
# small[Berlin,Moscow]            0        -9189
# small[Prague,Moscow]            0     -10048.5
# small[Hamburg,Moscow]            0     -10327.5
# small[Warsaw,Moscow]            0        -7272
# small[Budapest,Moscow]            0        -9144
# small[Geneva,Moscow]            0       -13707
# small[Kyiv,Moscow]            1        -2115
# small[Bucharest,Moscow]            0      -8392.5
# small[Birmingham,Moscow]            0       -15966
# small[Milan/Bergamo,Moscow]            0     -13009.5
# small[Edinburgh,Moscow]            0       -14814
# small[Nice,Moscow]            0       -14409
# small[Cologne/Bonn,Moscow]            0       -13095
# small[Saint Petersburg,Moscow]           -0      -1777.5
# small[Stuttgart,Moscow]            0       -12393
# small[Lyon,Moscow]            0     -14332.5
# small[Trondheim,Moscow]            0     -10021.5
# small[London,Lisbon]            0        -8892
# small[Madrid,Lisbon]            1      -1408.5
# small[Paris,Lisbon]            0        -8226
# small[Frankfurt,Lisbon]            0     -10966.5
# small[Amsterdam,Lisbon]            0       -11754
# small[Istanbul,Lisbon]            0     -18850.5
# small[Palma de Mallorca,Lisbon]            0        -6336
# small[Rome,Lisbon]            0       -11952
# small[Moscow,Lisbon]            0       -21915
# small[Zurich,Lisbon]            0       -10431
# small[Milan,Lisbon]            0     -10147.5
# small[Copenhagen,Lisbon]            0       -14463
# small[Manchester,Lisbon]            0     -10579.5
# small[Malaga,Lisbon]            1        -1314
# small[Vienna,Lisbon]            0     -12919.5
# small[Oslo,Lisbon]            0       -16407
# small[Dusseldorf,Lisbon]            0       -11286
# small[Dublin,Lisbon]            0      -9175.5
# small[Athens,Lisbon]            0       -17343
# small[Porto,Lisbon]           -0         -765
# small[Helsinki,Lisbon]            0       -19206
# small[Stockholm,Lisbon]            0     -17302.5
# small[Berlin,Lisbon]            0     -13162.5
# small[Prague,Lisbon]            0     -13414.5
# small[Hamburg,Lisbon]            0       -12915
# small[Warsaw,Lisbon]            0       -15471
# small[Budapest,Lisbon]            0     -13954.5
# small[Geneva,Lisbon]            0      -9652.5
# small[Kyiv,Lisbon]            0     -19048.5
# small[Bucharest,Lisbon]            0     -17068.5
# small[Birmingham,Lisbon]            0      -9112.5
# small[Milan/Bergamo,Lisbon]            0       -10242
# small[Edinburgh,Lisbon]            0     -10993.5
# small[Nice,Lisbon]            0        -8631
# small[Cologne/Bonn,Lisbon]            0     -11137.5
# small[Saint Petersburg,Lisbon]            0       -20520
# small[Stuttgart,Lisbon]            0       -10431
# small[Lyon,Lisbon]            0      -8005.5
# small[Trondheim,Lisbon]            0     -18337.5
# small[London,Zurich]            0      -4666.5
# small[Madrid,Zurich]            0        -7794
# small[Paris,Zurich]            0        -3141
# small[Frankfurt,Zurich]            0        -1728
# small[Amsterdam,Zurich]            0      -3568.5
# small[Istanbul,Zurich]            0       -10179
# small[Palma de Mallorca,Zurich]            0        -5607
# small[Rome,Zurich]            0      -3820.5
# small[Moscow,Zurich]            0       -12483
# small[Lisbon,Zurich]            0       -10431
# small[Milan,Zurich]            0      -1309.5
# small[Copenhagen,Zurich]            0      -5395.5
# small[Manchester,Zurich]            0        -5976
# small[Malaga,Zurich]            0        -9756
# small[Vienna,Zurich]            0      -3604.5
# small[Oslo,Zurich]            0        -7848
# small[Dusseldorf,Zurich]            0        -2601
# small[Dublin,Zurich]            0      -7258.5
# small[Athens,Zurich]            0        -9765
# small[Porto,Zurich]            0        -9297
# small[Helsinki,Zurich]            0       -10449
# small[Stockholm,Zurich]            0      -9292.5
# small[Berlin,Zurich]            0      -3748.5
# small[Prague,Zurich]            0      -3064.5
# small[Hamburg,Zurich]            0      -3883.5
# small[Warsaw,Zurich]            0        -6129
# small[Budapest,Zurich]            0        -4464
# small[Geneva,Zurich]            0       -625.5
# small[Kyiv,Zurich]            0      -9436.5
# small[Bucharest,Zurich]            0        -7956
# small[Birmingham,Zurich]            0      -5548.5
# small[Milan/Bergamo,Zurich]            0      -1309.5
# small[Edinburgh,Zurich]            0        -7182
# small[Nice,Zurich]            0        -2565
# small[Cologne/Bonn,Zurich]            0        -2340
# small[Saint Petersburg,Zurich]            0     -11371.5
# small[Stuttgart,Zurich]            1       -454.5
# small[Lyon,Zurich]            0      -1876.5
# small[Trondheim,Zurich]            0     -11506.5
# small[London,Milan]            0        -5463
# small[Madrid,Milan]            0      -7420.5
# small[Paris,Milan]            0      -3766.5
# small[Frankfurt,Milan]            0      -2902.5
# small[Amsterdam,Milan]            0      -4639.5
# small[Istanbul,Milan]            0     -10246.5
# small[Palma de Mallorca,Milan]            0      -4729.5
# small[Rome,Milan]            0        -2781
# small[Moscow,Milan]            0       -13158
# small[Lisbon,Milan]            0     -10147.5
# small[Zurich,Milan]            0      -1309.5
# small[Copenhagen,Milan]            0        -6552
# small[Manchester,Milan]            0        -6858
# small[Malaga,Milan]            0        -9243
# small[Vienna,Milan]            0        -4014
# small[Oslo,Milan]            0        -9027
# small[Dusseldorf,Milan]            0      -3712.5
# small[Dublin,Milan]            0      -8041.5
# small[Athens,Milan]            0        -9225
# small[Porto,Milan]            0        -9126
# small[Helsinki,Milan]            0       -10998
# small[Stockholm,Milan]            0      -9337.5
# small[Berlin,Milan]            0      -4828.5
# small[Prague,Milan]            0        -3879
# small[Hamburg,Milan]            0      -5062.5
# small[Warsaw,Milan]            0      -6727.5
# small[Budapest,Milan]            0        -5022
# small[Geneva,Milan]            0        -1602
# small[Kyiv,Milan]            0      -9886.5
# small[Bucharest,Milan]            0      -8248.5
# small[Birmingham,Milan]            0        -6372
# small[Milan/Bergamo,Milan]            0       -121.5
# small[Edinburgh,Milan]            0      -8158.5
# small[Nice,Milan]            1         -693
# small[Cologne/Bonn,Milan]            0        -3519
# small[Saint Petersburg,Milan]            0       -12132
# small[Stuttgart,Milan]            0        -2088
# small[Lyon,Milan]            0      -2128.5
# small[Trondheim,Milan]            0       -11205
# small[London,Copenhagen]            0        -5508
# small[Madrid,Copenhagen]            0       -11988
# small[Paris,Copenhagen]            0        -6516
# small[Frankfurt,Copenhagen]            0        -3789
# small[Amsterdam,Copenhagen]            0      -3577.5
# small[Istanbul,Copenhagen]            0       -11412
# small[Palma de Mallorca,Copenhagen]            0     -10876.5
# small[Rome,Copenhagen]            0        -8901
# small[Moscow,Copenhagen]            0      -9481.5
# small[Lisbon,Copenhagen]            0       -14463
# small[Zurich,Copenhagen]            0      -5395.5
# small[Milan,Copenhagen]            0        -6552
# small[Manchester,Copenhagen]            0      -6169.5
# small[Malaga,Copenhagen]            0       -14049
# small[Vienna,Copenhagen]            0      -4909.5
# small[Oslo,Copenhagen]            1        -1350
# small[Dusseldorf,Copenhagen]            0        -3690
# small[Dublin,Copenhagen]            0      -6979.5
# small[Athens,Copenhagen]            0       -12321
# small[Porto,Copenhagen]            0       -13221
# small[Helsinki,Copenhagen]            0      -5035.5
# small[Stockholm,Copenhagen]           -0        -1458
# small[Berlin,Copenhagen]            0       -994.5
# small[Prague,Copenhagen]            0      -3973.5
# small[Hamburg,Copenhagen]           -0         -810
# small[Warsaw,Copenhagen]            0      -4324.5
# small[Budapest,Copenhagen]            0        -5868
# small[Geneva,Copenhagen]            0      -6529.5
# small[Kyiv,Copenhagen]            0        -7533
# small[Bucharest,Copenhagen]            0        -8928
# small[Birmingham,Copenhagen]            0        -5895
# small[Milan/Bergamo,Copenhagen]            0        -6444
# small[Edinburgh,Copenhagen]            0        -6300
# small[Nice,Copenhagen]            0      -8725.5
# small[Cologne/Bonn,Copenhagen]            0        -4068
# small[Saint Petersburg,Copenhagen]            0      -6610.5
# small[Stuttgart,Copenhagen]            0      -4540.5
# small[Lyon,Copenhagen]            0        -7074
# small[Trondheim,Copenhagen]            0        -4878
# small[London,Manchester]            0        -1503
# small[Madrid,Manchester]            0      -9301.5
# small[Paris,Manchester]            0        -3411
# small[Frankfurt,Manchester]            0      -5377.5
# small[Amsterdam,Manchester]            0        -3114
# small[Istanbul,Manchester]            0       -15381
# small[Palma de Mallorca,Manchester]            0     -10066.5
# small[Rome,Manchester]            0        -9495
# small[Moscow,Manchester]            0       -16137
# small[Lisbon,Manchester]            0     -10579.5
# small[Zurich,Manchester]            0        -5976
# small[Milan,Manchester]            0        -6858
# small[Copenhagen,Manchester]            0      -6169.5
# small[Malaga,Manchester]            0     -10984.5
# small[Vienna,Manchester]            0        -8514
# small[Oslo,Manchester]            0      -6376.5
# small[Dusseldorf,Manchester]            0        -3933
# small[Dublin,Manchester]            0         -747
# small[Athens,Manchester]            0     -16186.5
# small[Porto,Manchester]            0      -9139.5
# small[Helsinki,Manchester]            0       -11115
# small[Stockholm,Manchester]            0        -8082
# small[Berlin,Manchester]            0        -6282
# small[Prague,Manchester]            0      -7708.5
# small[Hamburg,Manchester]            0        -5022
# small[Warsaw,Manchester]            0        -9927
# small[Budapest,Manchester]            0        -9657
# small[Geneva,Manchester]            0        -6300
# small[Kyiv,Manchester]            0       -13752
# small[Bucharest,Manchester]            0     -13153.5
# small[Birmingham,Manchester]            0         -315
# small[Milan/Bergamo,Manchester]            0        -6849
# small[Edinburgh,Manchester]            1       -787.5
# small[Nice,Manchester]            0        -7641
# small[Cologne/Bonn,Manchester]            0        -4131
# small[Saint Petersburg,Manchester]            0     -13117.5
# small[Stuttgart,Manchester]            0        -5976
# small[Lyon,Manchester]            0      -5575.5
# small[Trondheim,Manchester]            0        -7785
# small[London,Malaga]            0       -10089
# small[Madrid,Malaga]           -0      -1156.5
# small[Paris,Malaga]            0      -9166.5
# small[Frankfurt,Malaga]            0     -10390.5
# small[Amsterdam,Malaga]            0       -11439
# small[Istanbul,Malaga]            0     -17563.5
# small[Palma de Mallorca,Malaga]            0      -3883.5
# small[Rome,Malaga]            0      -8743.5
# small[Moscow,Malaga]            0       -21177
# small[Lisbon,Malaga]            1        -1314
# small[Zurich,Malaga]            0        -9756
# small[Milan,Malaga]            0        -9243
# small[Copenhagen,Malaga]            0       -14049
# small[Manchester,Malaga]            0     -10984.5
# small[Vienna,Malaga]            0       -12276
# small[Oslo,Malaga]            0       -16191
# small[Dusseldorf,Malaga]            0     -10840.5
# small[Dublin,Malaga]            0     -10705.5
# small[Athens,Malaga]            0     -15934.5
# small[Porto,Malaga]            0      -3784.5
# small[Helsinki,Malaga]            0       -18747
# small[Stockholm,Malaga]            0     -16915.5
# small[Berlin,Malaga]            0       -12582
# small[Prague,Malaga]            0     -11839.5
# small[Hamburg,Malaga]            0     -12478.5
# small[Warsaw,Malaga]            0       -14733
# small[Budapest,Malaga]            0       -12996
# small[Geneva,Malaga]            0        -7983
# small[Kyiv,Malaga]            0     -17887.5
# small[Bucharest,Malaga]            0     -15916.5
# small[Birmingham,Malaga]            0     -10426.5
# small[Milan/Bergamo,Malaga]            0      -9337.5
# small[Edinburgh,Malaga]            0     -12415.5
# small[Nice,Malaga]            0      -7132.5
# small[Cologne/Bonn,Malaga]            0     -10660.5
# small[Saint Petersburg,Malaga]            0     -19993.5
# small[Stuttgart,Malaga]            0        -9756
# small[Lyon,Malaga]            0        -7470
# small[Trondheim,Malaga]            0     -18220.5
# small[London,Vienna]            0        -7290
# small[Madrid,Vienna]            0     -10210.5
# small[Paris,Vienna]            0        -5922
# small[Frankfurt,Vienna]            0        -3591
# small[Amsterdam,Vienna]            0        -5994
# small[Istanbul,Vienna]            0        -7155
# small[Palma de Mallorca,Vienna]            0      -8491.5
# small[Rome,Vienna]           -0      -2137.5
# small[Moscow,Vienna]            0        -9459
# small[Lisbon,Vienna]            0     -12919.5
# small[Zurich,Vienna]            0      -3604.5
# small[Milan,Vienna]            0        -4014
# small[Copenhagen,Vienna]            0      -4909.5
# small[Manchester,Vienna]            0        -8514
# small[Malaga,Vienna]            0       -12276
# small[Oslo,Vienna]            0        -8307
# small[Dusseldorf,Vienna]            0      -4540.5
# small[Dublin,Vienna]            0      -9841.5
# small[Athens,Vienna]            0      -7321.5
# small[Porto,Vienna]            0       -11853
# small[Helsinki,Vienna]            0      -8140.5
# small[Stockholm,Vienna]            0      -7285.5
# small[Berlin,Vienna]            0        -2943
# small[Prague,Vienna]           -0         -693
# small[Hamburg,Vienna]            0      -4153.5
# small[Warsaw,Vienna]            1      -1552.5
# small[Budapest,Vienna]           -0       -598.5
# small[Geneva,Vienna]            0      -4531.5
# small[Kyiv,Vienna]            0        -6435
# small[Bucharest,Vienna]            0      -4792.5
# small[Birmingham,Vienna]            0        -8136
# small[Milan/Bergamo,Vienna]            0      -3496.5
# small[Edinburgh,Vienna]            0      -9580.5
# small[Nice,Vienna]            0        -5247
# small[Cologne/Bonn,Vienna]            0      -4297.5
# small[Saint Petersburg,Vienna]            0        -8874
# small[Stuttgart,Vienna]            0      -3325.5
# small[Lyon,Vienna]            0        -5157
# small[Trondheim,Vienna]            0     -10291.5
# small[London,Oslo]            0        -6948
# small[Madrid,Oslo]            0       -14085
# small[Paris,Oslo]            0      -8626.5
# small[Frankfurt,Oslo]            0        -6966
# small[Amsterdam,Oslo]            0        -5562
# small[Istanbul,Oslo]            0       -15723
# small[Palma de Mallorca,Oslo]            0       -14373
# small[Rome,Oslo]            0       -12267
# small[Moscow,Oslo]            0     -10570.5
# small[Lisbon,Oslo]            0       -16407
# small[Zurich,Oslo]            0        -7848
# small[Milan,Oslo]            0        -9027
# small[Copenhagen,Oslo]           -0        -1350
# small[Manchester,Oslo]            0      -6376.5
# small[Malaga,Oslo]            0       -16191
# small[Vienna,Oslo]            0        -8307
# small[Dusseldorf,Oslo]            0      -5719.5
# small[Dublin,Oslo]            0        -7272
# small[Athens,Oslo]            0       -15732
# small[Porto,Oslo]            0       -15120
# small[Helsinki,Oslo]            0      -4486.5
# small[Stockholm,Oslo]            1        -1170
# small[Berlin,Oslo]            0        -5040
# small[Prague,Oslo]            0      -6502.5
# small[Hamburg,Oslo]            0      -4144.5
# small[Warsaw,Oslo]            0        -6408
# small[Budapest,Oslo]            0      -8644.5
# small[Geneva,Oslo]            0        -8892
# small[Kyiv,Oslo]            0      -9463.5
# small[Bucharest,Oslo]            0       -11223
# small[Birmingham,Oslo]            0      -6475.5
# small[Milan/Bergamo,Oslo]            0      -8932.5
# small[Edinburgh,Oslo]            1      -2605.5
# small[Nice,Oslo]            0     -11281.5
# small[Cologne/Bonn,Oslo]            0      -5863.5
# small[Saint Petersburg,Oslo]            0      -6151.5
# small[Stuttgart,Oslo]            0        -7848
# small[Lyon,Oslo]            0      -9391.5
# small[Trondheim,Oslo]            0      -1093.5
# small[London,Dusseldorf]            0        -2907
# small[Madrid,Dusseldorf]            0      -8779.5
# small[Paris,Dusseldorf]            0        -2430
# small[Frankfurt,Dusseldorf]            0      -1021.5
# small[Amsterdam,Dusseldorf]            0       -508.5
# small[Istanbul,Dusseldorf]            0       -11916
# small[Palma de Mallorca,Dusseldorf]            0        -7839
# small[Rome,Dusseldorf]            0      -6304.5
# small[Moscow,Dusseldorf]            0     -13234.5
# small[Lisbon,Dusseldorf]            0       -11286
# small[Zurich,Dusseldorf]            0        -2601
# small[Milan,Dusseldorf]            0      -3712.5
# small[Copenhagen,Dusseldorf]            0        -3690
# small[Manchester,Dusseldorf]            0        -3933
# small[Malaga,Dusseldorf]            0     -10840.5
# small[Vienna,Dusseldorf]            0      -4540.5
# small[Oslo,Dusseldorf]            0      -5719.5
# small[Dublin,Dusseldorf]            0      -5908.5
# small[Athens,Dusseldorf]            0       -11322
# small[Porto,Dusseldorf]            0     -10066.5
# small[Helsinki,Dusseldorf]            0      -9526.5
# small[Stockholm,Dusseldorf]            0        -7173
# small[Berlin,Dusseldorf]            0        -2988
# small[Prague,Dusseldorf]            0      -3217.5
# small[Hamburg,Dusseldorf]            0        -2070
# small[Warsaw,Dusseldorf]            0      -6232.5
# small[Budapest,Dusseldorf]            0      -6196.5
# small[Geneva,Dusseldorf]            0        -3438
# small[Kyiv,Dusseldorf]            0       -10494
# small[Bucharest,Dusseldorf]            0        -9693
# small[Birmingham,Dusseldorf]            0      -3883.5
# small[Milan/Bergamo,Dusseldorf]            0        -3699
# small[Edinburgh,Dusseldorf]            0        -4995
# small[Nice,Dusseldorf]            0        -4761
# small[Cologne/Bonn,Dusseldorf]            1       -130.5
# small[Saint Petersburg,Dusseldorf]            0     -10561.5
# small[Stuttgart,Dusseldorf]            0      -1831.5
# small[Lyon,Dusseldorf]            0      -3928.5
# small[Trondheim,Dusseldorf]            0        -8775
# small[London,Dublin]            0      -2776.5
# small[Madrid,Dublin]            0        -9054
# small[Paris,Dublin]            0        -4626
# small[Frankfurt,Dublin]            0        -6804
# small[Amsterdam,Dublin]            0        -4248
# small[Istanbul,Dublin]            0     -16699.5
# small[Palma de Mallorca,Dublin]            0      -9751.5
# small[Rome,Dublin]            0     -10660.5
# small[Moscow,Dublin]            0     -17455.5
# small[Lisbon,Dublin]            0      -9175.5
# small[Zurich,Dublin]            0      -7258.5
# small[Milan,Dublin]            0      -8041.5
# small[Copenhagen,Dublin]            0      -6979.5
# small[Manchester,Dublin]            0         -747
# small[Malaga,Dublin]            0     -10705.5
# small[Vienna,Dublin]            0      -9841.5
# small[Oslo,Dublin]            0        -7272
# small[Dusseldorf,Dublin]            0      -5908.5
# small[Athens,Dublin]            0     -15988.5
# small[Porto,Dublin]            0        -8622
# small[Helsinki,Dublin]            0     -12172.5
# small[Stockholm,Dublin]            0     -10408.5
# small[Berlin,Dublin]            0        -8451
# small[Prague,Dublin]            0        -9054
# small[Hamburg,Dublin]            0      -6025.5
# small[Warsaw,Dublin]            0       -11511
# small[Budapest,Dublin]            0       -10989
# small[Geneva,Dublin]            0      -7429.5
# small[Kyiv,Dublin]            0       -15111
# small[Bucharest,Dublin]            0     -14485.5
# small[Birmingham,Dublin]            0      -1921.5
# small[Milan/Bergamo,Dublin]            0      -8050.5
# small[Edinburgh,Dublin]            0         -981
# small[Nice,Dublin]            0        -8730
# small[Cologne/Bonn,Dublin]            0      -6007.5
# small[Saint Petersburg,Dublin]            0     -14512.5
# small[Stuttgart,Dublin]            0      -7258.5
# small[Lyon,Dublin]            0      -6529.5
# small[Trondheim,Dublin]            0        -8766
# small[London,Athens]            0     -13396.5
# small[Madrid,Athens]            0       -14652
# small[Paris,Athens]            0       -11763
# small[Frankfurt,Athens]            0       -10413
# small[Amsterdam,Athens]            0       -12294
# small[Istanbul,Athens]           -0      -1570.5
# small[Palma de Mallorca,Athens]            0       -10503
# small[Rome,Athens]            1        -2943
# small[Moscow,Athens]            0     -13927.5
# small[Lisbon,Athens]            0       -17343
# small[Zurich,Athens]            0        -9765
# small[Milan,Athens]            0        -9225
# small[Copenhagen,Athens]            0       -12321
# small[Manchester,Athens]            0     -16186.5
# small[Malaga,Athens]            0     -15934.5
# small[Vienna,Athens]            0      -7321.5
# small[Oslo,Athens]            0       -15732
# small[Dusseldorf,Athens]            0       -11322
# small[Dublin,Athens]            0     -15988.5
# small[Porto,Athens]            0       -16587
# small[Helsinki,Athens]            0       -13923
# small[Stockholm,Athens]            0       -15363
# small[Berlin,Athens]            0     -11434.5
# small[Prague,Athens]            0      -8554.5
# small[Hamburg,Athens]            0     -12127.5
# small[Warsaw,Athens]            0      -9598.5
# small[Budapest,Athens]            0        -7020
# small[Geneva,Athens]            0        -9936
# small[Kyiv,Athens]            0        -8676
# small[Bucharest,Athens]            1        -2079
# small[Birmingham,Athens]            0       -15948
# small[Milan/Bergamo,Athens]            0      -9139.5
# small[Edinburgh,Athens]            0       -15921
# small[Nice,Athens]            0        -9099
# small[Cologne/Bonn,Athens]            0     -11065.5
# small[Saint Petersburg,Athens]            0       -14301
# small[Stuttgart,Athens]            0        -9666
# small[Lyon,Athens]            0       -10449
# small[Trondheim,Athens]            0       -17829
# small[London,Porto]            0        -8046
# small[Madrid,Porto]           -0        -1179
# small[Paris,Porto]            0        -7515
# small[Frankfurt,Porto]            0        -9792
# small[Amsterdam,Porto]            0      -9103.5
# small[Istanbul,Porto]            0     -17986.5
# small[Palma de Mallorca,Porto]            0      -5431.5
# small[Rome,Porto]            0     -11101.5
# small[Moscow,Porto]            0     -20758.5
# small[Lisbon,Porto]           -0         -765
# small[Zurich,Porto]            0        -9297
# small[Milan,Porto]            0        -9126
# small[Copenhagen,Porto]            0       -13221
# small[Manchester,Porto]            0      -9139.5
# small[Malaga,Porto]            0      -3784.5
# small[Vienna,Porto]            0       -11853
# small[Oslo,Porto]            0       -15120
# small[Dusseldorf,Porto]            0     -10066.5
# small[Dublin,Porto]            0        -8622
# small[Athens,Porto]            0       -16587
# small[Helsinki,Porto]            0     -17959.5
# small[Stockholm,Porto]            0     -17059.5
# small[Berlin,Porto]            0     -11974.5
# small[Prague,Porto]            0     -11452.5
# small[Hamburg,Porto]            0     -11686.5
# small[Warsaw,Porto]            0     -14332.5
# small[Budapest,Porto]            0     -12919.5
# small[Geneva,Porto]            0        -8208
# small[Kyiv,Porto]            0     -17725.5
# small[Bucharest,Porto]            0     -16123.5
# small[Birmingham,Porto]            0      -8590.5
# small[Milan/Bergamo,Porto]            0        -9216
# small[Edinburgh,Porto]            0       -10566
# small[Nice,Porto]            0      -8113.5
# small[Cologne/Bonn,Porto]            0      -9931.5
# small[Saint Petersburg,Porto]            0     -19291.5
# small[Stuttgart,Porto]            0        -9297
# small[Lyon,Porto]            0        -7083
# small[Trondheim,Porto]            0     -17032.5
# small[London,Helsinki]            0     -11722.5
# small[Madrid,Helsinki]            0     -16708.5
# small[Paris,Helsinki]            0       -11682
# small[Frankfurt,Helsinki]            0        -9297
# small[Amsterdam,Helsinki]            0      -8464.5
# small[Istanbul,Helsinki]            0     -12442.5
# small[Palma de Mallorca,Helsinki]            0       -15858
# small[Rome,Helsinki]            0       -13041
# small[Moscow,Helsinki]            0      -5116.5
# small[Lisbon,Helsinki]            0       -19206
# small[Zurich,Helsinki]            0       -10449
# small[Milan,Helsinki]            0       -10998
# small[Copenhagen,Helsinki]            0      -5035.5
# small[Manchester,Helsinki]            0       -11115
# small[Malaga,Helsinki]            0       -18747
# small[Vienna,Helsinki]            0      -8140.5
# small[Oslo,Helsinki]            0      -4486.5
# small[Dusseldorf,Helsinki]            0      -9526.5
# small[Dublin,Helsinki]            0     -12172.5
# small[Athens,Helsinki]            0       -13923
# small[Porto,Helsinki]            0     -17959.5
# small[Stockholm,Helsinki]            1        -1107
# small[Berlin,Helsinki]            0      -7105.5
# small[Prague,Helsinki]            0        -7659
# small[Hamburg,Helsinki]            0      -6637.5
# small[Warsaw,Helsinki]            1      -2560.5
# small[Budapest,Helsinki]            0      -8707.5
# small[Geneva,Helsinki]            0     -11137.5
# small[Kyiv,Helsinki]            0        -6966
# small[Bucharest,Helsinki]            0       -10098
# small[Birmingham,Helsinki]            0       -11493
# small[Milan/Bergamo,Helsinki]            0       -10863
# small[Edinburgh,Helsinki]            0       -10296
# small[Nice,Helsinki]            0       -12555
# small[Cologne/Bonn,Helsinki]            0      -9526.5
# small[Saint Petersburg,Helsinki]           -0         -837
# small[Stuttgart,Helsinki]            0      -9949.5
# small[Lyon,Helsinki]            0     -12235.5
# small[Trondheim,Helsinki]            0      -5188.5
# small[London,Stockholm]            0        -8415
# small[Madrid,Stockholm]            0     -14854.5
# small[Paris,Stockholm]            0      -9796.5
# small[Frankfurt,Stockholm]            0        -7398
# small[Amsterdam,Stockholm]            0        -6444
# small[Istanbul,Stockholm]            0     -12217.5
# small[Palma de Mallorca,Stockholm]            0     -14683.5
# small[Rome,Stockholm]            0       -11547
# small[Moscow,Stockholm]            0        -7155
# small[Lisbon,Stockholm]            0     -17302.5
# small[Zurich,Stockholm]            0      -9292.5
# small[Milan,Stockholm]            0      -9337.5
# small[Copenhagen,Stockholm]           -0        -1458
# small[Manchester,Stockholm]            0        -8082
# small[Malaga,Stockholm]            0     -16915.5
# small[Vienna,Stockholm]            0      -7285.5
# small[Oslo,Stockholm]           -0        -1170
# small[Dusseldorf,Stockholm]            0        -7173
# small[Dublin,Stockholm]            0     -10408.5
# small[Athens,Stockholm]            0       -15363
# small[Porto,Stockholm]            0     -17059.5
# small[Helsinki,Stockholm]           -0        -1107
# small[Berlin,Stockholm]            0      -4720.5
# small[Prague,Stockholm]            0      -6664.5
# small[Hamburg,Stockholm]            1        -2268
# small[Warsaw,Stockholm]            1      -2263.5
# small[Budapest,Stockholm]            0      -7465.5
# small[Geneva,Stockholm]            0        -9378
# small[Kyiv,Stockholm]            0        -7731
# small[Bucharest,Stockholm]            0      -9778.5
# small[Birmingham,Stockholm]            0        -8415
# small[Milan/Bergamo,Stockholm]            0        -9216
# small[Edinburgh,Stockholm]            0      -7456.5
# small[Nice,Stockholm]            0       -11430
# small[Cologne/Bonn,Stockholm]            0      -7321.5
# small[Saint Petersburg,Stockholm]            0        -3879
# small[Stuttgart,Stockholm]            0        -8217
# small[Lyon,Stockholm]            0        -9936
# small[Trondheim,Stockholm]            0      -1714.5
# small[London,Berlin]            0        -5337
# small[Madrid,Berlin]            0       -10584
# small[Paris,Berlin]            0      -5278.5
# small[Frankfurt,Berlin]           -0      -1183.5
# small[Amsterdam,Berlin]            0        -3348
# small[Istanbul,Berlin]            0       -10188
# small[Palma de Mallorca,Berlin]            0      -9265.5
# small[Rome,Berlin]            0      -7087.5
# small[Moscow,Berlin]            0        -9189
# small[Lisbon,Berlin]            0     -13162.5
# small[Zurich,Berlin]            0      -3748.5
# small[Milan,Berlin]            0      -4828.5
# small[Copenhagen,Berlin]            1       -994.5
# small[Manchester,Berlin]            0        -6282
# small[Malaga,Berlin]            0       -12582
# small[Vienna,Berlin]            0        -2943
# small[Oslo,Berlin]            0        -5040
# small[Dusseldorf,Berlin]            0        -2988
# small[Dublin,Berlin]            0        -8451
# small[Athens,Berlin]            0     -11434.5
# small[Porto,Berlin]            0     -11974.5
# small[Helsinki,Berlin]            0      -7105.5
# small[Stockholm,Berlin]            0      -4720.5
# small[Prague,Berlin]           -0       -787.5
# small[Hamburg,Berlin]           -0         -711
# small[Warsaw,Berlin]           -0        -1449
# small[Budapest,Berlin]            0        -3987
# small[Geneva,Berlin]            0        -4941
# small[Kyiv,Berlin]            0      -7366.5
# small[Bucharest,Berlin]            0        -7713
# small[Birmingham,Berlin]            0        -6156
# small[Milan/Bergamo,Berlin]            0      -4702.5
# small[Edinburgh,Berlin]            0      -6925.5
# small[Nice,Berlin]            0      -6061.5
# small[Cologne/Bonn,Berlin]            0      -2875.5
# small[Saint Petersburg,Berlin]            0        -8055
# small[Stuttgart,Berlin]            0        -3033
# small[Lyon,Berlin]            0      -5530.5
# small[Trondheim,Berlin]            0        -7416
# small[London,Prague]            0      -6547.5
# small[Madrid,Prague]            0     -10723.5
# small[Paris,Prague]            0      -5314.5
# small[Frankfurt,Prague]           -0        -1152
# small[Amsterdam,Prague]            0        -4536
# small[Istanbul,Prague]            0      -9544.5
# ...
# indirect_pass[Malaga,Cologne/Bonn]            0        90.48
# indirect_pass[Vienna,Cologne/Bonn]            0        36.24
# indirect_pass[Oslo,Cologne/Bonn]            0        51.28
# indirect_pass[Dusseldorf,Cologne/Bonn]           -0         2.32
# indirect_pass[Dublin,Cologne/Bonn]            0        47.52
# indirect_pass[Athens,Cologne/Bonn]            0        96.32
# indirect_pass[Porto,Cologne/Bonn]            0        80.64
# indirect_pass[Helsinki,Cologne/Bonn]            0        75.52
# indirect_pass[Stockholm,Cologne/Bonn]            0        58.08
# indirect_pass[Berlin,Cologne/Bonn]            0        23.28
# indirect_pass[Prague,Cologne/Bonn]            0        26.16
# indirect_pass[Hamburg,Cologne/Bonn]            0        17.68
# indirect_pass[Warsaw,Cologne/Bonn]            0        48.32
# indirect_pass[Budapest,Cologne/Bonn]            0        46.88
# indirect_pass[Geneva,Cologne/Bonn]            0           26
# indirect_pass[Kyiv,Cologne/Bonn]            0        81.84
# indirect_pass[Bucharest,Cologne/Bonn]            0        78.88
# indirect_pass[Birmingham,Cologne/Bonn]            0        32.24
# indirect_pass[Milan/Bergamo,Cologne/Bonn]            0        30.16
# indirect_pass[Edinburgh,Cologne/Bonn]            0        44.08
# indirect_pass[Nice,Cologne/Bonn]            0         39.6
# indirect_pass[Saint Petersburg,Cologne/Bonn]            0        87.84
# indirect_pass[Stuttgart,Cologne/Bonn]            0         13.6
# indirect_pass[Lyon,Cologne/Bonn]            0        29.44
# indirect_pass[Trondheim,Cologne/Bonn]            0        70.16
# indirect_pass[London,Saint Petersburg]            0       104.64
# indirect_pass[Madrid,Saint Petersburg]            0        158.8
# indirect_pass[Paris,Saint Petersburg]            0       107.84
# indirect_pass[Frankfurt,Saint Petersburg]            0        86.96
# indirect_pass[Amsterdam,Saint Petersburg]            0        88.16
# indirect_pass[Istanbul,Saint Petersburg]            0       104.72
# indirect_pass[Palma de Mallorca,Saint Petersburg]            0       147.76
# indirect_pass[Rome,Saint Petersburg]            0        116.8
# indirect_pass[Moscow,Saint Petersburg]           -0         31.6
# indirect_pass[Lisbon,Saint Petersburg]            0       180.16
# indirect_pass[Zurich,Saint Petersburg]            0        98.88
# indirect_pass[Milan,Saint Petersburg]            0          106
# indirect_pass[Copenhagen,Saint Petersburg]            0         57.2
# indirect_pass[Manchester,Saint Petersburg]            0       104.08
# indirect_pass[Malaga,Saint Petersburg]            0       177.44
# indirect_pass[Vienna,Saint Petersburg]            0         78.8
# indirect_pass[Oslo,Saint Petersburg]            0        54.16
# indirect_pass[Dusseldorf,Saint Petersburg]            0        87.36
# indirect_pass[Dublin,Saint Petersburg]            0        115.6
# indirect_pass[Athens,Saint Petersburg]            0       123.52
# indirect_pass[Porto,Saint Petersburg]            0       168.08
# indirect_pass[Helsinki,Saint Petersburg]           -0        14.88
# indirect_pass[Stockholm,Saint Petersburg]            0         34.4
# indirect_pass[Berlin,Saint Petersburg]            0        66.08
# indirect_pass[Prague,Saint Petersburg]            0           74
# indirect_pass[Hamburg,Saint Petersburg]            0        70.72
# indirect_pass[Warsaw,Saint Petersburg]            0        51.36
# indirect_pass[Budapest,Saint Petersburg]            0        77.84
# indirect_pass[Geneva,Saint Petersburg]            0       109.52
# indirect_pass[Kyiv,Saint Petersburg]           -0        52.48
# indirect_pass[Bucharest,Saint Petersburg]            0        86.88
# indirect_pass[Birmingham,Saint Petersburg]            0       106.24
# indirect_pass[Milan/Bergamo,Saint Petersburg]            0          104
# indirect_pass[Edinburgh,Saint Petersburg]            0        99.84
# indirect_pass[Nice,Saint Petersburg]            0       118.32
# indirect_pass[Cologne/Bonn,Saint Petersburg]            0        87.84
# indirect_pass[Stuttgart,Saint Petersburg]            0        91.28
# indirect_pass[Lyon,Saint Petersburg]            0       114.56
# indirect_pass[Trondheim,Saint Petersburg]            0         55.6
# indirect_pass[London,Stuttgart]            0        36.24
# indirect_pass[Madrid,Stuttgart]            0        68.48
# indirect_pass[Paris,Stuttgart]            0        24.88
# indirect_pass[Frankfurt,Stuttgart]           -0         7.52
# indirect_pass[Amsterdam,Stuttgart]            0        24.88
# indirect_pass[Istanbul,Stuttgart]            0        88.32
# indirect_pass[Palma de Mallorca,Stuttgart]            0        57.04
# indirect_pass[Rome,Stuttgart]            0        40.08
# indirect_pass[Moscow,Stuttgart]            0       102.96
# indirect_pass[Lisbon,Stuttgart]            0         91.6
# indirect_pass[Zurich,Stuttgart]            0         8.08
# indirect_pass[Milan,Stuttgart]            0        18.24
# indirect_pass[Copenhagen,Stuttgart]            0        39.84
# indirect_pass[Manchester,Stuttgart]            0        47.36
# indirect_pass[Malaga,Stuttgart]            0        86.24
# indirect_pass[Vienna,Stuttgart]            0        26.56
# indirect_pass[Oslo,Stuttgart]            0        61.76
# indirect_pass[Dusseldorf,Stuttgart]            0           16
# indirect_pass[Dublin,Stuttgart]            0        59.28
# indirect_pass[Athens,Stuttgart]            0        83.28
# indirect_pass[Porto,Stuttgart]            0         81.2
# indirect_pass[Helsinki,Stuttgart]            0        80.48
# indirect_pass[Stockholm,Stuttgart]            0        64.96
# indirect_pass[Berlin,Stuttgart]            0        25.36
# indirect_pass[Prague,Stuttgart]           -0        20.24
# indirect_pass[Hamburg,Stuttgart]            0        26.48
# indirect_pass[Warsaw,Stuttgart]            0        45.76
# indirect_pass[Budapest,Stuttgart]            0        37.12
# indirect_pass[Geneva,Stuttgart]            0        18.16
# indirect_pass[Kyiv,Stuttgart]            0        76.96
# indirect_pass[Bucharest,Stuttgart]            0        68.56
# indirect_pass[Birmingham,Stuttgart]            0        43.92
# indirect_pass[Milan/Bergamo,Stuttgart]            0        17.28
# indirect_pass[Edinburgh,Stuttgart]            0        57.52
# indirect_pass[Nice,Stuttgart]            0        28.96
# indirect_pass[Cologne/Bonn,Stuttgart]            0         13.6
# indirect_pass[Saint Petersburg,Stuttgart]            0        91.28
# indirect_pass[Lyon,Stuttgart]            0        23.36
# indirect_pass[Trondheim,Stuttgart]            0        81.12
# indirect_pass[London,Lyon]            0        36.56
# indirect_pass[Madrid,Lyon]            0        45.36
# indirect_pass[Paris,Lyon]           -0        19.44
# indirect_pass[Frankfurt,Lyon]            0        27.92
# indirect_pass[Amsterdam,Lyon]            0        36.56
# indirect_pass[Istanbul,Lyon]            0       100.24
# indirect_pass[Palma de Mallorca,Lyon]            0        35.28
# indirect_pass[Rome,Lyon]            0         37.2
# indirect_pass[Moscow,Lyon]            0          126
# indirect_pass[Lisbon,Lyon]            0        69.12
# indirect_pass[Zurich,Lyon]            0        16.64
# indirect_pass[Milan,Lyon]            0        16.96
# indirect_pass[Copenhagen,Lyon]            0        61.12
# indirect_pass[Manchester,Lyon]            0         49.6
# indirect_pass[Malaga,Lyon]            0        62.96
# indirect_pass[Vienna,Lyon]            0         45.6
# indirect_pass[Oslo,Lyon]            0        80.64
# indirect_pass[Dusseldorf,Lyon]            0        31.04
# indirect_pass[Dublin,Lyon]            0        57.76
# indirect_pass[Athens,Lyon]            0        88.64
# indirect_pass[Porto,Lyon]            0         59.6
# indirect_pass[Helsinki,Lyon]            0       103.36
# indirect_pass[Stockholm,Lyon]            0        86.96
# indirect_pass[Berlin,Lyon]            0        48.48
# indirect_pass[Prague,Lyon]            0         42.8
# indirect_pass[Hamburg,Lyon]            0         46.8
# indirect_pass[Warsaw,Lyon]            0        68.64
# indirect_pass[Budapest,Lyon]            0         54.8
# indirect_pass[Geneva,Lyon]            0          5.6
# indirect_pass[Kyiv,Lyon]            0           98
# indirect_pass[Bucharest,Lyon]            0        83.28
# indirect_pass[Birmingham,Lyon]            0         44.4
# indirect_pass[Milan/Bergamo,Lyon]            0        18.72
# indirect_pass[Edinburgh,Lyon]            0        62.88
# indirect_pass[Nice,Lyon]           -0         14.8
# indirect_pass[Cologne/Bonn,Lyon]            0        29.44
# indirect_pass[Saint Petersburg,Lyon]            0       114.56
# indirect_pass[Stuttgart,Lyon]            0        23.36
# indirect_pass[Trondheim,Lyon]            0        99.28
# indirect_pass[London,Trondheim]            0         72.8
# indirect_pass[Madrid,Trondheim]            0       135.36
# indirect_pass[Paris,Trondheim]            0        84.24
# indirect_pass[Frankfurt,Trondheim]            0        73.84
# indirect_pass[Amsterdam,Trondheim]            0         63.2
# indirect_pass[Istanbul,Trondheim]            0       137.92
# indirect_pass[Palma de Mallorca,Trondheim]            0        134.4
# indirect_pass[Rome,Trondheim]            0       119.28
# indirect_pass[Moscow,Trondheim]            0        86.48
# indirect_pass[Lisbon,Trondheim]            0       151.28
# indirect_pass[Zurich,Trondheim]            0        88.96
# indirect_pass[Milan,Trondheim]            0        99.44
# indirect_pass[Copenhagen,Trondheim]            0        43.28
# indirect_pass[Manchester,Trondheim]            0        65.92
# indirect_pass[Malaga,Trondheim]            0       155.84
# indirect_pass[Vienna,Trondheim]            0        86.16
# indirect_pass[Oslo,Trondheim]            0        19.44
# indirect_pass[Dusseldorf,Trondheim]            0         68.4
# indirect_pass[Dublin,Trondheim]            0        73.44
# indirect_pass[Athens,Trondheim]            0       147.52
# indirect_pass[Porto,Trondheim]            0       137.84
# indirect_pass[Helsinki,Trondheim]            0        42.08
# indirect_pass[Stockholm,Trondheim]            0        30.48
# indirect_pass[Berlin,Trondheim]            0        61.04
# indirect_pass[Prague,Trondheim]            0        74.96
# indirect_pass[Hamburg,Trondheim]            0        54.64
# indirect_pass[Warsaw,Trondheim]            0         69.2
# indirect_pass[Budapest,Trondheim]            0           92
# indirect_pass[Geneva,Trondheim]            0        96.24
# indirect_pass[Kyiv,Trondheim]            0        93.36
# indirect_pass[Bucharest,Trondheim]            0       116.16
# indirect_pass[Birmingham,Trondheim]            0        70.32
# indirect_pass[Milan/Bergamo,Trondheim]            0        98.24
# indirect_pass[Edinburgh,Trondheim]            0        55.92
# indirect_pass[Nice,Trondheim]            0        109.6
# indirect_pass[Cologne/Bonn,Trondheim]            0        70.16
# indirect_pass[Saint Petersburg,Trondheim]            0         55.6
# indirect_pass[Stuttgart,Trondheim]            0        81.12
# indirect_pass[Lyon,Trondheim]            0        99.28
# indirect_pass[Alicante,London]            0        72.72
# indirect_pass[Alicante,Frankfurt]            0        74.32
# indirect_pass[Alicante,Paris]            0        59.12
# indirect_pass[Alicante,Madrid]           -0        17.84
# indirect_pass[Alicante,Moscow]            0       169.84
# indirect_pass[Alicante,Istanbul]            0       125.84
# indirect_pass[Alicante,Dusseldorf]            0        76.56
# indirect_pass[Alicante,Dublin]            0        85.76
# indirect_pass[Alicante,Copenhagen]            0       107.36
# indirect_pass[Alicante,Rome]            0        58.24
# indirect_pass[Alicante,Manchester]            0        83.84
# indirect_pass[Alicante,Zurich]            0        61.76
# indirect_pass[Alicante,Berlin]            0        94.72
# indirect_pass[Alicante,Lisbon]            0        37.52
# indirect_pass[Alicante,Vienna]            0         86.8
# indirect_pass[Alicante,Prague]            0        87.44
# indirect_pass[Alicante,Milan]            0        55.92
# indirect_pass[Alicante,Oslo]            0        125.6
# indirect_pass[Alicante,Geneva]            0        51.12
# indirect_pass[Alicante,Athens]            0        105.2
# indirect_pass[Alicante,Helsinki]            0       149.68
# indirect_pass[Alicante,Edinburgh]            0        97.76
# indirect_pass[Alicante,Palma de Mallorca]            0        15.04
# indirect_pass[Alicante,Stockholm]            0        133.2
# indirect_pass[Alicante,Hamburg]            0        92.96
# indirect_pass[Alicante,Saint Petersburg]            0       160.64
# indirect_pass[Alicante,Warsaw]            0        112.8
# indirect_pass[Alicante,Malaga]           -0        19.44
# indirect_pass[Alicante,Budapest]            0         93.6
# indirect_pass[Alicante,Cologne/Bonn]            0        75.28
# indirect_pass[Alicante,Lyon]            0        46.32
# indirect_pass[Alicante,Bucharest]            0       114.96
# indirect_pass[Alicante,Birmingham]            0        78.24
# indirect_pass[Alicante,Stuttgart]            0        69.36
# indirect_pass[Alicante,Nice]            0        43.84
# indirect_pass[Alicante,Kyiv]            0        138.4
# indirect_pass[London,Alicante]            0        72.72
# indirect_pass[Frankfurt,Alicante]            0        74.32
# indirect_pass[Paris,Alicante]            0        59.12
# indirect_pass[Madrid,Alicante]           -0        17.84
# indirect_pass[Moscow,Alicante]            0       169.84
# indirect_pass[Istanbul,Alicante]            0       125.84
# indirect_pass[Dusseldorf,Alicante]            0        76.56
# indirect_pass[Dublin,Alicante]            0        85.76
# indirect_pass[Copenhagen,Alicante]            0       107.36
# indirect_pass[Rome,Alicante]            0        58.24
# indirect_pass[Manchester,Alicante]            0        83.84
# indirect_pass[Zurich,Alicante]            0        61.76
# indirect_pass[Berlin,Alicante]            0        94.72
# indirect_pass[Lisbon,Alicante]            0        37.52
# indirect_pass[Vienna,Alicante]            0         86.8
# indirect_pass[Prague,Alicante]            0        87.44
# indirect_pass[Milan,Alicante]            0        55.92
# indirect_pass[Oslo,Alicante]            0        125.6
# indirect_pass[Geneva,Alicante]            0        51.12
# indirect_pass[Athens,Alicante]            0        105.2
# indirect_pass[Helsinki,Alicante]            0       149.68
# indirect_pass[Edinburgh,Alicante]            0        97.76
# indirect_pass[Palma de Mallorca,Alicante]            0        15.04
# indirect_pass[Stockholm,Alicante]            0        133.2
# indirect_pass[Hamburg,Alicante]            0        92.96
# indirect_pass[Saint Petersburg,Alicante]            0       160.64
# indirect_pass[Warsaw,Alicante]            0        112.8
# indirect_pass[Malaga,Alicante]           -0        19.44
# indirect_pass[Budapest,Alicante]            0         93.6
# indirect_pass[Cologne/Bonn,Alicante]            0        75.28
# indirect_pass[Lyon,Alicante]            0        46.32
# indirect_pass[Bucharest,Alicante]            0       114.96
# indirect_pass[Birmingham,Alicante]            0        78.24
# indirect_pass[Stuttgart,Alicante]            0        69.36
# indirect_pass[Nice,Alicante]            0        43.84
# indirect_pass[Kyiv,Alicante]            0        138.4
# indirect_pass[Milan/Bergamo,Alicante]            0        58.08
# indirect_pass[Porto,Alicante]            0        37.84
# indirect_pass[Trondheim,Alicante]            0       143.36
# indirect_pass[Alicante,Milan/Bergamo]            0        58.08
# indirect_pass[Alicante,Porto]            0        37.84
# indirect_pass[Alicante,Trondheim]            0       143.36
# indirect_pass[Alicante,Amsterdam]            0        80.16
# indirect_pass[Amsterdam,Alicante]            0        80.16
# hub[Amsterdam]            1            0
#   hub[Paris]            1            0
